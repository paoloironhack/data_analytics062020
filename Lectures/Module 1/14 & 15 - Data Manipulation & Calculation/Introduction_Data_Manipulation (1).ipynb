# %% [markdown]
# # Data Manipulation

# %% [markdown]
# ## Introduction

# %% [markdown]
# One of the reasons Pandas has become such a popular tool for data analysts over the last few years is because it makes data transformation and manipulation much faster and easier. In this lesson, we will take an introductory look at how to rename and restructure data as we prepare it to be analyzed.

# %% [markdown]
# For this lesson, we will be using the same vehicles data set that we practiced importing and exporting in the Import and Export lesson. Let's go ahead and import the CSV version of the data set and see what it actually looks like.

# %%
import pandas as pd

# %%
# read 'vehicles/vehicles.csv' as data
data = pd.read_csv('vehicles/vehicles.csv')
data.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 0   Regular          19.388824        18           17            17
# 1   Regular          25.354615        13           13            13
# 2   Regular          20.600625        16           17            16
# 3   Regular          25.354615        13           13            13
# 4   Premium          20.600625        14           21            16
#
#    CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               522.764706            1950
# 1               683.615385            2550
# 2               555.437500            2100
# 3               683.615385            2550
# 4               555.437500            2550

# %% [markdown]
# ## Renaming Columns

# %% [markdown]
# Data will often come either without column names or with column names that are not as intuitive as they could be. When this is the case, we want to assign descriptive names to the columns so that we remember what the values in each column represent. Intuitively naming your columns before diving in and analyzing your data is a good habit to develop.

# %% [markdown]
# Pandas provides us with a couple different ways to modify column names. For example, the **.columns method** will return a list of all the column names in the data set.

# %%
# display columns
data.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Displacement', 'Cylinders',
#        'Transmission', 'Drivetrain', 'Vehicle Class', 'Fuel Type',
#        'Fuel Barrels/Year', 'City MPG', 'Highway MPG', 'Combined MPG',
#        'CO2 Emission Grams/Mile', 'Fuel Cost/Year'],
#       dtype='object')

# %% [markdown]
# If you want to set the column names for every column in the data set, or change the names of multiple columns, you can just **pass the columns method a list *with the same number of column names* as the data has columns, and Pandas will update all the column names.**

# %% [markdown]
# In the example below, we are updating the **Make column name to Manufacturer** and the **Engine Displacement column name to Displacement** using this method.

# %%
# Rename columns
data.columns = ['Manufacturer','Model','Year','Displacement',
                'Cylinders','Transmission','Drivetrain',
                'Vehicle Class','Fuel Type','Fuel Barrels/Year',
                'City MPG','Highway MPG','Combined MPG',
                'CO2 Emission Grams/Mile','Fuel Cost/Year']
 
data.columns
# Out:
# Index(['Manufacturer', 'Model', 'Year', 'Displacement', 'Cylinders',
#        'Transmission', 'Drivetrain', 'Vehicle Class', 'Fuel Type',
#        'Fuel Barrels/Year', 'City MPG', 'Highway MPG', 'Combined MPG',
#        'CO2 Emission Grams/Mile', 'Fuel Cost/Year'],
#       dtype='object')

# %% [markdown]
# If you want to rename just a single column, or just a few columns, you can use the **.rename method** and pass a dictionary containing the existing column names and new column names to the columns parameter. Below, we will change the column names we modified in the previous example back to their original column names using the rename method.

# %%
#rename columns using .rename 
data.rename(columns = {'Manufacturer' : 'Make'})
# Out:
#                    Make                Model  Year  Displacement  Cylinders  \
# 0            AM General    DJ Po Vehicle 2WD  1984           2.5        4.0
# 1            AM General     FJ8c Post Office  1984           4.2        6.0
# 2            AM General  Post Office DJ5 2WD  1985           2.5        4.0
# 3            AM General  Post Office DJ8 2WD  1985           4.2        6.0
# 4      ASC Incorporated                  GNX  1987           3.8        6.0
# ...                 ...                  ...   ...           ...        ...
# 35947             smart         fortwo coupe  2013           1.0        3.0
# 35948             smart         fortwo coupe  2014           1.0        3.0
# 35949             smart         fortwo coupe  2015           1.0        3.0
# 35950             smart         fortwo coupe  2016           0.9        3.0
# 35951             smart         fortwo coupe  2016           0.9        3.0
#
#           Transmission        Drivetrain                Vehicle Class  \
# 0      Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1      Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2      Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3      Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4      Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
# ...                ...               ...                          ...
# 35947        Auto(AM5)  Rear-Wheel Drive                  Two Seaters
# 35948        Auto(AM5)  Rear-Wheel Drive                  Two Seaters
# 35949        Auto(AM5)  Rear-Wheel Drive                  Two Seaters
# 35950        Auto(AM6)  Rear-Wheel Drive                  Two Seaters
# 35951     Manual 5-spd  Rear-Wheel Drive                  Two Seaters
#
#       Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 0       Regular          19.388824        18           17            17
# 1       Regular          25.354615        13           13            13
# 2       Regular          20.600625        16           17            16
# 3       Regular          25.354615        13           13            13
# 4       Premium          20.600625        14           21            16
# ...         ...                ...       ...          ...           ...
# 35947   Premium           9.155833        34           38            36
# 35948   Premium           9.155833        34           38            36
# 35949   Premium           9.155833        34           38            36
# 35950   Premium           9.155833        34           39            36
# 35951   Premium           9.417429        32           39            35
#
#        CO2 Emission Grams/Mile  Fuel Cost/Year
# 0                   522.764706            1950
# 1                   683.615385            2550
# 2                   555.437500            2100
# 3                   683.615385            2550
# 4                   555.437500            2550
# ...                        ...             ...
# 35947               244.000000            1100
# 35948               243.000000            1100
# 35949               244.000000            1100
# 35950               246.000000            1100
# 35951               255.000000            1150
#
# [35952 rows x 15 columns]

# %% [markdown]
# ## Changing Column Order

# %% [markdown]
# You can also **reorder columns** in a data frame. To do this, you would create a list containing the data frame's column names in the order you would like them. Then you can just recreate the data frame with the customized ordering as follows.

# %%
data = pd.read_csv('vehicles/vehicles.csv')
data.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Displacement', 'Cylinders',
#        'Transmission', 'Drivetrain', 'Vehicle Class', 'Fuel Type',
#        'Fuel Barrels/Year', 'City MPG', 'Highway MPG', 'Combined MPG',
#        'CO2 Emission Grams/Mile', 'Fuel Cost/Year'],
#       dtype='object')

# %%
# change column order: swap year and model, vehicle class and transmiss, ect. 
column_order = ['Make','Year','Model','Vehicle Class',
                'Transmission','Drivetrain','Fuel Type',
                'Cylinders','Engine Displacement','Fuel Barrels/Year'
                ,'Highway MPG','Combined MPG',
                'CO2 Emission Grams/Mile','Fuel Cost/Year']

# %%
data = data[column_order]
#data[['Year','Make']]

# %%
data.columns
# Out:
# Index(['Make', 'Year', 'Model', 'Vehicle Class', 'Transmission', 'Drivetrain',
#        'Fuel Type', 'Cylinders', 'Engine Displacement', 'Fuel Barrels/Year',
#        'Highway MPG', 'Combined MPG', 'CO2 Emission Grams/Mile',
#        'Fuel Cost/Year'],
#       dtype='object')

# %% [markdown]
# ## Filtering Records

# %% [markdown]
# When working with data, analysts often need to **filter the data based on one or more conditional statements**. This is similar to adding a WHERE clause to a query in SQL.

# %% [markdown]
# For example, suppose we needed to filter our data set for all Ford vehicles that had a 6 or more cylinders and a combined MPG of less than 18. We could enter our conditions inside square brackets to subset the data set for just the records that meet the conditions we've specified.

# %%
data
# Out:
#                    Make  Year                Model  \
# 0            AM General  1984    DJ Po Vehicle 2WD
# 1            AM General  1984     FJ8c Post Office
# 2            AM General  1985  Post Office DJ5 2WD
# 3            AM General  1985  Post Office DJ8 2WD
# 4      ASC Incorporated  1987                  GNX
# ...                 ...   ...                  ...
# 35947             smart  2013         fortwo coupe
# 35948             smart  2014         fortwo coupe
# 35949             smart  2015         fortwo coupe
# 35950             smart  2016         fortwo coupe
# 35951             smart  2016         fortwo coupe
#
#                      Vehicle Class     Transmission        Drivetrain  \
# 0      Special Purpose Vehicle 2WD  Automatic 3-spd     2-Wheel Drive
# 1      Special Purpose Vehicle 2WD  Automatic 3-spd     2-Wheel Drive
# 2      Special Purpose Vehicle 2WD  Automatic 3-spd  Rear-Wheel Drive
# 3      Special Purpose Vehicle 2WD  Automatic 3-spd  Rear-Wheel Drive
# 4                     Midsize Cars  Automatic 4-spd  Rear-Wheel Drive
# ...                            ...              ...               ...
# 35947                  Two Seaters        Auto(AM5)  Rear-Wheel Drive
# 35948                  Two Seaters        Auto(AM5)  Rear-Wheel Drive
# 35949                  Two Seaters        Auto(AM5)  Rear-Wheel Drive
# 35950                  Two Seaters        Auto(AM6)  Rear-Wheel Drive
# 35951                  Two Seaters     Manual 5-spd  Rear-Wheel Drive
#
#       Fuel Type  Cylinders  Engine Displacement  Fuel Barrels/Year  \
# 0       Regular        4.0                  2.5          19.388824
# 1       Regular        6.0                  4.2          25.354615
# 2       Regular        4.0                  2.5          20.600625
# 3       Regular        6.0                  4.2          25.354615
# 4       Premium        6.0                  3.8          20.600625
# ...         ...        ...                  ...                ...
# 35947   Premium        3.0                  1.0           9.155833
# 35948   Premium        3.0                  1.0           9.155833
# 35949   Premium        3.0                  1.0           9.155833
# 35950   Premium        3.0                  0.9           9.155833
# 35951   Premium        3.0                  0.9           9.417429
#
#        Highway MPG  Combined MPG  CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               17            17               522.764706            1950
# 1               13            13               683.615385            2550
# 2               17            16               555.437500            2100
# 3               13            13               683.615385            2550
# 4               21            16               555.437500            2550
# ...            ...           ...                      ...             ...
# 35947           38            36               244.000000            1100
# 35948           38            36               243.000000            1100
# 35949           38            36               244.000000            1100
# 35950           39            36               246.000000            1100
# 35951           39            35               255.000000            1150
#
# [35952 rows x 14 columns]

# %%
# filter data where Make == Ford, Cylinders => 6 AND 'Combined MPG' < 18
new_data = data[(data['Make'] == 'Ford') & (data['Cylinders'] >= 6) & (data['Combined MPG'] < 18)]
new_data.head()
# Out:
#        Make  Year         Model Vehicle Class     Transmission  \
# 11442  Ford  1986  Aerostar Van          Vans  Automatic 4-spd
# 11450  Ford  1988  Aerostar Van          Vans  Automatic 4-spd
# 11452  Ford  1989  Aerostar Van          Vans  Automatic 4-spd
# 11456  Ford  1990  Aerostar Van          Vans  Automatic 4-spd
# 11459  Ford  1991  Aerostar Van          Vans  Automatic 4-spd
#
#              Drivetrain Fuel Type  Cylinders  Engine Displacement  \
# 11442  Rear-Wheel Drive   Regular        6.0                  2.8
# 11450  Rear-Wheel Drive   Regular        6.0                  3.0
# 11452  Rear-Wheel Drive   Regular        6.0                  3.0
# 11456  Rear-Wheel Drive   Regular        6.0                  4.0
# 11459  Rear-Wheel Drive   Regular        6.0                  4.0
#
#        Fuel Barrels/Year  Highway MPG  Combined MPG  CO2 Emission Grams/Mile  \
# 11442          19.388824           21            17               522.764706
# 11450          19.388824           20            17               522.764706
# 11452          19.388824           21            17               522.764706
# 11456          19.388824           20            17               522.764706
# 11459          19.388824           20            17               522.764706
#
#        Fuel Cost/Year
# 11442            1950
# 11450            1950
# 11452            1950
# 11456            1950
# 11459            1950

# %% [markdown]
# There are a couple of important things to note here:
#
# - First, when you want to apply **multiple conditions**, you need to use an "and" operator (&) or an "or" operator (|) between your conditions. The "and" operator will return records where both of the conditions surrounding it are true, and the "or" operator will return records where either of the conditions surrounding it are true.
# - The second thing to note is that all our conditional statements are **enclosed in parentheses**. This is easy to forget, but necessary or else your results will be incorrect.

# %%
new_data_bmw_audi = data[((data['Make'] == 'BMW') & (data['Year'] >= 2016)) | ((data['Make'] == 'Audi') & (data['Year'] >= 2016))]
new_data_bmw_audi
# Out:
#       Make  Year                 Model    Vehicle Class     Transmission  \
# 638   Audi  2016                    A3  Subcompact Cars      Auto(AM-S6)
# 640   Audi  2016          A3 Cabriolet  Subcompact Cars      Auto(AM-S6)
# 642   Audi  2016  A3 Cabriolet quattro  Subcompact Cars      Auto(AM-S6)
# 643   Audi  2016             A3 e-tron     Compact Cars      Auto(AM-S6)
# 644   Audi  2016       A3 e-tron ultra     Compact Cars      Auto(AM-S6)
# ...    ...   ...                   ...              ...              ...
# 3038   BMW  2016          Z4 sDrive28i      Two Seaters     Manual 6-spd
# 3058   BMW  2016          Z4 sDrive35i      Two Seaters      Auto(AM-S7)
# 3064   BMW  2016         Z4 sDrive35is      Two Seaters      Auto(AM-S7)
# 3071   BMW  2016                i3 REX  Subcompact Cars   Automatic (A1)
# 3074   BMW  2016                    i8  Subcompact Cars  Automatic 6-spd
#
#              Drivetrain                   Fuel Type  Cylinders  \
# 638   Front-Wheel Drive                     Regular        4.0
# 640   Front-Wheel Drive                     Regular        4.0
# 642     All-Wheel Drive                     Regular        4.0
# 643   Front-Wheel Drive     Premium and Electricity        4.0
# 644   Front-Wheel Drive     Premium and Electricity        4.0
# ...                 ...                         ...        ...
# 3038   Rear-Wheel Drive                     Premium        4.0
# 3058   Rear-Wheel Drive                     Premium        6.0
# 3064   Rear-Wheel Drive                     Premium        6.0
# 3071   Rear-Wheel Drive  Premium Gas or Electricity        2.0
# 3074    All-Wheel Drive     Premium and Electricity        3.0
#
#       Engine Displacement  Fuel Barrels/Year  Highway MPG  Combined MPG  \
# 638                   1.8          12.207778           33            27
# 640                   1.8          11.771786           35            28
# 642                   2.0          12.677308           32            26
# 643                   1.4           5.863280           37            35
# 644                   1.4           5.115503           41            39
# ...                   ...                ...          ...           ...
# 3038                  2.0          12.677308           34            26
# 3058                  3.0          16.480500           24            20
# 3064                  3.0          16.480500           24            20
# 3071                  0.6           1.563190           37            39
# 3074                  1.5           7.356924           29            28
#
#       CO2 Emission Grams/Mile  Fuel Cost/Year
# 638                     328.0            1250
# 640                     314.0            1200
# 642                     334.0            1300
# 643                     158.0            1150
# 644                     138.0            1050
# ...                       ...             ...
# 3038                    337.0            1550
# 3058                    454.0            2000
# 3064                    454.0            2000
# 3071                     37.0            1050
# 3074                    198.0            1450
#
# [277 rows x 14 columns]

# %%
new_data_bmw_audi = data[((data['Make'] == 'BMW') | (data['Make'] == 'Audi')) & (data['Year'] >= 2016)]
new_data_bmw_audi
# Out:
#       Make  Year                 Model    Vehicle Class     Transmission  \
# 638   Audi  2016                    A3  Subcompact Cars      Auto(AM-S6)
# 640   Audi  2016          A3 Cabriolet  Subcompact Cars      Auto(AM-S6)
# 642   Audi  2016  A3 Cabriolet quattro  Subcompact Cars      Auto(AM-S6)
# 643   Audi  2016             A3 e-tron     Compact Cars      Auto(AM-S6)
# 644   Audi  2016       A3 e-tron ultra     Compact Cars      Auto(AM-S6)
# ...    ...   ...                   ...              ...              ...
# 3038   BMW  2016          Z4 sDrive28i      Two Seaters     Manual 6-spd
# 3058   BMW  2016          Z4 sDrive35i      Two Seaters      Auto(AM-S7)
# 3064   BMW  2016         Z4 sDrive35is      Two Seaters      Auto(AM-S7)
# 3071   BMW  2016                i3 REX  Subcompact Cars   Automatic (A1)
# 3074   BMW  2016                    i8  Subcompact Cars  Automatic 6-spd
#
#              Drivetrain                   Fuel Type  Cylinders  \
# 638   Front-Wheel Drive                     Regular        4.0
# 640   Front-Wheel Drive                     Regular        4.0
# 642     All-Wheel Drive                     Regular        4.0
# 643   Front-Wheel Drive     Premium and Electricity        4.0
# 644   Front-Wheel Drive     Premium and Electricity        4.0
# ...                 ...                         ...        ...
# 3038   Rear-Wheel Drive                     Premium        4.0
# 3058   Rear-Wheel Drive                     Premium        6.0
# 3064   Rear-Wheel Drive                     Premium        6.0
# 3071   Rear-Wheel Drive  Premium Gas or Electricity        2.0
# 3074    All-Wheel Drive     Premium and Electricity        3.0
#
#       Engine Displacement  Fuel Barrels/Year  Highway MPG  Combined MPG  \
# 638                   1.8          12.207778           33            27
# 640                   1.8          11.771786           35            28
# 642                   2.0          12.677308           32            26
# 643                   1.4           5.863280           37            35
# 644                   1.4           5.115503           41            39
# ...                   ...                ...          ...           ...
# 3038                  2.0          12.677308           34            26
# 3058                  3.0          16.480500           24            20
# 3064                  3.0          16.480500           24            20
# 3071                  0.6           1.563190           37            39
# 3074                  1.5           7.356924           29            28
#
#       CO2 Emission Grams/Mile  Fuel Cost/Year
# 638                     328.0            1250
# 640                     314.0            1200
# 642                     334.0            1300
# 643                     158.0            1150
# 644                     138.0            1050
# ...                       ...             ...
# 3038                    337.0            1550
# 3058                    454.0            2000
# 3064                    454.0            2000
# 3071                     37.0            1050
# 3074                    198.0            1450
#
# [277 rows x 14 columns]

# %% [markdown]
# ## Retrieving Information from the Dataframe

# %% [markdown]
# You can also retrieve "high-level" information from the data frame using the following methods.

# %%
# Then, inspect the dtypes
data.dtypes
# Out:
# Make                        object
# Year                         int64
# Model                       object
# Vehicle Class               object
# Transmission                object
# Drivetrain                  object
# Fuel Type                   object
# Cylinders                  float64
# Engine Displacement        float64
# Fuel Barrels/Year          float64
# Highway MPG                  int64
# Combined MPG                 int64
# CO2 Emission Grams/Mile    float64
# Fuel Cost/Year               int64
# dtype: object

# %%
# First, use describe method 
data.describe()
# Out:
#               Year     Cylinders  Engine Displacement  Fuel Barrels/Year  \
# count  35952.00000  35952.000000         35952.000000       35952.000000
# mean    2000.71640      5.765076             3.338493          17.609056
# std       10.08529      1.755268             1.359395           4.467283
# min     1984.00000      2.000000             0.600000           0.060000
# 25%     1991.00000      4.000000             2.200000          14.699423
# 50%     2001.00000      6.000000             3.000000          17.347895
# 75%     2010.00000      6.000000             4.300000          20.600625
# max     2017.00000     16.000000             8.400000          47.087143
#
#         Highway MPG  Combined MPG  CO2 Emission Grams/Mile  Fuel Cost/Year
# count  35952.000000  35952.000000             35952.000000    35952.000000
# mean      23.880646     19.929322               475.316339     1892.598465
# std        5.890876      5.112409               119.060773      506.958627
# min        9.000000      7.000000                37.000000      600.000000
# 25%       20.000000     16.000000               395.000000     1500.000000
# 50%       24.000000     19.000000               467.736842     1850.000000
# 75%       27.000000     23.000000               555.437500     2200.000000
# max       61.000000     56.000000              1269.571429     5800.000000

# %%
data.describe().transpose()
# Out:
#                            count         mean         std      min  \
# Year                     35952.0  2000.716400   10.085290  1984.00
# Cylinders                35952.0     5.765076    1.755268     2.00
# Engine Displacement      35952.0     3.338493    1.359395     0.60
# Fuel Barrels/Year        35952.0    17.609056    4.467283     0.06
# Highway MPG              35952.0    23.880646    5.890876     9.00
# Combined MPG             35952.0    19.929322    5.112409     7.00
# CO2 Emission Grams/Mile  35952.0   475.316339  119.060773    37.00
# Fuel Cost/Year           35952.0  1892.598465  506.958627   600.00
#
#                                  25%          50%          75%          max
# Year                     1991.000000  2001.000000  2010.000000  2017.000000
# Cylinders                   4.000000     6.000000     6.000000    16.000000
# Engine Displacement         2.200000     3.000000     4.300000     8.400000
# Fuel Barrels/Year          14.699423    17.347895    20.600625    47.087143
# Highway MPG                20.000000    24.000000    27.000000    61.000000
# Combined MPG               16.000000    19.000000    23.000000    56.000000
# CO2 Emission Grams/Mile   395.000000   467.736842   555.437500  1269.571429
# Fuel Cost/Year           1500.000000  1850.000000  2200.000000  5800.000000

# %% [markdown]
# ## .loc and .iloc

# %% [markdown]
# We saw that we were able to select and retrieve specific information in our data frame using techniques such as conditional filtering. We also saw that we could simply select any number of columns from a data frame using the double bracket syntax. However, now suppose that we want to select not only specific columns, but also a (or any number of) row(s). In that case, we can use the .loc and .iloc methods.

# %% [markdown]
# .loc is short for location and let's you select a subset of the data based on the location of the row index and column name. Consider the following example.

# %%
data.head(20)
# Out:
#                 Make  Year                Model                Vehicle Class  \
# 0         AM General  1984    DJ Po Vehicle 2WD  Special Purpose Vehicle 2WD
# 1         AM General  1984     FJ8c Post Office  Special Purpose Vehicle 2WD
# 2         AM General  1985  Post Office DJ5 2WD  Special Purpose Vehicle 2WD
# 3         AM General  1985  Post Office DJ8 2WD  Special Purpose Vehicle 2WD
# 4   ASC Incorporated  1987                  GNX                 Midsize Cars
# 5              Acura  1997          2.2CL/3.0CL              Subcompact Cars
# 6              Acura  1997          2.2CL/3.0CL              Subcompact Cars
# 7              Acura  1997          2.2CL/3.0CL              Subcompact Cars
# 8              Acura  1998          2.3CL/3.0CL              Subcompact Cars
# 9              Acura  1998          2.3CL/3.0CL              Subcompact Cars
# 10             Acura  1998          2.3CL/3.0CL              Subcompact Cars
# 11             Acura  1999          2.3CL/3.0CL              Subcompact Cars
# 12             Acura  1999          2.3CL/3.0CL              Subcompact Cars
# 13             Acura  1999          2.3CL/3.0CL              Subcompact Cars
# 14             Acura  1995                2.5TL                 Compact Cars
# 15             Acura  1996          2.5TL/3.2TL                 Compact Cars
# 16             Acura  1996          2.5TL/3.2TL                 Compact Cars
# 17             Acura  1997          2.5TL/3.2TL                 Compact Cars
# 18             Acura  1997          2.5TL/3.2TL                 Compact Cars
# 19             Acura  1998          2.5TL/3.2TL                 Compact Cars
#
#        Transmission         Drivetrain Fuel Type  Cylinders  \
# 0   Automatic 3-spd      2-Wheel Drive   Regular        4.0
# 1   Automatic 3-spd      2-Wheel Drive   Regular        6.0
# 2   Automatic 3-spd   Rear-Wheel Drive   Regular        4.0
# 3   Automatic 3-spd   Rear-Wheel Drive   Regular        6.0
# 4   Automatic 4-spd   Rear-Wheel Drive   Premium        6.0
# 5   Automatic 4-spd  Front-Wheel Drive   Regular        4.0
# 6      Manual 5-spd  Front-Wheel Drive   Regular        4.0
# 7   Automatic 4-spd  Front-Wheel Drive   Regular        6.0
# 8   Automatic 4-spd  Front-Wheel Drive   Regular        4.0
# 9      Manual 5-spd  Front-Wheel Drive   Regular        4.0
# 10  Automatic 4-spd  Front-Wheel Drive   Regular        6.0
# 11  Automatic 4-spd  Front-Wheel Drive   Regular        4.0
# 12     Manual 5-spd  Front-Wheel Drive   Regular        4.0
# 13  Automatic 4-spd  Front-Wheel Drive   Regular        6.0
# 14  Automatic 4-spd  Front-Wheel Drive   Premium        5.0
# 15  Automatic 4-spd  Front-Wheel Drive   Premium        5.0
# 16  Automatic 4-spd  Front-Wheel Drive   Premium        6.0
# 17  Automatic 4-spd  Front-Wheel Drive   Premium        5.0
# 18  Automatic 4-spd  Front-Wheel Drive   Premium        6.0
# 19  Automatic 4-spd  Front-Wheel Drive   Premium        5.0
#
#     Engine Displacement  Fuel Barrels/Year  Highway MPG  Combined MPG  \
# 0                   2.5          19.388824           17            17
# 1                   4.2          25.354615           13            13
# 2                   2.5          20.600625           17            16
# 3                   4.2          25.354615           13            13
# 4                   3.8          20.600625           21            16
# 5                   2.2          14.982273           26            22
# 6                   2.2          13.733750           28            24
# 7                   3.0          16.480500           26            20
# 8                   2.3          14.982273           27            22
# 9                   2.3          13.733750           29            24
# 10                  3.0          16.480500           26            20
# 11                  2.3          14.982273           27            22
# 12                  2.3          13.733750           29            24
# 13                  3.0          16.480500           26            20
# 14                  2.5          16.480500           23            20
# 15                  2.5          16.480500           23            20
# 16                  3.2          17.347895           22            19
# 17                  2.5          16.480500           23            20
# 18                  3.2          17.347895           22            19
# 19                  2.5          16.480500           23            20
#
#     CO2 Emission Grams/Mile  Fuel Cost/Year
# 0                522.764706            1950
# 1                683.615385            2550
# 2                555.437500            2100
# 3                683.615385            2550
# 4                555.437500            2550
# 5                403.954545            1500
# 6                370.291667            1400
# 7                444.350000            1650
# 8                403.954545            1500
# 9                370.291667            1400
# 10               444.350000            1650
# 11               403.954545            1500
# 12               370.291667            1400
# 13               444.350000            1650
# 14               444.350000            2000
# 15               444.350000            2000
# 16               467.736842            2150
# 17               444.350000            2000
# 18               467.736842            2150
# 19               444.350000            2000

# %%
data.loc[20, 'Year']
# Out:
# 1998

# %%
data.loc[20, ['Year', 'Model']]

# %%
data.loc[20]
# Out:
# Make                                   Acura
# Year                                    1998
# Model                            2.5TL/3.2TL
# Vehicle Class                   Compact Cars
# Transmission                 Automatic 4-spd
# Drivetrain                 Front-Wheel Drive
# Fuel Type                            Premium
# Cylinders                                  6
# Engine Displacement                      3.2
# Fuel Barrels/Year                    17.3479
# Highway MPG                               22
# Combined MPG                              19
# CO2 Emission Grams/Mile              467.737
# Fuel Cost/Year                          2150
# Name: 20, dtype: object

# %% [markdown]
# **Important:** Keep in mind that single brackets will return a pd.Series, whereas double brackets will return a pd.DataFrame object.

# %%
data.loc[[20]]
# Out:
#      Make  Year        Model Vehicle Class     Transmission  \
# 20  Acura  1998  2.5TL/3.2TL  Compact Cars  Automatic 4-spd
#
#            Drivetrain Fuel Type  Cylinders  Engine Displacement  \
# 20  Front-Wheel Drive   Premium        6.0                  3.2
#
#     Fuel Barrels/Year  Highway MPG  Combined MPG  CO2 Emission Grams/Mile  \
# 20          17.347895           22            19               467.736842
#
#     Fuel Cost/Year
# 20            2150

# %%
data.loc[[2034]]
# Out:
#      Make  Year     Model Vehicle Class     Transmission        Drivetrain  \
# 2034  BMW  1986  5 Series  Compact Cars  Automatic 4-spd  Rear-Wheel Drive
#
#      Fuel Type  Cylinders  Engine Displacement  Fuel Barrels/Year  \
# 2034   Regular        6.0                  3.4          20.600625
#
#       Highway MPG  Combined MPG  CO2 Emission Grams/Mile  Fuel Cost/Year
# 2034           20            16                 555.4375            2100

# %% [markdown]
# The .loc method can also be used to retrieve a specific subset of the data based on a particular value.

# %%
data.loc[data['Make'] == "BMW"]
# Out:
#      Make  Year              Model    Vehicle Class     Transmission  \
# 1398  BMW  2010  128ci Convertible  Subcompact Cars   Automatic (S6)
# 1399  BMW  2010  128ci Convertible  Subcompact Cars     Manual 6-spd
# 1400  BMW  2011  128ci Convertible  Subcompact Cars     Manual 6-spd
# 1401  BMW  2011  128ci Convertible  Subcompact Cars   Automatic (S6)
# 1402  BMW  2012  128ci Convertible  Subcompact Cars   Automatic (S6)
# ...   ...   ...                ...              ...              ...
# 3070  BMW  2015             i3 REX  Subcompact Cars   Automatic (A1)
# 3071  BMW  2016             i3 REX  Subcompact Cars   Automatic (A1)
# 3072  BMW  2014                 i8  Subcompact Cars  Automatic 6-spd
# 3073  BMW  2015                 i8  Subcompact Cars  Automatic 6-spd
# 3074  BMW  2016                 i8  Subcompact Cars  Automatic 6-spd
#
#             Drivetrain                   Fuel Type  Cylinders  \
# 1398  Rear-Wheel Drive                     Premium        6.0
# 1399  Rear-Wheel Drive                     Premium        6.0
# 1400  Rear-Wheel Drive                     Premium        6.0
# 1401  Rear-Wheel Drive                     Premium        6.0
# 1402  Rear-Wheel Drive                     Premium        6.0
# ...                ...                         ...        ...
# 3070  Rear-Wheel Drive  Premium Gas or Electricity        2.0
# 3071  Rear-Wheel Drive  Premium Gas or Electricity        2.0
# 3072   All-Wheel Drive     Premium and Electricity        3.0
# 3073   All-Wheel Drive     Premium and Electricity        3.0
# 3074   All-Wheel Drive     Premium and Electricity        3.0
#
#       Engine Displacement  Fuel Barrels/Year  Highway MPG  Combined MPG  \
# 1398                  3.0          15.695714           27            21
# 1399                  3.0          14.982273           28            22
# 1400                  3.0          14.982273           28            22
# 1401                  3.0          15.695714           27            21
# 1402                  3.0          15.695714           27            21
# ...                   ...                ...          ...           ...
# 3070                  0.6           1.563190           37            39
# 3071                  0.6           1.563190           37            39
# 3072                  1.5           7.356924           29            28
# 3073                  1.5           7.356924           29            28
# 3074                  1.5           7.356924           29            28
#
#       CO2 Emission Grams/Mile  Fuel Cost/Year
# 1398               423.190476            1950
# 1399               403.954545            1850
# 1400               403.954545            1850
# 1401               423.190476            1950
# 1402               423.190476            1950
# ...                       ...             ...
# 3070                40.000000            1050
# 3071                37.000000            1050
# 3072               198.000000            1450
# 3073               198.000000            1450
# 3074               198.000000            1450
#
# [1677 rows x 14 columns]

# %% [markdown]
# **Important:** This is equivalent to the following.

# %%
data[data['Make'] == "BMW"]
# Out:
#      Make  Year              Model    Vehicle Class     Transmission  \
# 1398  BMW  2010  128ci Convertible  Subcompact Cars   Automatic (S6)
# 1399  BMW  2010  128ci Convertible  Subcompact Cars     Manual 6-spd
# 1400  BMW  2011  128ci Convertible  Subcompact Cars     Manual 6-spd
# 1401  BMW  2011  128ci Convertible  Subcompact Cars   Automatic (S6)
# 1402  BMW  2012  128ci Convertible  Subcompact Cars   Automatic (S6)
# ...   ...   ...                ...              ...              ...
# 3070  BMW  2015             i3 REX  Subcompact Cars   Automatic (A1)
# 3071  BMW  2016             i3 REX  Subcompact Cars   Automatic (A1)
# 3072  BMW  2014                 i8  Subcompact Cars  Automatic 6-spd
# 3073  BMW  2015                 i8  Subcompact Cars  Automatic 6-spd
# 3074  BMW  2016                 i8  Subcompact Cars  Automatic 6-spd
#
#             Drivetrain                   Fuel Type  Cylinders  \
# 1398  Rear-Wheel Drive                     Premium        6.0
# 1399  Rear-Wheel Drive                     Premium        6.0
# 1400  Rear-Wheel Drive                     Premium        6.0
# 1401  Rear-Wheel Drive                     Premium        6.0
# 1402  Rear-Wheel Drive                     Premium        6.0
# ...                ...                         ...        ...
# 3070  Rear-Wheel Drive  Premium Gas or Electricity        2.0
# 3071  Rear-Wheel Drive  Premium Gas or Electricity        2.0
# 3072   All-Wheel Drive     Premium and Electricity        3.0
# 3073   All-Wheel Drive     Premium and Electricity        3.0
# 3074   All-Wheel Drive     Premium and Electricity        3.0
#
#       Engine Displacement  Fuel Barrels/Year  Highway MPG  Combined MPG  \
# 1398                  3.0          15.695714           27            21
# 1399                  3.0          14.982273           28            22
# 1400                  3.0          14.982273           28            22
# 1401                  3.0          15.695714           27            21
# 1402                  3.0          15.695714           27            21
# ...                   ...                ...          ...           ...
# 3070                  0.6           1.563190           37            39
# 3071                  0.6           1.563190           37            39
# 3072                  1.5           7.356924           29            28
# 3073                  1.5           7.356924           29            28
# 3074                  1.5           7.356924           29            28
#
#       CO2 Emission Grams/Mile  Fuel Cost/Year
# 1398               423.190476            1950
# 1399               403.954545            1850
# 1400               403.954545            1850
# 1401               423.190476            1950
# 1402               423.190476            1950
# ...                       ...             ...
# 3070                40.000000            1050
# 3071                37.000000            1050
# 3072               198.000000            1450
# 3073               198.000000            1450
# 3074               198.000000            1450
#
# [1677 rows x 14 columns]

# %% [markdown]
# Now suppose that we want to retrieve information based on the row and/or column **index**. In that case, we can use the .iloc method.

# %%
# Retrieve row 7-18
data.iloc[7:18]
# Out:
#      Make  Year        Model    Vehicle Class     Transmission  \
# 7   Acura  1997  2.2CL/3.0CL  Subcompact Cars  Automatic 4-spd
# 8   Acura  1998  2.3CL/3.0CL  Subcompact Cars  Automatic 4-spd
# 9   Acura  1998  2.3CL/3.0CL  Subcompact Cars     Manual 5-spd
# 10  Acura  1998  2.3CL/3.0CL  Subcompact Cars  Automatic 4-spd
# 11  Acura  1999  2.3CL/3.0CL  Subcompact Cars  Automatic 4-spd
# 12  Acura  1999  2.3CL/3.0CL  Subcompact Cars     Manual 5-spd
# 13  Acura  1999  2.3CL/3.0CL  Subcompact Cars  Automatic 4-spd
# 14  Acura  1995        2.5TL     Compact Cars  Automatic 4-spd
# 15  Acura  1996  2.5TL/3.2TL     Compact Cars  Automatic 4-spd
# 16  Acura  1996  2.5TL/3.2TL     Compact Cars  Automatic 4-spd
# 17  Acura  1997  2.5TL/3.2TL     Compact Cars  Automatic 4-spd
#
#            Drivetrain Fuel Type  Cylinders  Engine Displacement  \
# 7   Front-Wheel Drive   Regular        6.0                  3.0
# 8   Front-Wheel Drive   Regular        4.0                  2.3
# 9   Front-Wheel Drive   Regular        4.0                  2.3
# 10  Front-Wheel Drive   Regular        6.0                  3.0
# 11  Front-Wheel Drive   Regular        4.0                  2.3
# 12  Front-Wheel Drive   Regular        4.0                  2.3
# 13  Front-Wheel Drive   Regular        6.0                  3.0
# 14  Front-Wheel Drive   Premium        5.0                  2.5
# 15  Front-Wheel Drive   Premium        5.0                  2.5
# 16  Front-Wheel Drive   Premium        6.0                  3.2
# 17  Front-Wheel Drive   Premium        5.0                  2.5
#
#     Fuel Barrels/Year  Highway MPG  Combined MPG  CO2 Emission Grams/Mile  \
# 7           16.480500           26            20               444.350000
# 8           14.982273           27            22               403.954545
# 9           13.733750           29            24               370.291667
# 10          16.480500           26            20               444.350000
# 11          14.982273           27            22               403.954545
# 12          13.733750           29            24               370.291667
# 13          16.480500           26            20               444.350000
# 14          16.480500           23            20               444.350000
# 15          16.480500           23            20               444.350000
# 16          17.347895           22            19               467.736842
# 17          16.480500           23            20               444.350000
#
#     Fuel Cost/Year
# 7             1650
# 8             1500
# 9             1400
# 10            1650
# 11            1500
# 12            1400
# 13            1650
# 14            2000
# 15            2000
# 16            2150
# 17            2000

# %%
data['Transmission']
# Out:
# 0        Automatic 3-spd
# 1        Automatic 3-spd
# 2        Automatic 3-spd
# 3        Automatic 3-spd
# 4        Automatic 4-spd
#               ...
# 35947          Auto(AM5)
# 35948          Auto(AM5)
# 35949          Auto(AM5)
# 35950          Auto(AM6)
# 35951       Manual 5-spd
# Name: Transmission, Length: 35952, dtype: object

# %%
data.iloc[:, 4]
# Out:
# 0        Automatic 3-spd
# 1        Automatic 3-spd
# 2        Automatic 3-spd
# 3        Automatic 3-spd
# 4        Automatic 4-spd
#               ...
# 35947          Auto(AM5)
# 35948          Auto(AM5)
# 35949          Auto(AM5)
# 35950          Auto(AM6)
# 35951       Manual 5-spd
# Name: Transmission, Length: 35952, dtype: object

# %%
# Retrieve row 7-18 from column 4 
data.iloc[7:18, 4]
# Out:
# 7     Automatic 4-spd
# 8     Automatic 4-spd
# 9        Manual 5-spd
# 10    Automatic 4-spd
# 11    Automatic 4-spd
# 12       Manual 5-spd
# 13    Automatic 4-spd
# 14    Automatic 4-spd
# 15    Automatic 4-spd
# 16    Automatic 4-spd
# 17    Automatic 4-spd
# Name: Transmission, dtype: object

# %%
# Retrieve row 7-18 from column 4 
data.iloc[7:18, [4]]
# Out:
#        Transmission
# 7   Automatic 4-spd
# 8   Automatic 4-spd
# 9      Manual 5-spd
# 10  Automatic 4-spd
# 11  Automatic 4-spd
# 12     Manual 5-spd
# 13  Automatic 4-spd
# 14  Automatic 4-spd
# 15  Automatic 4-spd
# 16  Automatic 4-spd
# 17  Automatic 4-spd

# %%
# Retrieve row 7-18 from columns 4, 8 and 2 
data.iloc[291:300, [4,8,2]]
# Out:
#         Transmission  Engine Displacement      Model
# 291     Manual 6-spd                  2.4        TSX
# 292   Automatic (S5)                  3.5        TSX
# 293   Automatic (S5)                  2.4  TSX Wagon
# 294   Automatic (S5)                  2.4  TSX Wagon
# 295   Automatic (S5)                  2.4  TSX Wagon
# 296   Automatic (S5)                  2.4  TSX Wagon
# 297  Automatic 4-spd                  2.5      Vigor
# 298     Manual 5-spd                  2.5      Vigor
# 299  Automatic 4-spd                  2.5      Vigor

# %% [markdown]
# ## Summary

# %% [markdown]
# In this lesson, we learned a variety of ways to manipulate data frames. We started by covering how to change the names of a data frame's columns and the order in which those columns appear. After that, we looked at how we could easily obtain useful "meta-data" about the data frame as a whole. At the end of this lesson, we looked at the .loc and .iloc methods.

# %% [markdown]
# In the following lesson, we will look at more advanced data frame operations.
