# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources in the README.md file
# - Happy learning!

# %%
#Import your libraries
import pandas as pd
import numpy as np
import datetime
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Challenge 1 - Import and Describe the Dataset

# %% [markdown]
# #### In this challenge we will use the `austin_weather` data.
#
# #### First, import it into a data frame called `austin`. You can find the data [here](https://drive.google.com/file/d/1dJEvgjTYxd4JCGQ9Zki_irzilkuMFq9p/view?usp=sharing). Please download them and place them in the local data folder

# %%
# Your code here
austin = pd.read_csv('../data/austin_weather.csv')

# %% [markdown]
# #### Next, describe the dataset you have loaded:
# - Look at the variables and their types
# - Examine the descriptive statistics of the numeric variables
# - Look at the first five rows of all variables to evaluate the categorical variables as well

# %%
# Your code here
austin.dtypes
# Out:
# Date                          object
# TempHighF                      int64
# TempAvgF                       int64
# TempLowF                       int64
# DewPointHighF                 object
# DewPointAvgF                  object
# DewPointLowF                  object
# HumidityHighPercent           object
# HumidityAvgPercent            object
# HumidityLowPercent            object
# SeaLevelPressureHighInches    object
# SeaLevelPressureAvgInches     object
# SeaLevelPressureLowInches     object
# VisibilityHighMiles           object
# VisibilityAvgMiles            object
# VisibilityLowMiles            object
# WindHighMPH                   object
# WindAvgMPH                    object
# WindGustMPH                   object
# PrecipitationSumInches        object
# Events                        object
# dtype: object

# %%
austin.describe().T
# Out:
#             count       mean        std   min   25%   50%   75%    max
# TempHighF  1319.0  80.862775  14.766523  32.0  72.0  83.0  92.0  107.0
# TempAvgF   1319.0  70.642911  14.045904  29.0  62.0  73.0  83.0   93.0
# TempLowF   1319.0  59.902957  14.190648  19.0  49.0  63.0  73.0   81.0

# %%
# Your code here
austin.head(5)
# Out:
#          Date  TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF  \
# 0  2013-12-21         74        60        45            67           49
# 1  2013-12-22         56        48        39            43           36
# 2  2013-12-23         58        45        32            31           27
# 3  2013-12-24         61        46        31            36           28
# 4  2013-12-25         58        50        41            44           40
#
#   DewPointLowF HumidityHighPercent HumidityAvgPercent HumidityLowPercent  \
# 0           43                  93                 75                 57
# 1           28                  93                 68                 43
# 2           23                  76                 52                 27
# 3           21                  89                 56                 22
# 4           36                  86                 71                 56
#
#   SeaLevelPressureHighInches SeaLevelPressureAvgInches  \
# 0                      29.86                     29.68
# 1                      30.41                     30.13
# 2                      30.56                     30.49
# 3                      30.56                     30.45
# 4                      30.41                     30.33
#
#   SeaLevelPressureLowInches VisibilityHighMiles VisibilityAvgMiles  \
# 0                     29.59                  10                  7
# 1                     29.87                  10                 10
# 2                     30.41                  10                 10
# 3                      30.3                  10                 10
# 4                     30.27                  10                 10
#
#   VisibilityLowMiles WindHighMPH WindAvgMPH WindGustMPH  \
# 0                  2          20          4          31
# 1                  5          16          6          25
# 2                 10           8          3          12
# 3                  7          12          4          20
# 4                  7          10          2          16
#
#   PrecipitationSumInches               Events
# 0                   0.46  Rain , Thunderstorm
# 1                      0
# 2                      0
# 3                      0
# 4                      T

# %% [markdown]
# #### Given the information you have learned from examining the dataset, write down three insights about the data in a markdown cell below

# %% [markdown]
# #### Insight example:
#
# There are 21 variables in the dataset. 3 of them are numeric and the rest contain some text.<br>
#
# #### Your insights
# 1 .
# 2.
# 3.

# %% [markdown]
# #### Let's examine the DewPointAvgF variable by using the `unique()` function to list all unique values in this dataframe.
#
# Describe what you find in a markdown cell below the code. What did you notice? What do you think made Pandas to treat this column as *object* instead of *int64*?

# %%
# Your code here
austin['DewPointAvgF'].unique()
# Out:
# array(['49', '36', '27', '28', '40', '39', '41', '26', '42', '22', '48',
#        '32', '8', '11', '45', '55', '61', '37', '47', '25', '23', '20',
#        '33', '30', '29', '17', '14', '13', '54', '59', '15', '24', '34',
#        '35', '57', '50', '53', '60', '46', '56', '51', '31', '38', '62',
#        '43', '63', '64', '67', '66', '58', '70', '68', '65', '69', '71',
#        '72', '-', '73', '74', '21', '44', '52', '12', '75', '76', '18'],
#       dtype=object)

# %%
# Your observation here
#Next to the numbers there are "-" dashes in the data which causes the astype function to fail.

# %% [markdown]
# The following is a list of columns misrepresented as `object`. Use this list to convert the columns to numeric using the `pandas.to_numeric` function in the next cell. If you encounter errors in converting strings to numeric values, you need to catch those errors and force the conversion by supplying `errors='coerce'` as an argument for `pandas.to_numeric`. Coercing will replace non-convertable elements with `NaN` which represents an undefined numeric value. This makes it possible for us to conveniently handle missing values in subsequent data processing.
#
# *Hint: you may use a loop to change one column at a time but it is more efficient to use `apply`.*

# %%
wrong_type_columns = ['DewPointHighF', 'DewPointAvgF', 'DewPointLowF', 'HumidityHighPercent', 
                      'HumidityAvgPercent', 'HumidityLowPercent', 'SeaLevelPressureHighInches', 
                      'SeaLevelPressureAvgInches' ,'SeaLevelPressureLowInches', 'VisibilityHighMiles',
                      'VisibilityAvgMiles', 'VisibilityLowMiles', 'WindHighMPH', 'WindAvgMPH', 
                      'WindGustMPH', 'PrecipitationSumInches']

# %%
austin[wrong_type_columns] = austin[wrong_type_columns].apply(pd.to_numeric,errors='coerce')

# %% [markdown]
# #### Check if your code has worked by printing the data types again. You should see only two `object` columns (`Date` and `Events`) now. All other columns should be `int64` or `float64`.

# %%
# Your code here
austin.dtypes
# Out:
# Date                           object
# TempHighF                       int64
# TempAvgF                        int64
# TempLowF                        int64
# DewPointHighF                 float64
# DewPointAvgF                  float64
# DewPointLowF                  float64
# HumidityHighPercent           float64
# HumidityAvgPercent            float64
# HumidityLowPercent            float64
# SeaLevelPressureHighInches    float64
# SeaLevelPressureAvgInches     float64
# SeaLevelPressureLowInches     float64
# VisibilityHighMiles           float64
# VisibilityAvgMiles            float64
# VisibilityLowMiles            float64
# WindHighMPH                   float64
# WindAvgMPH                    float64
# WindGustMPH                   float64
# PrecipitationSumInches        float64
# Events                         object
# dtype: object

# %% [markdown]
# # Challenge 2 - Handle the Missing Data

# %% [markdown]
# #### Now that we have fixed the type mismatch, let's address the missing data.
#
# By coercing the columns to numeric, we have created `NaN` for each cell containing characters. We should choose a strategy to address these missing data.
#
# The first step is to examine how many rows contain missing data.
#
# We check how much missing data we have by applying the `.isnull()` function to our dataset. To find the rows with missing data in any of its cells, we apply `.any(axis=1)` to the function. `austin.isnull().any(axis=1)` will return a column containing true if the row contains at least one missing value and false otherwise. Therefore we must subset our dataframe with this column. This will give us all rows with at least one missing value.
#
# #### In the next cell, identify all rows containing at least one missing value. Assign the dataframes with missing values to a variable called `missing_values`.

# %%
# Your code here
missing_values = austin.loc[austin.isnull().any(axis=1)]

# %% [markdown]
# There are multiple strategies to handle missing data. Below lists the most common ones data scientists use:
#
# * Removing all rows or all columns containing missing data. This is the simplest strategy. It may work in some cases but not others.
#
# * Filling all missing values with a placeholder value.
#     * For categorical data, `0`, `-1`, and `9999` are some commonly used placeholder values.
#     * For continuous data, some may opt to fill all missing data with the mean. This strategy is not optimal since it can increase the fit of the model.
#
# * Filling the values using some algorithm.
#
# #### In our case, we will use a hybrid approach which is to first remove the data that contain most missing values then fill in the rest of the missing values with the *linear interpolation* algorithm.

# %% [markdown]
# #### Next, count the number of rows of `austin` and `missing_values`.

# %%
# Your code here
print('Normal data set contains {0} rows and we have {1} rows with missing data'.format(len(austin),len(missing_values)))
# Out:
# Normal data set contains 1319 rows and we have 136 rows with missing data

# %% [markdown]
# #### Calculate the ratio of missing rows to total rows

# %%
# Your code here
print('{0:.2f}% of the rows have missing data'.format(
    (len(missing_values) / len(austin))*100))
# Out:
# 10.31% of the rows have missing data

# %% [markdown]
# As you can see, there is a large proportion of missing data (over 10%). Perhaps we should evaluate which columns have the most missing data and remove those columns. For the remaining columns, we will perform a linear approximation of the missing data.
#
# We can find the number of missing rows in each column using the `.isna()` function. We then chain the `.sum` function to the `.isna()` function and find the number of missing rows per column

# %%
# Your code here
austin.isna().sum(0) / len(austin) * 100
# Out:
# Date                          0.000000
# TempHighF                     0.000000
# TempAvgF                      0.000000
# TempLowF                      0.000000
# DewPointHighF                 0.530705
# DewPointAvgF                  0.530705
# DewPointLowF                  0.530705
# HumidityHighPercent           0.151630
# HumidityAvgPercent            0.151630
# HumidityLowPercent            0.151630
# SeaLevelPressureHighInches    0.227445
# SeaLevelPressureAvgInches     0.227445
# SeaLevelPressureLowInches     0.227445
# VisibilityHighMiles           0.909780
# VisibilityAvgMiles            0.909780
# VisibilityLowMiles            0.909780
# WindHighMPH                   0.151630
# WindAvgMPH                    0.151630
# WindGustMPH                   0.303260
# PrecipitationSumInches        9.401061
# Events                        0.000000
# dtype: float64

# %% [markdown]
# #### As you can see from the output, the majority of missing data is in one column called `PrecipitationSumInches`. What's the number of missing values in this column in ratio to its total number of rows?

# %%
# Your code here
print('In the field PrecipitationSumInches we miss {0} values which is about {1:.2f}% for the total'.format(
                  austin.PrecipitationSumInches.isna().sum(), 
                  (austin.PrecipitationSumInches.isna().sum() / len(austin))*100))
# Out:
# In the field PrecipitationSumInches we miss 124 values which is about 9.40% for the total

# %% [markdown]
# Over 10% data missing! Therefore, we prefer to remove this column instead of filling its missing values. It doesn't make sense to *guess* its missing values because the estimation will be too
#
# #### Remove this column from `austin` using the `.drop()` function. Use the `inplace=True` argument.
#
# *Hints:*
#
# * By supplying `inplace=True` to `drop()`, the original dataframe object will be changed in place and the function will return `None`. In contrast, if you don't supply `inplace=True`, which is equivalent to supplying `inplace=False` because `False` is the default value, the original dataframe object will be kept and the function returns a copy of the transformed dataframe object. In the latter case, you'll have to assign the returned object back to your variable.
#
# * Also, since you are dropping a column instead of a row, you'll need to supply `axis=1` to `drop()`.
#
# [Reference for `pandas.DataFrame.drop`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.drop.html)

# %%
# Your code here 
austin = austin.drop(columns = 'PrecipitationSumInches')


# Print `austin` to confirm the column is indeed removed

austin.columns
# Out:
# Index(['Date', 'TempHighF', 'TempAvgF', 'TempLowF', 'DewPointHighF',
#        'DewPointAvgF', 'DewPointLowF', 'HumidityHighPercent',
#        'HumidityAvgPercent', 'HumidityLowPercent',
#        'SeaLevelPressureHighInches', 'SeaLevelPressureAvgInches',
#        'SeaLevelPressureLowInches', 'VisibilityHighMiles',
#        'VisibilityAvgMiles', 'VisibilityLowMiles', 'WindHighMPH', 'WindAvgMPH',
#        'WindGustMPH', 'Events'],
#       dtype='object')

# %% [markdown]
# #### Next we will perform linear interpolation of the missing data.
#
# This means that we will use a linear algorithm to estimate the missing data. Linear interpolation assumes that there is a straight line between the points and the missing point will fall on that line. This is a good enough approximation for weather related data. Weather related data is typically a time series. Therefore, we do not want to drop rows from our data if possible. It is prefereable to estimate the missing values rather than remove the rows. However, if you have data from a single point in time, perhaps a better solution would be to remove the rows.
#
# If you would like to read more about linear interpolation, you can do so [here](https://en.wikipedia.org/wiki/Linear_interpolation).
#
# In the following cell, use the `.interpolate()` function on the entire dataframe. This time pass the `inplace=False` argument to the function and assign the interpolated dataframe to a new variable called `austin_fixed` so that we can compare with `austin`.

# %%
# Your code here
austin_fixed = austin.interpolate(inplace=False)

# %% [markdown]
# #### Check to make sure `austin_fixed` contains no missing data. Also check `austin` - it still contains missing data.

# %%
# Your code here
austin_fixed.isna().sum()
# Out:
# Date                          0
# TempHighF                     0
# TempAvgF                      0
# TempLowF                      0
# DewPointHighF                 0
# DewPointAvgF                  0
# DewPointLowF                  0
# HumidityHighPercent           0
# HumidityAvgPercent            0
# HumidityLowPercent            0
# SeaLevelPressureHighInches    0
# SeaLevelPressureAvgInches     0
# SeaLevelPressureLowInches     0
# VisibilityHighMiles           0
# VisibilityAvgMiles            0
# VisibilityLowMiles            0
# WindHighMPH                   0
# WindAvgMPH                    0
# WindGustMPH                   0
# Events                        0
# dtype: int64

# %% [markdown]
# # Challenge 3 - Processing the `Events` Column

# %% [markdown]
# #### Our dataframe contains one true text column - the Events column. We should evaluate this column to determine how to process it.
#
# Use the `value_counts()` function to evaluate the contents of this column

# %%
# Your code here:
austin['Events'].value_counts()
# Out:
#                              903
# Rain                         192
# Rain , Thunderstorm          137
# Fog , Rain , Thunderstorm     33
# Fog                           21
# Thunderstorm                  17
# Fog , Rain                    14
# Fog , Thunderstorm             1
# Rain , Snow                    1
# Name: Events, dtype: int64

# %% [markdown]
# Reading the values of `Events` and reflecting what those values mean in the context of data, you realize this column indicates what weather events had happened in a particular day.
#
# #### What is the largest number of events happened in a single day? Enter your answer in the next cell.

# %%
print('Largest number of events in a singled day is {0}'.format(
    max(austin['Events'].apply(lambda x: len(str(x).split(','))))))
# Out:
# Largest number of events in a singled day is 3

# %% [markdown]
# #### We want to transform the string-type `Events` values to the numbers. This will allow us to apply machine learning algorithms easily.
#
# How? We will create a new column for each type of events (i.e. *Rain*, *Snow*, *Fog*, *Thunderstorm*. In each column, we use `1` to indicate if the corresponding event happened in that day and use `0` otherwise.
#
# Below we provide you a list of all event types. Loop the list and create a dummy column with `0` values for each event in `austin_fixed`. To create a new dummy column with `0` values, simply use `austin_fixed[event] = 0`.

# %%
event_list = ['Snow', 'Fog', 'Rain', 'Thunderstorm']

# Your code here

for event in event_list:
    austin_fixed[event] = 0
# Print your new dataframe to check whether new columns have been created:
austin_fixed.head().T
# Out:
#                                               0           1           2  \
# Date                                 2013-12-21  2013-12-22  2013-12-23
# TempHighF                                    74          56          58
# TempAvgF                                     60          48          45
# TempLowF                                     45          39          32
# DewPointHighF                                67          43          31
# DewPointAvgF                                 49          36          27
# DewPointLowF                                 43          28          23
# HumidityHighPercent                          93          93          76
# HumidityAvgPercent                           75          68          52
# HumidityLowPercent                           57          43          27
# SeaLevelPressureHighInches                29.86       30.41       30.56
# SeaLevelPressureAvgInches                 29.68       30.13       30.49
# SeaLevelPressureLowInches                 29.59       29.87       30.41
# VisibilityHighMiles                          10          10          10
# VisibilityAvgMiles                            7          10          10
# VisibilityLowMiles                            2           5          10
# WindHighMPH                                  20          16           8
# WindAvgMPH                                    4           6           3
# WindGustMPH                                  31          25          12
# Events                      Rain , Thunderstorm
# Snow                                          0           0           0
# Fog                                           0           0           0
# Rain                                          0           0           0
# Thunderstorm                                  0           0           0
#
#                                      3           4
# Date                        2013-12-24  2013-12-25
# TempHighF                           61          58
# TempAvgF                            46          50
# TempLowF                            31          41
# DewPointHighF                       36          44
# DewPointAvgF                        28          40
# DewPointLowF                        21          36
# HumidityHighPercent                 89          86
# HumidityAvgPercent                  56          71
# HumidityLowPercent                  22          56
# SeaLevelPressureHighInches       30.56       30.41
# SeaLevelPressureAvgInches        30.45       30.33
# SeaLevelPressureLowInches         30.3       30.27
# VisibilityHighMiles                 10          10
# VisibilityAvgMiles                  10          10
# VisibilityLowMiles                   7           7
# WindHighMPH                         12          10
# WindAvgMPH                           4           2
# WindGustMPH                         20          16
# Events
# Snow                                 0           0
# Fog                                  0           0
# Rain                                 0           0
# Thunderstorm                         0           0

# %% [markdown]
# #### Next, populate the actual values in the dummy columns of  `austin_fixed`.
#
# You will check the *Events* column. If its string value contains `Rain`, then the *Rain* column should be `1`. The same for `Snow`, `Fog`, and `Thunderstorm`.
#
# *Hints:*
#
# * Use [`pandas.Series.str.contains()`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.str.contains.html) to create the value series of each new column.
#
# * What if the values you populated are booleans instead of numbers? You can cast the boolean values to numbers by using `.astype(int)`. For instance, `pd.Series([True, True, False]).astype(int)` will return a new series with values of `[1, 1, 0]`.

# %%
# Your code here
for event in event_list:
    austin_fixed[event] = austin_fixed['Events'].str.contains(event).astype(int)

# %% [markdown]
# #### Print out `austin_fixed` to check if the event columns are populated with the intended values

# %%
# Your code here
austin_fixed.T
# Out:
#                                            0           1           2     \
# Date                                 2013-12-21  2013-12-22  2013-12-23
# TempHighF                                    74          56          58
# TempAvgF                                     60          48          45
# TempLowF                                     45          39          32
# DewPointHighF                                67          43          31
# DewPointAvgF                                 49          36          27
# DewPointLowF                                 43          28          23
# HumidityHighPercent                          93          93          76
# HumidityAvgPercent                           75          68          52
# HumidityLowPercent                           57          43          27
# SeaLevelPressureHighInches                29.86       30.41       30.56
# SeaLevelPressureAvgInches                 29.68       30.13       30.49
# SeaLevelPressureLowInches                 29.59       29.87       30.41
# VisibilityHighMiles                          10          10          10
# VisibilityAvgMiles                            7          10          10
# VisibilityLowMiles                            2           5          10
# WindHighMPH                                  20          16           8
# WindAvgMPH                                    4           6           3
# WindGustMPH                                  31          25          12
# Events                      Rain , Thunderstorm
# Snow                                          0           0           0
# Fog                                           0           0           0
# Rain                                          1           0           0
# Thunderstorm                                  1           0           0
#
#                                   3           4           5           6     \
# Date                        2013-12-24  2013-12-25  2013-12-26  2013-12-27
# TempHighF                           61          58          57          60
# TempAvgF                            46          50          48          53
# TempLowF                            31          41          39          45
# DewPointHighF                       36          44          39          41
# DewPointAvgF                        28          40          36          39
# DewPointLowF                        21          36          33          37
# HumidityHighPercent                 89          86          79          83
# HumidityAvgPercent                  56          71          63          65
# HumidityLowPercent                  22          56          47          47
# SeaLevelPressureHighInches       30.56       30.41       30.47       30.46
# SeaLevelPressureAvgInches        30.45       30.33        30.4       30.39
# SeaLevelPressureLowInches         30.3       30.27       30.34       30.34
# VisibilityHighMiles                 10          10          10          10
# VisibilityAvgMiles                  10          10           9           9
# VisibilityLowMiles                   7           7           7           7
# WindHighMPH                         12          10          12           7
# WindAvgMPH                           4           2           3           1
# WindGustMPH                         20          16          17          11
# Events
# Snow                                 0           0           0           0
# Fog                                  0           0           0           0
# Rain                                 0           0           0           0
# Thunderstorm                         0           0           0           0
#
#                                   7           8           9           10    \
# Date                        2013-12-28  2013-12-29  2013-12-30  2013-12-31
# TempHighF                           62          64          44          55
# TempAvgF                            51          50          40          46
# TempLowF                            40          36          35          36
# DewPointHighF                       43          49          31          31
# DewPointAvgF                        39          41          26          28
# DewPointLowF                        33          28          21          23
# HumidityHighPercent                 92          92          75          76
# HumidityAvgPercent                  64          76          60          54
# HumidityLowPercent                  36          60          45          32
# SeaLevelPressureHighInches       30.33       30.31       30.44       30.49
# SeaLevelPressureAvgInches        30.17        30.1       30.33       30.39
# SeaLevelPressureLowInches        30.04       29.99       30.26       30.27
# VisibilityHighMiles                 10          10          10          10
# VisibilityAvgMiles                  10          10          10          10
# VisibilityLowMiles                   7           4          10          10
# WindHighMPH                         10          17          13           8
# WindAvgMPH                           2           5           5           1
# WindGustMPH                         14          24          21          12
# Events
# Snow                                 0           0           0           0
# Fog                                  0           0           0           0
# Rain                                 0           0           0           0
# Thunderstorm                         0           0           0           0
#
#                                   11          12          13          14    \
# Date                        2014-01-01  2014-01-02  2014-01-03  2014-01-04
# TempHighF                           69          55          58          71
# TempAvgF                            54          44          43          57
# TempLowF                            39          33          28          42
# DewPointHighF                       51          39          37          55
# DewPointAvgF                        42          26          22          48
# DewPointLowF                        30          19          18          38
# HumidityHighPercent                 83          83          75          89
# HumidityAvgPercent                  68          55          49          68
# HumidityLowPercent                  52          26          22          47
# SeaLevelPressureHighInches       30.25       30.49       30.48       30.12
# SeaLevelPressureAvgInches        30.11       30.37       30.35       29.95
# SeaLevelPressureLowInches        30.01       30.15       30.14       29.81
# VisibilityHighMiles                 10          10          10          10
# VisibilityAvgMiles                  10          10          10          10
# VisibilityLowMiles                   8           9          10           8
# WindHighMPH                         13          21          14          16
# WindAvgMPH                           4           8           4           7
# WindGustMPH                         22          31          21          28
# Events
# Snow                                 0           0           0           0
# Fog                                  0           0           0           0
# Rain                                 0           0           0           0
# Thunderstorm                         0           0           0           0
#
#                                   15          16          17          18    \
# Date                        2014-01-05  2014-01-06  2014-01-07  2014-01-08
# TempHighF                           59          36          48          53
# TempAvgF                            47          29          35          47
# TempLowF                            34          22          22          40
# DewPointHighF                       54          15          29          51
# DewPointAvgF                        32           8          11          45
# DewPointLowF                        15           2           4          30
# HumidityHighPercent                 87          50          68          93
# HumidityAvgPercent                  59          38          43          75
# HumidityLowPercent                  31          26          17          57
# SeaLevelPressureHighInches       30.48        30.8       30.66       30.33
# SeaLevelPressureAvgInches        30.08       30.68       30.52        30.2
# SeaLevelPressureLowInches        29.79        30.5       30.36       30.12
# VisibilityHighMiles                 10          10          10          10
# VisibilityAvgMiles                  10          10          10           2
# VisibilityLowMiles                   4          10          10           1
# WindHighMPH                         21          17          13          12
# WindAvgMPH                          10           7           5           1
# WindGustMPH                         34          27          22          18
# Events                                                                Rain
# Snow                                 0           0           0           0
# Fog                                  0           0           0           0
# Rain                                 0           0           0           1
# Thunderstorm                         0           0           0           0
#
#                                   19          20          21          22    \
# Date                        2014-01-09  2014-01-10  2014-01-11  2014-01-12
# TempHighF                           70          72          75          67
# TempAvgF                            62          65          62          57
# TempLowF                            53          57          48          46
# DewPointHighF                       60          64          54          58
# DewPointAvgF                        55          61          37          47
# DewPointLowF                        50          54          20          33
# HumidityHighPercent                 93          93          93          84
# HumidityAvgPercent                  80          81          53          68
# HumidityLowPercent                  66          68          13          52
# SeaLevelPressureHighInches       30.18       29.97       30.16       30.12
# SeaLevelPressureAvgInches        30.11       29.87       30.06       30.01
# SeaLevelPressureLowInches           30       29.75       29.87        29.9
# VisibilityHighMiles                 10          10          10          10
# VisibilityAvgMiles                   4           8           9          10
# VisibilityLowMiles                   0           1           5          10
# WindHighMPH                         12          13          12          15
# WindAvgMPH                           3           6           3           4
# WindGustMPH                         19          21          19          24
# Events                             Fog        Rain                    Rain
# Snow                                 0           0           0           0
# Fog                                  1           0           0           0
# Rain                                 0           1           0           1
# Thunderstorm                         0           0           0           0
#
#                                   23          24          25          26    \
# Date                        2014-01-13  2014-01-14  2014-01-15  2014-01-16
# TempHighF                           71          76          64          72
# TempAvgF                            57          57          52          56
# TempLowF                            43          37          40          40
# DewPointHighF                       60          31          29          31
# DewPointAvgF                        36          25          23          27
# DewPointLowF                        17          20          16          23
# HumidityHighPercent                 87          70          49          55
# HumidityAvgPercent                  51          41          35          38
# HumidityLowPercent                  14          12          21          20
# SeaLevelPressureHighInches       30.16       30.34       30.47       30.21
# SeaLevelPressureAvgInches        30.01       30.13       30.33       30.13
# SeaLevelPressureLowInches        29.86       30.01       30.17       30.06
# VisibilityHighMiles                 10          10          10          10
# VisibilityAvgMiles                   9          10          10          10
# VisibilityLowMiles                   7          10          10          10
# WindHighMPH                         17          16          14          14
# WindAvgMPH                           7           5           4           4
# WindGustMPH                         29          29          21          20
# Events
# Snow                                 0           0           0           0
# Fog                                  0           0           0           0
# Rain                                 0           0           0           0
# Thunderstorm                         0           0           0           0
#
#                                   27          28          29          30    \
# Date                        2014-01-17  2014-01-18  2014-01-19  2014-01-20
# TempHighF                           64          70          72          82
# TempAvgF                            54          54          59          64
# TempLowF                            43          37          45          46
# DewPointHighF                       31          41          41          51
# DewPointAvgF                        20          33          30          36
# DewPointLowF                        15          23          18          23
# HumidityHighPercent                 45          59          64          71
# HumidityAvgPercent                  31          45          39          44
# HumidityLowPercent                  17          31          14          17
# SeaLevelPressureHighInches       30.37       30.26       30.35       30.16
# SeaLevelPressureAvgInches        30.29       30.19       30.22          30
# SeaLevelPressureLowInches        30.21        30.1       30.12       29.85
# VisibilityHighMiles                 10          10          10          10
# VisibilityAvgMiles                  10          10          10          10
# VisibilityLowMiles                   9          10          10          10
# WindHighMPH                         14          12           9          16
# WindAvgMPH                           5           2           3           5
# WindGustMPH                         21          19          16          26
# Events
# Snow                                 0           0           0           0
# Fog                                  0           0           0           0
# Rain                                 0           0           0           0
# Thunderstorm                         0           0           0           0
#
#                                   31          32           33          34    \
# Date                        2014-01-21  2014-01-22   2014-01-23  2014-01-24
# TempHighF                           63          70           56          40
# TempAvgF                            51          54           42          33
# TempLowF                            38          37           27          26
# DewPointHighF                       28          39           42          22
# DewPointAvgF                        23          27           29          17
# DewPointLowF                        19          24           20          10
# HumidityHighPercent                 59          70           78          81
# HumidityAvgPercent                  39          45           64          60
# HumidityLowPercent                  19          19           50          39
# SeaLevelPressureHighInches       30.43       30.23        30.73       30.76
# SeaLevelPressureAvgInches        30.31       30.11        30.47       30.63
# SeaLevelPressureLowInches        30.19       30.01        30.06        30.4
# VisibilityHighMiles                 10          10           10          10
# VisibilityAvgMiles                  10          10            8           9
# VisibilityLowMiles                  10          10            2           3
# WindHighMPH                         15          12           20          16
# WindAvgMPH                           6           4            9           5
# WindGustMPH                         25          18           31          24
# Events                                              Rain , Snow
# Snow                                 0           0            1           0
# Fog                                  0           0            0           0
# Rain                                 0           0            1           0
# Thunderstorm                         0           0            0           0
#
#                                   35          36          37          38    \
# Date                        2014-01-25  2014-01-26  2014-01-27  2014-01-28
# TempHighF                           70          76          60          39
# TempAvgF                            48          60          47          33
# TempLowF                            26          43          34          27
# DewPointHighF                       38          45          43          19
# DewPointAvgF                        27          39          23          14
# DewPointLowF                        22          33           5           7
# HumidityHighPercent                 85          76          66          69
# HumidityAvgPercent                  53          52          44          48
# HumidityLowPercent                  20          27          21          27
# SeaLevelPressureHighInches       30.38          30       30.28       30.51
# SeaLevelPressureAvgInches        30.19       29.84       30.09        30.4
# SeaLevelPressureLowInches        30.02       29.69       29.81       30.27
# VisibilityHighMiles                 10          10          10          10
# VisibilityAvgMiles                  10          10          10          10
# VisibilityLowMiles                   8          10          10          10
# WindHighMPH                          8          12          21          15
# WindAvgMPH                           1           3           9           6
# WindGustMPH                         14          20          32          23
# Events                                                    Rain        Rain
# Snow                                 0           0           0           0
# Fog                                  0           0           0           0
# Rain                                 0           0           1           1
# Thunderstorm                         0           0           0           0
#
#                                   39          40          41          42    \
# Date                        2014-01-29  2014-01-30  2014-01-31  2014-02-01
# TempHighF                           49          65          80          76
# TempAvgF                            38          48          68          66
# TempLowF                            27          31          55          55
# DewPointHighF                       19          51          59          62
# DewPointAvgF                        13          36          54          59
# DewPointLowF                         9          20          51          41
# HumidityHighPercent                 63          80          86          81
# HumidityAvgPercent                  42          64          64          71
# HumidityLowPercent                  21          48          42          60
# SeaLevelPressureHighInches       30.52       30.26       29.96       29.91
# SeaLevelPressureAvgInches        30.41       30.06       29.87       29.81
# SeaLevelPressureLowInches        30.29        29.9       29.79       29.75
# VisibilityHighMiles                 10          10          10          10
# VisibilityAvgMiles                  10          10          10          10
# VisibilityLowMiles                  10          10           9           9
# WindHighMPH                         15          15          14          14
# WindAvgMPH                           5           7           9           6
# WindGustMPH                         23          27          25          26
# Events                                                                Rain
# Snow                                 0           0           0           0
# Fog                                  0           0           0           0
# Rain                                 0           0           0           1
# Thunderstorm                         0           0           0           0
#
#                                   43          44          45          46    \
# Date                        2014-02-02  2014-02-03  2014-02-04  2014-02-05
# TempHighF                           55          46          64          48
# TempAvgF                            45          40          53          40
# TempLowF                            35          34          42          31
# DewPointHighF                       40          38          45          42
# DewPointAvgF                        33          33          41          26
# DewPointLowF                        27          28          39          16
# HumidityHighPercent                 79          82          89          80
# HumidityAvgPercent                  69          74          68          60
# HumidityLowPercent                  59          65          46          39
# SeaLevelPressureHighInches       30.27       30.28       30.11        30.5
# SeaLevelPressureAvgInches        30.09       30.17       29.95       30.37
# SeaLevelPressureLowInches         29.9       29.98       29.87       30.13
# VisibilityHighMiles                 10          10          10          10
# VisibilityAvgMiles                   8           6           6          10
# VisibilityLowMiles                   4           3           2          10
# WindHighMPH                         18          13          10          16
# WindAvgMPH                          11           6           2          10
# WindGustMPH                         29          17          18          24
# Events                            Rain                    Rain
# Snow                                 0           0           0           0
# Fog                                  0           0           0           0
# Rain                                 1           0           1           0
# Thunderstorm                         0           0           0           0
#
#                                   47          48          49          50    \
# Date                        2014-02-06  2014-02-07  2014-02-08  2014-02-09
# TempHighF                           32          38          65          76
# TempAvgF                            29          34          51          59
# TempLowF                            26          29          37          41
# DewPointHighF                       17          29          42          53
# DewPointAvgF                        15          24          36          45
# DewPointLowF                        13          17          29          38
# HumidityHighPercent                 58          78          85          96
# HumidityAvgPercent                  54          68          63          70
# HumidityLowPercent                  49          58          40          44
# SeaLevelPressureHighInches       30.57       30.41       30.26       30.12
# SeaLevelPressureAvgInches        30.48       30.32       30.17       30.05
# SeaLevelPressureLowInches        30.42       30.24       30.03       29.93
# VisibilityHighMiles                 10          10          10          10
# VisibilityAvgMiles                  10           7           7           5
# VisibilityLowMiles                  10           2           3           0
# WindHighMPH                         15           8          14          13
# WindAvgMPH                           8           3           5           4
# WindGustMPH                         23          12          21          20
# Events                                                                 Fog
# Snow                                 0           0           0           0
# Fog                                  0           0           0           1
# Rain                                 0           0           0           0
# Thunderstorm                         0           0           0           0
#
#                                   51          52          53          54    \
# Date                        2014-02-10  2014-02-11  2014-02-12  2014-02-13
# TempHighF                           60          36          57          69
# TempAvgF                            48          35          45          51
# TempLowF                            35          33          33          32
# DewPointHighF                       49          31          34          38
# DewPointAvgF                        36          29          29          34
# DewPointLowF                        30          27          27          28
# HumidityHighPercent                 82          89          75          85
# HumidityAvgPercent                  74          80          57          58
# HumidityLowPercent                  66          70          38          30
# SeaLevelPressureHighInches       30.23        30.3       30.27       30.11
# SeaLevelPressureAvgInches        30.15       30.24       30.18       30.02
# SeaLevelPressureLowInches        30.02       30.19       30.08       29.93
# VisibilityHighMiles                 10           9          10          10
# VisibilityAvgMiles                   8           5           9          10
# VisibilityLowMiles                   4           1           7          10
# WindHighMPH                         15          15          14          10
# WindAvgMPH                           9           9           5           4
# WindGustMPH                         23          23          22          19
# Events                            Rain        Rain
# Snow                                 0           0           0           0
# Fog                                  0           0           0           0
# Rain                                 1           1           0           0
# Thunderstorm                         0           0           0           0
#
#                                   55          56          57          58    \
# Date                        2014-02-14  2014-02-15  2014-02-16  2014-02-17
# TempHighF                           86          76          76          81
# TempAvgF                            67          59          68          70
# TempLowF                            47          42          59          58
# DewPointHighF                       48          52          61          62
# DewPointAvgF                        37          35          57          50
# DewPointLowF                        22          22          53          29
# HumidityHighPercent                 86          64          90          87
# HumidityAvgPercent                  51          43          74          52
# HumidityLowPercent                  15          22          57          17
# SeaLevelPressureHighInches       30.08       30.17       30.08       30.12
# SeaLevelPressureAvgInches        29.93       30.09       30.01       30.03
# SeaLevelPressureLowInches        29.85       30.01       29.94       29.92
# VisibilityHighMiles                 10          10          10          10
# VisibilityAvgMiles                  10          10           5           8
# VisibilityLowMiles                   8          10           0           2
# WindHighMPH                         18          15          13          15
# WindAvgMPH                           6           5           5           5
# WindGustMPH                         30          23          23          23
# Events                                                     Fog
# Snow                                 0           0           0           0
# Fog                                  0           0           1           0
# Rain                                 0           0           0           0
# Thunderstorm                         0           0           0           0
#
#                                   59          60          61          62    \
# Date                        2014-02-18  2014-02-19  2014-02-20  2014-02-21
# TempHighF                           82          82          83          72
# TempAvgF                            69          73          70          57
# TempLowF                            55          63          57          41
# DewPointHighF                       63          62          64          33
# DewPointAvgF                        53          60          50          27
# DewPointLowF                        32          59          27          22
# HumidityHighPercent                 78          93          81          67
# HumidityAvgPercent                  55          70          48          43
# HumidityLowPercent                  32          47          15          19
# SeaLevelPressureHighInches        30.1       29.93       30.09       30.21
# SeaLevelPressureAvgInches           30       29.85       29.85       30.11
# SeaLevelPressureLowInches        29.89       29.72       29.71       30.03
# VisibilityHighMiles                 10          10          10          10
# VisibilityAvgMiles                  10           9           9          10
# VisibilityLowMiles                   9           2           7          10
# WindHighMPH                         13          15          16          14
# WindAvgMPH                           4           7           8           5
# WindGustMPH                         20          25          28          20
# Events
# Snow                                 0           0           0           0
# Fog                                  0           0           0           0
# Rain                                 0           0           0           0
# Thunderstorm                         0           0           0           0
#
#                                   63          64          65          66    \
# Date                        2014-02-22  2014-02-23  2014-02-24  2014-02-25
# TempHighF                           77          86          76          71
# TempAvgF                            63          74          66          62
# TempLowF                            48          62          55          52
# DewPointHighF                       57          61          63          65
# DewPointAvgF                        46          56          51          60
# DewPointLowF                        30          44          43          47
# HumidityHighPercent                 73          84          81          93
# HumidityAvgPercent                  53          57          65          85
# HumidityLowPercent                  32          29          49          77
# SeaLevelPressureHighInches       30.05       30.05        30.1       30.06
# SeaLevelPressureAvgInches        29.96       29.95       30.04       30.01
# SeaLevelPressureLowInches        29.87       29.88       29.99       29.95
# VisibilityHighMiles                 10          10          10          10
# VisibilityAvgMiles                  10          10           9           4
# VisibilityLowMiles                  10           7           5           1
# WindHighMPH                         14          15          12          12
# WindAvgMPH                           6           4           4           5
# WindGustMPH                         22          24          18          20
# Events                                                                Rain
# Snow                                 0           0           0           0
# Fog                                  0           0           0           0
# Rain                                 0           0           0           1
# Thunderstorm                         0           0           0           0
#
#                                   67          68          69          70    \
# Date                        2014-02-26  2014-02-27  2014-02-28  2014-03-01
# TempHighF                           52          59          80          82
# TempAvgF                            44          45          62          68
# TempLowF                            36          31          44          53
# DewPointHighF                       46          32          50          65
# DewPointAvgF                        33          27          46          57
# DewPointLowF                        21          21          35          48
# HumidityHighPercent                 83          82          83          93
# HumidityAvgPercent                  63          56          60          74
# HumidityLowPercent                  43          29          37          54
# SeaLevelPressureHighInches       30.26       30.22       29.92       30.02
# SeaLevelPressureAvgInches        30.18        30.1       29.85       29.95
# SeaLevelPressureLowInches        30.06       29.94       29.75       29.87
# VisibilityHighMiles                 10          10          10          10
# VisibilityAvgMiles                   8          10          10           7
# VisibilityLowMiles                   2          10           7           0
# WindHighMPH                         20          12          13          16
# WindAvgMPH                           8           3           6           5
# WindGustMPH                         29          17          21          27
# Events                            Rain                                 Fog
# Snow                                 0           0           0           0
# Fog                                  0           0           0           1
# Rain                                 1           0           0           0
# Thunderstorm                         0           0           0           0
#
#                                   71                   72          73    \
# Date                        2014-03-02           2014-03-03  2014-03-04
# TempHighF                           73                   47          50
# TempAvgF                            51                   36          40
# TempLowF                            28                   24          30
# DewPointHighF                       67                   27          36
# DewPointAvgF                        45                   20          31
# DewPointLowF                        20                   12          26
# HumidityHighPercent                 89                   75          92
# HumidityAvgPercent                  79                   56          72
# HumidityLowPercent                  69                   37          52
# SeaLevelPressureHighInches       30.31                30.44       30.31
# SeaLevelPressureAvgInches        30.05                30.33       30.18
# SeaLevelPressureLowInches        29.88                30.25       30.06
# VisibilityHighMiles                 10                   10          10
# VisibilityAvgMiles                   8                    9           8
# VisibilityLowMiles                   2                    4           2
# WindHighMPH                         20                   18           9
# WindAvgMPH                          10                   10           4
# WindGustMPH                         37                   29          13
# Events                            Rain  Rain , Thunderstorm        Rain
# Snow                                 0                    0           0
# Fog                                  0                    0           0
# Rain                                 1                    1           1
# Thunderstorm                         0                    1           0
#
#                                   74          75          76    \
# Date                        2014-03-05  2014-03-06  2014-03-07
# TempHighF                           53          65          67
# TempAvgF                            46          54          53
# TempLowF                            38          43          39
# DewPointHighF                       43          42          50
# DewPointAvgF                        39          38          42
# DewPointLowF                        35          35          36
# HumidityHighPercent                 86          89          86
# HumidityAvgPercent                  76          62          65
# HumidityLowPercent                  66          34          44
# SeaLevelPressureHighInches       30.18       30.28        30.1
# SeaLevelPressureAvgInches        30.06       30.18       29.99
# SeaLevelPressureLowInches        29.99       30.08       29.88
# VisibilityHighMiles                 10          10          10
# VisibilityAvgMiles                   7           8           9
# VisibilityLowMiles                   4           4           5
# WindHighMPH                         13          13          16
# WindAvgMPH                           3           4           6
# WindGustMPH                         16          20          22
# Events
# Snow                                 0           0           0
# Fog                                  0           0           0
# Rain                                 0           0           0
# Thunderstorm                         0           0           0
#
#                                            77          78          79    \
# Date                                 2014-03-08  2014-03-09  2014-03-10
# TempHighF                                    59          58          71
# TempAvgF                                     52          49          61
# TempLowF                                     44          39          50
# DewPointHighF                                57          45          56
# DewPointAvgF                                 49          39          51
# DewPointLowF                                 39          31          45
# HumidityHighPercent                          93          86          84
# HumidityAvgPercent                           88          71          69
# HumidityLowPercent                           83          55          53
# SeaLevelPressureHighInches                 30.3       30.37       30.25
# SeaLevelPressureAvgInches                 30.09       30.29       30.08
# SeaLevelPressureLowInches                  29.9       30.22       29.94
# VisibilityHighMiles                          10          10          10
# VisibilityAvgMiles                            3           9           9
# VisibilityLowMiles                            1           2           4
# WindHighMPH                                  14          15          12
# WindAvgMPH                                    4           5           3
# WindGustMPH                                  21          23          17
# Events                      Rain , Thunderstorm        Rain        Rain
# Snow                                          0           0           0
# Fog                                           0           0           0
# Rain                                          1           1           1
# Thunderstorm                                  1           0           0
#
#                                   80          81          82          83    \
# Date                        2014-03-11  2014-03-12  2014-03-13  2014-03-14
# TempHighF                           83          70          68          75
# TempAvgF                            70          60          52          62
# TempLowF                            56          49          37          49
# DewPointHighF                       56          50          40          59
# DewPointAvgF                        54          28          26          51
# DewPointLowF                        52          16          20          43
# HumidityHighPercent                 93          56          68          86
# HumidityAvgPercent                  66          36          35          68
# HumidityLowPercent                  39          16          21          49
# SeaLevelPressureHighInches       29.93        30.3       30.37       30.11
# SeaLevelPressureAvgInches        29.77       30.13       30.26       30.04
# SeaLevelPressureLowInches        29.58       29.73       30.12       29.95
# VisibilityHighMiles                 10          10          10          10
# VisibilityAvgMiles                   9          10          10          10
# VisibilityLowMiles                   4          10          10          10
# WindHighMPH                         14          24           9          13
# WindAvgMPH                           5          11           4           5
# WindGustMPH                         22          37          18          24
# Events
# Snow                                 0           0           0           0
# Fog                                  0           0           0           0
# Rain                                 0           0           0           0
# Thunderstorm                         0           0           0           0
#
#                                   84          85          86          87    \
# Date                        2014-03-15  2014-03-16  2014-03-17  2014-03-18
# TempHighF                           74          64          68          83
# TempAvgF                            68          56          55          65
# TempLowF                            62          48          41          47
# DewPointHighF                       64          58          31          56
# DewPointAvgF                        62          45          26          42
# DewPointLowF                        59          32          20          31
# HumidityHighPercent                 93          93          53          73
# HumidityAvgPercent                  81          66          36          49
# HumidityLowPercent                  68          39          18          24
# SeaLevelPressureHighInches       29.97       30.07       30.06       29.83
# SeaLevelPressureAvgInches        29.86        29.9       29.94       29.74
# SeaLevelPressureLowInches        29.68        29.7       29.78       29.67
# VisibilityHighMiles                 10          10          10          10
# VisibilityAvgMiles                   5          10          10          10
# VisibilityLowMiles                   0          10          10          10
# WindHighMPH                         12          24          16          18
# WindAvgMPH                           4          11           6           8
# WindGustMPH                         17          36          26          26
# Events                      Fog , Rain
# Snow                                 0           0           0           0
# Fog                                  1           0           0           0
# Rain                                 1           0           0           0
# Thunderstorm                         0           0           0           0
#
#                                   88          89          90          91    \
# Date                        2014-03-19  2014-03-20  2014-03-21  2014-03-22
# TempHighF                           72          76          80          77
# TempAvgF                            62          59          67          69
# TempLowF                            51          42          54          61
# DewPointHighF                       55          40          60          65
# DewPointAvgF                        37          36          54          62
# DewPointLowF                        28          31          41          51
# HumidityHighPercent                 80          82          93         100
# HumidityAvgPercent                  52          52          69          80
# HumidityLowPercent                  24          21          45          60
# SeaLevelPressureHighInches       30.21       30.25       30.03       30.02
# SeaLevelPressureAvgInches        30.07       30.15       29.95       29.95
# SeaLevelPressureLowInches        29.88       30.04       29.83       29.88
# VisibilityHighMiles                 10          10          10          10
# VisibilityAvgMiles                   9          10           8           7
# VisibilityLowMiles                   6          10           0           1
# WindHighMPH                         15          10          17          12
# WindAvgMPH                           6           2           7           4
# WindGustMPH                         26          15          27          17
# Events                                                     Fog
# Snow                                 0           0           0           0
# Fog                                  0           0           1           0
# Rain                                 0           0           0           0
# Thunderstorm                         0           0           0           0
#
#                                   92          93          94          95    \
# Date                        2014-03-23  2014-03-24  2014-03-25  2014-03-26
# TempHighF                           61          66          69          66
# TempAvgF                            54          58          57          60
# TempLowF                            47          50          44          54
# DewPointHighF                       51          47          46          55
# DewPointAvgF                        43          42          38          47
# DewPointLowF                        36          38          31          30
# HumidityHighPercent                 72          72          93          78
# HumidityAvgPercent                  62          58          61          57
# HumidityLowPercent                  51          44          28          36
# SeaLevelPressureHighInches       30.27       30.24       30.35        30.2
# SeaLevelPressureAvgInches        30.19       30.14       30.24       30.08
# SeaLevelPressureLowInches        30.05       30.03       30.14       29.95
# VisibilityHighMiles                 10          10          10          10
# VisibilityAvgMiles                  10          10          10          10
# VisibilityLowMiles                   9          10           7           6
# WindHighMPH                         17          10          15          22
# WindAvgMPH                           9           3           5          10
# WindGustMPH                         30          15          22          33
# Events                                                                Rain
# ...
# SeaLevelPressureLowInches        29.95       29.89       29.86       29.92
# VisibilityHighMiles                 10          10          10          10
# VisibilityAvgMiles                  10          10          10          10
# VisibilityLowMiles                   8          10          10          10
# WindHighMPH                         14          13          13          13
# WindAvgMPH                           6           7           7           6
# WindGustMPH                         25          26          28          19
# Events
# Snow                                 0           0           0           0
# Fog                                  0           0           0           0
# Rain                                 0           0           0           0
# Thunderstorm                         0           0           0           0
#
#                                     1293                 1294          1295  \
# Date                          2017-07-06           2017-07-07    2017-07-08
# TempHighF                            100                   99           100
# TempAvgF                              89                   87            88
# TempLowF                              77                   75            75
# DewPointHighF                         74                   74            71
# DewPointAvgF                          71                   71            67
# DewPointLowF                          63                   65            62
# HumidityHighPercent                   88                   88            87
# HumidityAvgPercent                    60                   61            59
# HumidityLowPercent                    31                   33            31
# SeaLevelPressureHighInches         30.15                30.13         30.09
# SeaLevelPressureAvgInches          30.06                30.05         30.02
# SeaLevelPressureLowInches          29.98                29.98         29.94
# VisibilityHighMiles                   10                   10            10
# VisibilityAvgMiles                    10                   10            10
# VisibilityLowMiles                    10                   10            10
# WindHighMPH                           12                   15             9
# WindAvgMPH                             4                    3             3
# WindGustMPH                           20                   27            17
# Events                      Thunderstorm  Rain , Thunderstorm  Thunderstorm
# Snow                                   0                    0             0
# Fog                                    0                    0             0
# Rain                                   0                    1             0
# Thunderstorm                           1                    1             1
#
#                                   1296        1297        1298        1299  \
# Date                        2017-07-09  2017-07-10  2017-07-11  2017-07-12
# TempHighF                          101         100         101         101
# TempAvgF                            89          88          89          89
# TempLowF                            77          76          77          77
# DewPointHighF                       71          72          73          73
# DewPointAvgF                        67          65          69          70
# DewPointLowF                        60          58          58          59
# HumidityHighPercent                 82          87          88          88
# HumidityAvgPercent                  56          57          58          59
# HumidityLowPercent                  29          26          27          29
# SeaLevelPressureHighInches       30.04       29.99       30.05       30.07
# SeaLevelPressureAvgInches        29.99       29.95       29.96       29.99
# SeaLevelPressureLowInches        29.91       29.89       29.87       29.93
# VisibilityHighMiles                 10          10          10          10
# VisibilityAvgMiles                  10          10          10          10
# VisibilityLowMiles                  10          10          10          10
# WindHighMPH                         12          12          14          13
# WindAvgMPH                           4           5           7           6
# WindGustMPH                         19          20          22          20
# Events
# Snow                                 0           0           0           0
# Fog                                  0           0           0           0
# Rain                                 0           0           0           0
# Thunderstorm                         0           0           0           0
#
#                                   1300        1301                 1302  \
# Date                        2017-07-13  2017-07-14           2017-07-15
# TempHighF                          102         101                  103
# TempAvgF                            90          89                   87
# TempLowF                            77          77                   71
# DewPointHighF                       74          74                   73
# DewPointAvgF                        70          69                   70
# DewPointLowF                        63          61                   63
# HumidityHighPercent                 88          88                  100
# HumidityAvgPercent                  59          58                   65
# HumidityLowPercent                  29          27                   29
# SeaLevelPressureHighInches       30.15       30.16                30.07
# SeaLevelPressureAvgInches        30.06       30.07                30.01
# SeaLevelPressureLowInches        29.97       29.98                29.94
# VisibilityHighMiles                 10          10                   10
# VisibilityAvgMiles                  10          10                    9
# VisibilityLowMiles                  10          10                    2
# WindHighMPH                         10          15                   23
# WindAvgMPH                           3           4                    3
# WindGustMPH                         19          22                   35
# Events                                              Rain , Thunderstorm
# Snow                                 0           0                    0
# Fog                                  0           0                    0
# Rain                                 0           0                    1
# Thunderstorm                         0           0                    1
#
#                                   1303                 1304        1305  \
# Date                        2017-07-16           2017-07-17  2017-07-18
# TempHighF                           99                   98         100
# TempAvgF                            84                   88          88
# TempLowF                            68                   77          76
# DewPointHighF                       71                   75          74
# DewPointAvgF                        69                   71          70
# DewPointLowF                        65                   66          65
# HumidityHighPercent                100                   88          88
# HumidityAvgPercent                  67                   63          61
# HumidityLowPercent                  33                   38          33
# SeaLevelPressureHighInches       29.99                29.94       30.03
# SeaLevelPressureAvgInches        29.93                 29.9       29.98
# SeaLevelPressureLowInches        29.84                29.84       29.93
# VisibilityHighMiles                 10                   10          10
# VisibilityAvgMiles                   9                   10          10
# VisibilityLowMiles                   6                   10          10
# WindHighMPH                         12                   16          14
# WindAvgMPH                           3                    3           5
# WindGustMPH                         24                   23          20
# Events                                  Rain , Thunderstorm
# Snow                                 0                    0           0
# Fog                                  0                    0           0
# Rain                                 0                    1           0
# Thunderstorm                         0                    1           0
#
#                                   1306        1307        1308        1309  \
# Date                        2017-07-19  2017-07-20  2017-07-21  2017-07-22
# TempHighF                          101         103         104         103
# TempAvgF                            89          90          91          90
# TempLowF                            77          77          77          77
# DewPointHighF                       74          75          74          74
# DewPointAvgF                        70          69          68          68
# DewPointLowF                        63          61          61          61
# HumidityHighPercent                 88          85          85          88
# HumidityAvgPercent                  60          56          56          58
# HumidityLowPercent                  31          27          27          27
# SeaLevelPressureHighInches       30.17       30.12       30.01       29.96
# SeaLevelPressureAvgInches        30.07       30.03       29.95        29.9
# SeaLevelPressureLowInches        29.99       29.93       29.86       29.81
# VisibilityHighMiles                 10          10          10          10
# VisibilityAvgMiles                  10          10          10          10
# VisibilityLowMiles                  10          10          10          10
# WindHighMPH                         18          14          14          13
# WindAvgMPH                           5           5           5           6
# WindGustMPH                         29          22          24          22
# Events
# Snow                                 0           0           0           0
# Fog                                  0           0           0           0
# Rain                                 0           0           0           0
# Thunderstorm                         0           0           0           0
#
#                                            1310                 1311  \
# Date                                 2017-07-23           2017-07-24
# TempHighF                                   103                  102
# TempAvgF                                     90                   89
# TempLowF                                     77                   76
# DewPointHighF                                74                   75
# DewPointAvgF                                 71                   71
# DewPointLowF                                 66                   56
# HumidityHighPercent                          85                   91
# HumidityAvgPercent                           58                   60
# HumidityLowPercent                           31                   29
# SeaLevelPressureHighInches                29.93                30.01
# SeaLevelPressureAvgInches                 29.88                29.95
# SeaLevelPressureLowInches                 29.82                29.89
# VisibilityHighMiles                          10                   10
# VisibilityAvgMiles                           10                   10
# VisibilityLowMiles                            2                    9
# WindHighMPH                                  13                   13
# WindAvgMPH                                    4                    3
# WindGustMPH                                  24                   19
# Events                      Rain , Thunderstorm  Rain , Thunderstorm
# Snow                                          0                    0
# Fog                                           0                    0
# Rain                                          1                    1
# Thunderstorm                                  1                    1
#
#                                   1312        1313        1314        1315  \
# Date                        2017-07-25  2017-07-26  2017-07-27  2017-07-28
# TempHighF                          103         103         103         105
# TempAvgF                            91          91          89          91
# TempLowF                            78          78          75          76
# DewPointHighF                       75          75          71          71
# DewPointAvgF                        71          70          67          64
# DewPointLowF                        63          61          61          55
# HumidityHighPercent                 91          91          82          87
# HumidityAvgPercent                  61          58          54          54
# HumidityLowPercent                  31          25          25          20
# SeaLevelPressureHighInches       30.11       30.13       30.04       29.97
# SeaLevelPressureAvgInches        30.03       30.03       29.97        29.9
# SeaLevelPressureLowInches        29.95       29.93       29.88       29.81
# VisibilityHighMiles                 10          10          10          10
# VisibilityAvgMiles                  10          10          10          10
# VisibilityLowMiles                   9          10          10          10
# WindHighMPH                         15          15          12          14
# WindAvgMPH                           7           6           5           5
# WindGustMPH                         24          27          21          20
# Events
# Snow                                 0           0           0           0
# Fog                                  0           0           0           0
# Rain                                 0           0           0           0
# Thunderstorm                         0           0           0           0
#
#                                   1316        1317        1318
# Date                        2017-07-29  2017-07-30  2017-07-31
# TempHighF                          107         106          99
# TempAvgF                            92          93          88
# TempLowF                            77          79          77
# DewPointHighF                       72          70          66
# DewPointAvgF                        64          68          61
# DewPointLowF                        55          63          54
# HumidityHighPercent                 82          69          64
# HumidityAvgPercent                  51          48          43
# HumidityLowPercent                  19          27          22
# SeaLevelPressureHighInches       29.91       29.96       30.04
# SeaLevelPressureAvgInches        29.86       29.91       29.97
# SeaLevelPressureLowInches        29.79       29.87       29.91
# VisibilityHighMiles                 10          10          10
# VisibilityAvgMiles                  10          10          10
# VisibilityLowMiles                  10          10          10
# WindHighMPH                         12          13          12
# WindAvgMPH                           4           4           4
# WindGustMPH                         17          20          20
# Events
# Snow                                 0           0           0
# Fog                                  0           0           0
# Rain                                 0           0           0
# Thunderstorm                         0           0           0

# %% [markdown]
# #### If your code worked correctly, now we can drop the `Events` column as we don't need it any more.

# %%
# Your code here
austin_fixed = austin_fixed.drop(columns='Events')
austin_fixed
# Out:
#             Date  TempHighF  TempAvgF  TempLowF  DewPointHighF  DewPointAvgF  \
# 0     2013-12-21         74        60        45           67.0          49.0
# 1     2013-12-22         56        48        39           43.0          36.0
# 2     2013-12-23         58        45        32           31.0          27.0
# 3     2013-12-24         61        46        31           36.0          28.0
# 4     2013-12-25         58        50        41           44.0          40.0
# ...          ...        ...       ...       ...            ...           ...
# 1314  2017-07-27        103        89        75           71.0          67.0
# 1315  2017-07-28        105        91        76           71.0          64.0
# 1316  2017-07-29        107        92        77           72.0          64.0
# 1317  2017-07-30        106        93        79           70.0          68.0
# 1318  2017-07-31         99        88        77           66.0          61.0
#
#       DewPointLowF  HumidityHighPercent  HumidityAvgPercent  \
# 0             43.0                 93.0                75.0
# 1             28.0                 93.0                68.0
# 2             23.0                 76.0                52.0
# 3             21.0                 89.0                56.0
# 4             36.0                 86.0                71.0
# ...            ...                  ...                 ...
# 1314          61.0                 82.0                54.0
# 1315          55.0                 87.0                54.0
# 1316          55.0                 82.0                51.0
# 1317          63.0                 69.0                48.0
# 1318          54.0                 64.0                43.0
#
#       HumidityLowPercent  SeaLevelPressureHighInches  \
# 0                   57.0                       29.86
# 1                   43.0                       30.41
# 2                   27.0                       30.56
# 3                   22.0                       30.56
# 4                   56.0                       30.41
# ...                  ...                         ...
# 1314                25.0                       30.04
# 1315                20.0                       29.97
# 1316                19.0                       29.91
# 1317                27.0                       29.96
# 1318                22.0                       30.04
#
#       SeaLevelPressureAvgInches  SeaLevelPressureLowInches  \
# 0                         29.68                      29.59
# 1                         30.13                      29.87
# 2                         30.49                      30.41
# 3                         30.45                      30.30
# 4                         30.33                      30.27
# ...                         ...                        ...
# 1314                      29.97                      29.88
# 1315                      29.90                      29.81
# 1316                      29.86                      29.79
# 1317                      29.91                      29.87
# 1318                      29.97                      29.91
#
#       VisibilityHighMiles  VisibilityAvgMiles  VisibilityLowMiles  \
# 0                    10.0                 7.0                 2.0
# 1                    10.0                10.0                 5.0
# 2                    10.0                10.0                10.0
# 3                    10.0                10.0                 7.0
# 4                    10.0                10.0                 7.0
# ...                   ...                 ...                 ...
# 1314                 10.0                10.0                10.0
# 1315                 10.0                10.0                10.0
# 1316                 10.0                10.0                10.0
# 1317                 10.0                10.0                10.0
# 1318                 10.0                10.0                10.0
#
#       WindHighMPH  WindAvgMPH  WindGustMPH  Snow  Fog  Rain  Thunderstorm
# 0            20.0         4.0         31.0     0    0     1             1
# 1            16.0         6.0         25.0     0    0     0             0
# 2             8.0         3.0         12.0     0    0     0             0
# 3            12.0         4.0         20.0     0    0     0             0
# 4            10.0         2.0         16.0     0    0     0             0
# ...           ...         ...          ...   ...  ...   ...           ...
# 1314         12.0         5.0         21.0     0    0     0             0
# 1315         14.0         5.0         20.0     0    0     0             0
# 1316         12.0         4.0         17.0     0    0     0             0
# 1317         13.0         4.0         20.0     0    0     0             0
# 1318         12.0         4.0         20.0     0    0     0             0
#
# [1319 rows x 23 columns]

# %% [markdown]
# # Challenge 4 - Processing The `Date` Column
#
# The `Date` column is another non-numeric field in our dataset. A value in that field looks like `'2014-01-06'` which consists of the year, month, and day connected with hyphens. One way to convert the date string to numerical is using a similar approach as we used for `Events`, namely splitting the column into numerical `Year`, `Month`, and `Day` columns. In this challenge we'll show you another way which is to use the Python `datetime` library's `toordinal()` function. Depending on what actual machine learning analysis you will conduct, each approach has its pros and cons. Our goal today is to practice data preparation so we'll skip the discussion here.
#
# Here you can find the [reference](https://docs.python.org/3/library/datetime.html) and [example](https://stackoverflow.com/questions/39846918/convert-date-to-ordinal-python) for `toordinal`. The basic process is to first convert the string to a `datetime` object using `datetime.datetime.strptime`, then convert the `datetime` object to numerical using `toordinal`.
#
# #### In the cell below, convert the `Date` column values from string to numeric values using `toordinal()`.

# %%
# Your code here
austin_fixed['Date'] = austin_fixed['Date'].apply(lambda x : datetime.datetime.strptime(x,'%Y-%m-%d').date().toordinal())

# %% [markdown]
# #### Print `austin_fixed` to check your `Date` column.

# %%
austin_fixed['Date'].head(5)
# Out:
# 0    735223
# 1    735224
# 2    735225
# 3    735226
# 4    735227
# Name: Date, dtype: int64

# %% [markdown]
# # Challenge 5 - Sampling and Holdout Sets

# %% [markdown]
# #### Now that we have processed the data for machine learning, we will separate the data to test and training sets.
#
# We first train the model using only the training set. We check our metrics on the training set. We then apply the model to the test set and check our metrics on the test set as well. If the metrics are significantly more optimal on the training set, then we know we have overfit our model. We will need to revise our model to ensure it will be more applicable to data outside the test set.

# %% [markdown]
# #### In the next cells we will separate the data into a training set and a test set using the `train_test_split()` function in scikit-learn.
#
# When using `scikit-learn` for machine learning, we first separate the data to predictor and response variables. This is the standard way of passing datasets into a model in `scikit-learn`. The `scikit-learn` will then find out whether the predictors and responses fit the model.
#
# In the next cell, assign the `TempAvgF` column to `y` and the remaining columns to `X`. Your `X` should be a subset of `austin_fixed` containing the following columns:
#
# ```['Date',
#  'TempHighF',
#  'TempLowF',
#  'DewPointHighF',
#  'DewPointAvgF',
#  'DewPointLowF',
#  'HumidityHighPercent',
#  'HumidityAvgPercent',
#  'HumidityLowPercent',
#  'SeaLevelPressureHighInches',
#  'SeaLevelPressureAvgInches',
#  'SeaLevelPressureLowInches',
#  'VisibilityHighMiles',
#  'VisibilityAvgMiles',
#  'VisibilityLowMiles',
#  'WindHighMPH',
#  'WindAvgMPH',
#  'WindGustMPH',
#  'Snow',
#  'Fog',
#  'Rain',
#  'Thunderstorm']```
#
#  Your `y` should be a subset of `austin_fixed` containing one column `TempAvgF`.

# %%
# Your code here:
y = austin_fixed.TempAvgF

x = austin_fixed[[i for i in austin_fixed.columns if i not in ['TempAvgF','Date']]]

# %% [markdown]
# In the next cell, import `train_test_split` from `sklearn.model_selection`

# %%
#Your code here:
from sklearn.model_selection import train_test_split

# %% [markdown]
# Now that we have split the data to predictor and response variables and imported the `train_test_split()` function, split `X` and `y` into `X_train`, `X_test`, `y_train`, and `y_test`. 80% of the data should be in the training set and 20% in the test set. `train_test_split()` reference can be accessed [here](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html).
#
#
# Enter your code in the cell below:

# %%
#Your code here:
x_train, x_test = train_test_split(x,test_size=0.2)

y_train, y_test = train_test_split(y,test_size=0.2)

# %% [markdown]
# #### Congratulations! Now you have finished the preparation of the dataset!

# %% [markdown]
# # Bonus Challenge 1
#
# #### While the above is the common practice to prepare most datasets, when it comes to time series data, we sometimes do not want to randomly select rows from our dataset.
#
# This is because many time series algorithms rely on observations having equal time distances between them. In such cases, we typically select the majority of rows as the test data and the last few rows as the training data. We don't use `train_test_split()` to select the train/test data because it returns random selections.
#
# In the following cell, compute the number of rows that account for 80% of our data and round it to the next integer. Assign this number to `ts_rows`.

# %%
# Your code here:

test = 0.8

ts_rows = int(test * len(x))

# %% [markdown]
# Assign the first `ts_rows` rows of `X` to `X_ts_train` and the remaining rows to `X_ts_test`.

# %%
# Your code here:
x_ts_train = x[0:ts_rows]
x_ts_test = x[ts_rows:]

# %% [markdown]
# Assign the first `ts_rows` rows of `y` to `y_ts_train` and the remaining rows to `y_ts_test`.

# %%
# Your code here:
y_ts_train = y[0:ts_rows]
y_ts_test = y[ts_rows:]
y_ts_train
# Out:
# 0       60
# 1       48
# 2       45
# 3       46
# 4       50
#         ..
# 1050    68
# 1051    68
# 1052    66
# 1053    66
# 1054    63
# Name: TempAvgF, Length: 1055, dtype: int64
