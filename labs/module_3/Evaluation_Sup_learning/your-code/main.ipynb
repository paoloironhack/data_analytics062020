# %% [markdown]
# # Model Evaluation & Fitting
# ## Predicting Boston Housing Prices

# %%
# import libraries  here
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, auc

# %% [markdown]
# ## Getting Started
# In this project, you will use the Boston Housing Prices dataset to build several models to predict the prices of homes with particular qualities from the suburbs of Boston, MA.
# We will build models with several different parameters, which will change the goodness of fit for each.

# %% [markdown]
# ---
# ## 1- Data Exploration

# %% [markdown]
# ### Import and explore the data. Clean the data for outliers and missing values.

# %% [markdown]
# Download the Boston dataset from [here](https://drive.google.com/file/d/1Bux3hwVYr6BuFbdUIK2db1lOY6EqghfD/view?usp=sharing) , place it in the data folder and import it as dataframe. **The features in the dataset are described [here](https://www.kaggle.com/prasadperera/the-boston-housing-dataset)**
# <br> Since we want to predict the value of houses, the **target variable**, `'MEDV'`, will be the variable we seek to predict.

# %%
#your code here
data = pd.read_csv('../data/Boston.csv')
data.head(5)
# Out:
#    Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0           1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1           2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2           3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3           4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4           5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
#
#    tax  ptratio   black  lstat  medv
# 0  296     15.3  396.90   4.98  24.0
# 1  242     17.8  396.90   9.14  21.6
# 2  242     17.8  392.83   4.03  34.7
# 3  222     18.7  394.63   2.94  33.4
# 4  222     18.7  396.90   5.33  36.2

# %% [markdown]
# ### Next, we want to explore the data. Pick several variables you think will be most correlated with the prices of homes in Boston, and create plots that show the data dispersion as well as the regression line of best fit.

# %%
#your code here
#I don't get a clear idea about what the variables are. So ,referring to correlation data 
data.corr()

#From the values of correlation below, I'm choosing the columns "black","rm","zn" ,"dis" which have a fair positive correlation with our target variable MEDV.
# Out:
#             Unnamed: 0      crim        zn     indus      chas       nox  \
# Unnamed: 0    1.000000  0.407407 -0.103393  0.399439 -0.003759  0.398736
# crim          0.407407  1.000000 -0.200469  0.406583 -0.055892  0.420972
# zn           -0.103393 -0.200469  1.000000 -0.533828 -0.042697 -0.516604
# indus         0.399439  0.406583 -0.533828  1.000000  0.062938  0.763651
# chas         -0.003759 -0.055892 -0.042697  0.062938  1.000000  0.091203
# nox           0.398736  0.420972 -0.516604  0.763651  0.091203  1.000000
# rm           -0.079971 -0.219247  0.311991 -0.391676  0.091251 -0.302188
# age           0.203784  0.352734 -0.569537  0.644779  0.086518  0.731470
# dis          -0.302211 -0.379670  0.664408 -0.708027 -0.099176 -0.769230
# rad           0.686002  0.625505 -0.311948  0.595129 -0.007368  0.611441
# tax           0.666626  0.582764 -0.314563  0.720760 -0.035587  0.668023
# ptratio       0.291074  0.289946 -0.391679  0.383248 -0.121515  0.188933
# ...

# %%
# Your plots here
sns.pairplot(data=data,vars = ['black','zn','rm','dis','medv'],kind="reg",palette = "husl")

# %% [markdown]
# ### What do these plots tell you about the relationships between these variables and the prices of homes in Boston? Are these the relationships you expected to see in these variables?
# - Reference: https://www.kaggle.com/c/boston-housing

# %%
### Your response here
#Refering to the link above, a description of the features in this dataset :
"""""crim
per capita crime rate by town.

zn
proportion of residential land zoned for lots over 25,000 sq.ft.

indus
proportion of non-retail business acres per town.

chas
Charles River dummy variable (= 1 if tract bounds river; 0 otherwise).

nox
nitrogen oxides concentration (parts per 10 million).

rm
average number of rooms per dwelling.

age
proportion of owner-occupied units built prior to 1940.

dis
weighted mean of distances to five Boston employment centres.

rad
index of accessibility to radial highways.

tax
full-value property-tax rate per $10,000.

ptratio
pupil-teacher ratio by town.

black
1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town.

lstat
lower status of the population (percent).

medv
median value of owner-occupied homes in $1000s."""""

#From the plots above, the inferences are:
"""""1.Target variable "medv" - Median value(price)of homes are comparitively the most correlated to "rm"-the no.of rooms per dwelling.
2.Next to "rm" ,it is "dis"-the weighted mean of distances from employment centres which impacts the pricing.
3.The column "black"  which is a measure of the proportion of blacks in the town also seem to have a positive influence on the pricing.
4."zn" - Zone of residential land is positively correlated with the pricing.
5. "Lstat" - is most negatively corelated with house pricing."""""
# Out:
# '""1.Target variable "medv" - Median value(price)of homes are comparitively the most correlated to "rm"-the no.of rooms per dwelling.\n2.Next to "rm" ,it is "dis"-the weighted mean of distances from employment centres which impacts the pricing.\n3.The column "black"  which is a measure of the proportion of blacks in the town also seem to have a positive influence on the pricing.\n4."zn" - Zone of residential land is positively correlated with the pricing.\n5. "Lstat" - is most negatively corelated with house pricing.'

# %% [markdown]
# ### Make a heatmap of the remaining variables. Are there any variables that you did not consider that have very high correlations? What are they?

# %%
#your code here
fig, ax = plt.subplots(figsize=(10, 5))
# plot heatmap
df = data.copy()
df.drop(columns = ['black','zn','rm','dis'] ,inplace = True)
sns.heatmap(df.corr(),cmap="YlGnBu", annot = True)
plt.show()

# %% [markdown]
# #### Significant correlations

# %%
#your code here
"""""Apart from the features mentioned above ,there's only one feature "chas" - Charles River dummy variable 
    which has a slightly positive correlation with the target."""""
# Out:
# '""Apart from the features mentioned above ,there\'s only one feature "chas" - Charles River dummy variable \n    which has a slightly positive correlation with the target.'

# %% [markdown]
# ### Calculate Statistics
# Calculate descriptive statistics for housing price. Include the minimum, maximum, mean, median, and standard deviation.

# %%
# Your code here
data['medv'].describe()
# Out:
# count    506.000000
# mean      22.532806
# std        9.197104
# min        5.000000
# 25%       17.025000
# 50%       21.200000
# 75%       25.000000
# max       50.000000
# Name: medv, dtype: float64

# %% [markdown]
# ----
#
# ## 2- Developing a Model

# %% [markdown]
# ### Implementation: Shuffle and Split Data
# Split the data into the testing and training datasets. Shuffle the data as well to remove any bias in selecting the traing and test.

# %%
#your code here
y = data['medv']
X = data.drop('medv', axis=1) 

# Your code here:
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20 , random_state = 42, shuffle = True)

# %% [markdown]
# ----
#
# ## 3- Analyzing Model Performance
# Next, we are going to build a Random Forest Regressor, and test its performance with several different parameter settings.

# %% [markdown]
# ### Learning Curves
# Lets build the different models. Set the max_depth parameter to 2, 4, 6, 8, and 10 respectively.

# %%
#your code here

from sklearn.ensemble import RandomForestRegressor

def Randomforest(x):
        model= RandomForestRegressor(max_depth = i)
        model.fit(X_train, y_train)
        return model

def scoring (model):
    print(f'Score of train set of {model} is {round(model.score(X_train, y_train),2)}')
    print(f'Score of test set of {model} is {round(model.score(X_test, y_test),2)}')

#define two variables to store training score and test score, and appending them in the function definition itself.
train_scores = []
test_scores = []

for i in range(2, 12, 2):
    Randomforest(i)
    scoring(Randomforest(i))

    train_scores.append(Randomforest(i).score(X_train,y_train))
    test_scores.append(Randomforest(i).score(X_test,y_test))
    
print(train_scores)
print(test_scores)
# Out:
# Score of train set of RandomForestRegressor(max_depth=2) is 0.76
# Score of test set of RandomForestRegressor(max_depth=2) is 0.7
# Score of train set of RandomForestRegressor(max_depth=4) is 0.91
# Score of test set of RandomForestRegressor(max_depth=4) is 0.84
# Score of train set of RandomForestRegressor(max_depth=6) is 0.95
# Score of test set of RandomForestRegressor(max_depth=6) is 0.87
# Score of train set of RandomForestRegressor(max_depth=8) is 0.97
# Score of test set of RandomForestRegressor(max_depth=8) is 0.87
# Score of train set of RandomForestRegressor(max_depth=10) is 0.97
# Score of test set of RandomForestRegressor(max_depth=10) is 0.87
# [0.76777409000202, 0.9103210946586227, 0.9521791788407563, 0.9681460787018056, 0.973823339517473]
# [0.7077334892100474, 0.8463681171889446, 0.8624866736609644, 0.8792303795034038, 0.8751438442561799]

# %% [markdown]
# Now, plot the score for each tree on the training set and on the testing set.

# %%
# Produce a plot with the score for the testing and training for the different max depths
#your code here

#create a dataframe with max_depth, train score and test score as features
scores = pd.DataFrame.from_dict({'max_depth': [2, 4, 6, 8, 10], 'train_score' : train_scores, 
 'test_score' : test_scores})
scores
# Out:
#    max_depth  train_score  test_score
# 0          2     0.767774    0.707733
# 1          4     0.910321    0.846368
# 2          6     0.952179    0.862487
# 3          8     0.968146    0.879230
# 4         10     0.973823    0.875144

# %%
#Create plot
plt.figure(figsize=(10,8))
x = scores.max_depth
y1 = scores.train_score
y2 = scores.test_score
plt.plot(x, y1, 'blue', label = 'Training Score')
plt.plot(x, y2, 'red', label = 'Test Score')
plt.legend()
plt.title('Train & Test score of Random Forest Regressors')
plt.xlabel('Max depth')
plt.ylabel('scores')
plt.show()

# %% [markdown]
# What do these results tell you about the effect of the depth of the trees on the performance of the model?

# %%
# Your response here
#The higher the depth, the more better the train and test scores will be.

# %% [markdown]
# ### Bias-Variance Tradeoff
# When the model is trained with a maximum depth of 1, does the model suffer from high bias or from high variance? How about when the model is trained with a maximum depth of 10?

# %%
# Your response here
#Maximum depth of 10 indicates a high variance (hence a low bias) and fits very well to the data.
#Viceversa for a max depth of 1.

# %% [markdown]
# ### Best-Guess Optimal Model
# What is the max_depth parameter that you think would optimize the model? Based on your previous results run your model and explain its performance.

# %% [markdown]
# #### Train the Random forest regressor model with the optimal value for max_depth

# %%
#your code here
model8 = RandomForestRegressor(max_depth=8, random_state=0)
model8.fit(X_train, y_train)
y_pred8 = model8.predict(X_test)
pd.DataFrame({'test':y_test, 'predicted':y_pred8})
# Out:
#      test  predicted
# 173  23.6  22.877716
# 274  32.4  30.990383
# 491  13.6  15.859549
# 72   22.8  23.219028
# 452  16.1  16.568056
# ..    ...        ...
# 412  17.9  12.168177
# 436   9.6  12.879216
# 411  17.2  13.797108
# 86   22.5  20.731599
# 75   21.4  22.809176
#
# [102 rows x 2 columns]

# %% [markdown]
# #### Use the mean absolute error (MAE) to calculate the performance of the model

# %%
#your code here
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test, y_pred8)
# Out:
# 2.100760063040965

# %% [markdown]
# #### Use the root mean squared error (RMSE) to calculate the performance of the model

# %%
#your code here
import math
MSE = sklearn.metrics.mean_squared_error(y_test, y_pred8)
RMSE = math.sqrt(MSE)
RMSE
# Out:
# 3.1668179777353465

# %% [markdown]
# #### Create a function that calculates  and returns the r2 score as performance metric

# %%
#your code here
def r2_score(y_test, y_pred):
    return sklearn.metrics.r2_score(y_test, y_pred)

# %% [markdown]
# #### Calculate the r2 score of the model using the function defined above

# %%
#your code here
r2_score(y_test,y_pred8)
# Out:
# 0.8632453465249041

# %% [markdown]
# #### Bonus question
# Read [this article](https://medium.com/human-in-a-machine-world/mae-and-rmse-which-metric-is-better-e60ac3bde13d)
# about the differences between MAE and RMSE. Do you think that one of the two types of error is more appropriate for this problem, and why?

# %%
#your answer here

# %% [markdown]
# ### 4 - Applicability
# *In a few sentences, discuss whether the constructed model should or should not be used in a real-world setting.*
# **Hint:** Some questions to answering:
# - *How relevant today is data that was collected from 1978?*
# - *Are the features present in the data sufficient to describe a home?*
# - *Is the model robust enough to make consistent predictions?*
# - *Would data collected in an urban city like Boston be applicable in a rural city?*

# %%
#Your response here
#1. The data is pretty outdated, that too for a major city like Boston there would be an inomparably huge difference in the housing prices.
#2. On a high level,Some features in the dataset seem to be irrelevant without needing to look at the correlation data,while some addl.features 
#  can be included depending on whether its a city or outskirts. 
#Hence the predictions based on this dataset would not hold good currently or if dated back,not for a small town either.
