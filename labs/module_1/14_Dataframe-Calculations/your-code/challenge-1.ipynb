# %% [markdown]
# # Challenge 1
#
# In this challenge you will be working on **Pokemon**. You will answer a series of questions in order to practice dataframe calculation, aggregation, and transformation.
#
# ![Pokemon](../images/pokemon.jpg)
#
# Follow the instructions below and enter your code.
#
# #### Import all required libraries.

# %%
# import libraries
import pandas as pd
import numpy as np

# %% [markdown]
# #### Import data set.
#
# Import data set `Pokemon` from Ironhack's database. Read the data into a dataframe called `pokemon`.
#
# *Data set attributed to [Alberto Barradas](https://www.kaggle.com/abcsds/pokemon/)*
# Please download the dataset from our google drive [here](https://drive.google.com/file/d/1Vw4VEsYt8b4Kp2371woWFmnAaWyBSYLl/view?usp=sharing) and place it in the provided data folder. You will access the data folder with a relative path.

# %%
# import data set 
pokemon = pd.read_csv('data/pokemon_updated.csv',sep=',')

# %% [markdown]
# #### Print first 10 rows of `pokemon`.

# %%
# your code here
pokemon.head(10)
# Out:
#                         Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0                  Bulbasaur  Grass  Poison    318  45      49       49
# 1                    Ivysaur  Grass  Poison    405  60      62       63
# 2                   Venusaur  Grass  Poison    525  80      82       83
# 3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4                 Charmander   Fire     NaN    309  39      52       43
# 5                 Charmeleon   Fire     NaN    405  58      64       58
# 6                  Charizard   Fire  Flying    534  78      84       78
# 7  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False
# 5       80       65     80           1      False
# 6      109       85    100           1      False
# 7      130       85    100           1      False
# 8      159      115    100           1      False
# 9       50       64     43           1      False

# %% [markdown]
# When you look at a data set, you often wonder what each column means. Some open-source data sets provide descriptions of the data set. In many cases, data descriptions are extremely useful for data analysts to perform work efficiently and successfully.
#
# For the `Pokemon.csv` data set, we are including the descriptions below. Read the descriptions and understand what each column means. This knowledge is helpful in your work with the data.
#
# | Column | Description |
# | --- | --- |
# | # | ID for each pokemon |
# | Name | Name of each pokemon |
# | Type 1 | Each pokemon has a type, this determines weakness/resistance to attacks |
# | Type 2 | Some pokemon are dual type and have 2 |
# | Total | A general guide to how strong a pokemon is |
# | HP | Hit points, or health, defines how much damage a pokemon can withstand before fainting |
# | Attack | The base modifier for normal attacks (eg. Scratch, Punch) |
# | Defense | The base damage resistance against normal attacks |
# | SP Atk | Special attack, the base modifier for special attacks (e.g. fire blast, bubble beam) |
# | SP Def | The base damage resistance against special attacks |
# | Speed | Determines which pokemon attacks first each round |
# | Generation | Number of generation |
# | Legendary | True if Legendary Pokemon False if not |

# %% [markdown]
# #### Obtain the distinct values across `Type 1` and `Type 2`.
#
# Exctract all the values in `Type 1` and `Type 2`. Then create an array containing the distinct values across both fields.

# %%
pd.unique(pokemon[['Type 1', 'Type 2']].values.ravel('K'))
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying', nan], dtype=object)

# %% [markdown]
# #### Cleanup `Name` that contain "Mega".
#
# If you have checked out the pokemon names carefully enough, you should have found there are junk texts in the pokemon names which contain "Mega". We want to clean up the pokemon names. For instance, "VenusaurMega Venusaur" should be "Mega Venusaur", and "CharizardMega Charizard X" should be "Mega Charizard X".

# %%
# your code here
import re

pokemon.Name = pd.DataFrame(pokemon.Name.apply(lambda x: re.sub(r'(.+)(Mega.+)',r'\2', x)))

pokemon.head(10)
# Out:
#                Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0         Bulbasaur  Grass  Poison    318  45      49       49       65
# 1           Ivysaur  Grass  Poison    405  60      62       63       80
# 2          Venusaur  Grass  Poison    525  80      82       83      100
# 3     Mega Venusaur  Grass  Poison    625  80     100      123      122
# 4        Charmander   Fire     NaN    309  39      52       43       60
# 5        Charmeleon   Fire     NaN    405  58      64       58       80
# 6         Charizard   Fire  Flying    534  78      84       78      109
# 7  Mega Charizard X   Fire  Dragon    634  78     130      111      130
# 8  Mega Charizard Y   Fire  Flying    634  78     104       78      159
# 9          Squirtle  Water     NaN    314  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False
# 5       65     80           1      False
# 6       85    100           1      False
# 7       85    100           1      False
# 8      115    100           1      False
# 9       64     43           1      False

# %% [markdown]
# #### Create a new column called `A/D Ratio` whose value equals to `Attack` devided by `Defense`.
#
# For instance, if a pokemon has the Attack score 49 and Defense score 49, the corresponding `A/D Ratio` is 49/49=1.

# %%
# your code here
pokemon['A/D Ratio'] = pokemon['Attack'] / pokemon['Defense']

# %% [markdown]
# #### Identify the pokemon with the highest `A/D Ratio`.

# %%
# your code here
pokemon[pokemon['A/D Ratio'] == pokemon['A/D Ratio'].max()]
# Out:
#                    Name   Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 429  DeoxysAttack Forme  Psychic    NaN    600  50     180       20      180
#
#      Sp. Def  Speed  Generation  Legendary  A/D Ratio
# 429       20    150           3       True        9.0

# %% [markdown]
# #### Identify the pokemon with the lowest A/D Ratio.

# %%
# your code here
pokemon[pokemon['A/D Ratio'] == pokemon['A/D Ratio'].min()]
# Out:
#         Name Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 230  Shuckle    Bug   Rock    505  20      10      230       10      230
#
#      Speed  Generation  Legendary  A/D Ratio
# 230      5           2      False   0.043478

# %% [markdown]
# #### Create a new column called `Combo Type` whose value combines `Type 1` and `Type 2`.
#
# Rules:
#
# * If both `Type 1` and `Type 2` have valid values, the `Combo Type` value should contain both values in the form of `<Type 1> <Type 2>`. For example, if `Type 1` value is `Grass` and `Type 2` value is `Poison`, `Combo Type` will be `Grass-Poison`.
#
# * If `Type 1` has valid value but `Type 2` is not, `Combo Type` will be the same as `Type 1`. For example, if `Type 1` is `Fire` whereas `Type 2` is `NaN`, `Combo Type` will be `Fire`.

# %%
pokemon[['Type 1','Type 2']] = pokemon[['Type 1','Type 2']].replace(np.nan, '', regex=True)

## Think I way overcomplication this one :( but I wanted to try to solve it with a lambda function. 
## I used a better numpy answer in challenge 2

pokemon['Combo Type'] = pokemon.apply(lambda x: str(x.loc['Type 1']) + '-' + str(x.loc['Type 2'])
             
             if pd.notnull(x.loc['Type 1']) &  (x.loc['Type 2'] != "")  
              
             else  
              str(x.loc['Type 1'])  + str(x.loc['Type 2'])
              ,axis=1)

pokemon.head()
# Out:
#             Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0      Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1        Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2       Venusaur  Grass  Poison    525  80      82       83      100      100
# 3  Mega Venusaur  Grass  Poison    625  80     100      123      122      120
# 4     Charmander   Fire            309  39      52       43       60       50
#
#    Speed  Generation  Legendary  A/D Ratio    Combo Type
# 0     45           1      False   1.000000  Grass-Poison
# 1     60           1      False   0.984127  Grass-Poison
# 2     80           1      False   0.987952  Grass-Poison
# 3     80           1      False   0.813008  Grass-Poison
# 4     65           1      False   1.209302          Fire

# %% [markdown]
# #### Identify the pokemon whose `A/D Ratio` are among the top 5.

# %%
# your code here
pokemon.sort_values(['A/D Ratio'],ascending=False)[:5]
# Out:
#                    Name   Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 429  DeoxysAttack Forme  Psychic            600  50     180       20      180
# 347            Carvanha    Water    Dark    305  45      90       20       65
# 19        Mega Beedrill      Bug  Poison    495  65     150       40       15
# 453            Cranidos     Rock            350  67     125       40       30
# 348            Sharpedo    Water    Dark    460  70     120       40       95
#
#      Sp. Def  Speed  Generation  Legendary  A/D Ratio  Combo Type
# 429       20    150           3       True      9.000     Psychic
# 347       20     65           3      False      4.500  Water-Dark
# 19        80    145           1      False      3.750  Bug-Poison
# 453       30     58           4      False      3.125        Rock
# 348       40     95           3      False      3.000  Water-Dark

# %% [markdown]
# #### For the 5 pokemon printed above, aggregate `Combo Type` and use a list to store the unique values.
#
# Your end product is a list containing the distinct `Combo Type` values of the 5 pokemon with the highest `A/D Ratio`.

# %%
# your code here
pokemon.sort_values(['A/D Ratio'],ascending=False).iloc[:5,-1].to_list()
# Out:
# ['Psychic', 'Water-Dark', 'Bug-Poison', 'Rock', 'Water-Dark']

# %% [markdown]
# #### For each of the `Combo Type` values obtained from the previous question, calculate the mean scores of all numeric fields across all pokemon.
#
# Your output should look like below:
#
# [Aggregate](https://drive.google.com/file/d/1d2EofoaL4-bSm68STzwNNaoP_SgIYQ9n/view?usp=sharing)

# %%
# your code here
pokemon.groupby(['Combo Type']).mean()
#paolo: notice it is requested only for the top 5
# Out:
#                     Total         HP      Attack     Defense     Sp. Atk  \
# Combo Type
# Bug            289.705882  53.058824   50.352941   55.411765   39.294118
# Bug-Electric   395.500000  60.000000   62.000000   55.000000   77.000000
# Bug-Fighting   550.000000  80.000000  155.000000   95.000000   40.000000
# Bug-Fire       455.000000  70.000000   72.500000   60.000000   92.500000
# Bug-Flying     419.500000  63.000000   70.142857   61.571429   72.857143
# ...                   ...        ...         ...         ...         ...
# Water-Ice      511.666667  90.000000   83.333333  113.333333   80.000000
# Water-Poison   426.666667  61.666667   68.333333   58.333333   61.666667
# Water-Psychic  481.000000  87.000000   73.000000  104.000000   94.000000
# Water-Rock     428.750000  70.750000   82.750000  112.750000   61.500000
# Water-Steel    530.000000  84.000000   86.000000   88.000000  111.000000
#
#                   Sp. Def      Speed  Generation  Legendary  A/D Ratio
# Combo Type
# Bug             43.647059  47.941176    3.470588        0.0   0.940179
# Bug-Electric    55.000000  86.500000    5.000000        0.0   1.111667
# Bug-Fighting   100.000000  80.000000    2.000000        0.0   1.637681
# Bug-Fire        80.000000  80.000000    5.000000        0.0   1.234266
# Bug-Flying      69.071429  82.857143    2.857143        0.0   1.146274
# ...                   ...        ...         ...        ...        ...
# Water-Ice       78.333333  66.666667    1.000000        0.0   0.821759
# Water-Poison    91.666667  85.000000    1.333333        0.0   1.162149
# Water-Psychic   79.000000  44.000000    1.200000        0.0   0.783668
# Water-Rock      65.000000  36.000000    3.750000        0.0   0.727170
# Water-Steel    101.000000  60.000000    4.000000        0.0   0.977273
#
# [154 rows x 10 columns]

# %%
#paolo: good work
