# %% [markdown]
# # Subsetting and Descriptive Stats
#
# ## Before your start:
#    - Remember that you just need to do one of the challenges.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly: enjoy the process!
#    - **Only one challenge is mandatory, you can pick your favorite**
#    - **Please always use relative paths to access the data**
#
#
# #### Import all the necessary libraries here:

# %%
# import libraries here
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # [ONLY ONE MANDATORY] Challenge 1
# #### In this challenge we will use the `Temp_States`  dataset.
# Download the dataset from [here](https://drive.google.com/file/d/1Ycqn6b9vkBAhYRVo9LAiHxKtWaBoJLVi/view?usp=sharing) and place it in the data folder
#
# #### First import the dataset into a dataframe called `temp`.

# %%
# your code here

# %% [markdown]
# #### Print `temp`.

# %%
# your code here

# %% [markdown]
# #### Explore the data types of the *temp* dataframe. What types of data do we have? Comment your result.

# %%
# your code here

# %%
"""
your comments here
"""
# Out:
# '\nyour comments here\n'

# %% [markdown]
# #### Select the rows where state is New York.

# %%
# your code here

# %% [markdown]
# #### What is the average temperature of cities in New York?

# %%
# your code here

# %% [markdown]
# #### Which states and cities have a temperature above 15 degrees Celsius?

# %%
# your code here

# %% [markdown]
# #### Now, return only the cities that have a temperature above 15 degrees Celsius.

# %%
# your code here

# %% [markdown]
# #### Which cities have a temperature above 15 degrees Celcius and below 20 degrees Celsius?
#
# **Hint**: First, write the condition. Then, select the rows.

# %%
# your code here

# %% [markdown]
# #### Find the mean and standard deviation of the temperature of each state.

# %%
# your code here

# %% [markdown]
# # [ONLY ONE MANDATORY]  Challenge 2

# %%
"""I'm still working on this one. I finished Challenge 3."""

# %% [markdown]
# Download the dataset `employees` from [here](https://drive.google.com/file/d/1CYFlr1Gc-B6nM3LfNUHj0WDNlXnK2ALI/view?usp=sharing) and place it in the data folder.
# Load the `employees` dataset into a dataframe. Call the dataframe `employees`.

# %%
# your code here
employees = pd.read_csv('..\\data\\Employee.csv')
employees.head()
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 0    Jose         IT  Bachelor      M    analyst      1      35
# 1   Maria         IT    Master      F    analyst      2      30
# 2   David         HR    Master      M    analyst      2      30
# 3   Sonia         HR  Bachelor      F    analyst      4      35
# 4  Samuel      Sales    Master      M  associate      3      55

# %% [markdown]
# #### Explore the data types of the `employees` dataframe. Comment your results.

# %%
# your code here
employees.dtypes
# Out:
# Name          object
# Department    object
# Education     object
# Gender        object
# Title         object
# Years          int64
# Salary         int64
# dtype: object

# %%
"""
your comments here:
The datatypes are mainly categorical. There are very few numerical variables in this database. Only salary is a continous
variable. 
"""
# Out:
# '\nyour comments here:\nThe datatypes are mainly categorical. There are very few numerical variables in this database. Only salary is a continous\n'

# %% [markdown]
# #### What's the average salary in this company?

# %%
# your code here
employees['Salary'].mean()
# Out:
# 48.888888888888886

# %% [markdown]
# #### What's the highest salary?

# %%
# your code here
employees['Salary'].max()
# Out:
# 70

# %% [markdown]
# #### What's the lowest salary?

# %%
# your code here
employees['Salary'].min()
# Out:
# 30

# %% [markdown]
# #### Who are the employees with the lowest salary?

# %%
# your code here
employees.loc[employees['Salary'] == employees['Salary'].min()]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Find all the information about an employee called David.

# %%
# your code here
employees.loc[employees['Name'] == 'David']
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Could you return only David's salary?

# %%
# your code here
(employees.loc[employees['Name'] == 'David'])['Salary']
# Out:
# 2    30
# Name: Salary, dtype: int64

# %% [markdown]
# #### Print all the rows where job title is associate.

# %%
# your code here
employees.loc[employees['Title'] == 'associate']
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 7   Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Print the first 3 rows of your dataframe.
# **Tip**: There are 2 ways to do it. Do it both ways.

# %%
# Method 1
# your code here
employees.head(3)
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %%
# Method 2
# your code here
employees.iloc[:3]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Find the employees whose title is associate and whose salary is above 55.

# %%
# your code here
employees.loc[(employees['Title'] == 'associate') & (employees['Salary'] > 55)]
# Out:
#     Name Department Education Gender      Title  Years  Salary
# 7  Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Group the employees by number of years of employment. What are the average salaries in each group?

# %%
# your code here
employees.pivot_table(values)

# %% [markdown]
# ####  What is the average salary per title?

# %%
# your code here

# %% [markdown]
# ####  Find the salary quartiles.

# %%
# your code here

# %% [markdown]
# #### Is the mean salary different per gender?

# %%
# your code here

# %% [markdown]
# #### Find the minimum, mean and maximum of all numeric columns for each company department.

# %%
# your code here

# %% [markdown]
# #### Bonus Question:  for each department, compute the difference between the maximum and the minimum salary.
# **Hint**: try using `agg` or `apply` combined with `lambda` functions.

# %%
# your code here

# %% [markdown]
# # [ONLY ONE MANDATORY] Challenge 3
# Download the dataset `Orders` from [here](https://drive.google.com/file/d/1aG8-IFQXyAYGYBpVSRsiMG-XR0iDRVXN/view?usp=sharing) and place it in the data folder.
# Load the `Orders` into a dataframe. Call the dataframe `Orders`.

# %%
# your code here
orders = pd.read_csv('..\\data\\Orders.csv')
orders.head()
# Out:
#    Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0           0     536365    85123A  2010     12    3     8
# 1           1     536365     71053  2010     12    3     8
# 2           2     536365    84406B  2010     12    3     8
# 3           3     536365    84029G  2010     12    3     8
# 4           4     536365    84029E  2010     12    3     8
#
#                            Description  Quantity          InvoiceDate  \
# 0   white hanging heart t-light holder         6  2010-12-01 08:26:00
# 1                  white metal lantern         6  2010-12-01 08:26:00
# 2       cream cupid hearts coat hanger         8  2010-12-01 08:26:00
# 3  knitted union flag hot water bottle         6  2010-12-01 08:26:00
# 4       red woolly hottie white heart.         6  2010-12-01 08:26:00
#
#    UnitPrice  CustomerID         Country  amount_spent
# 0       2.55       17850  United Kingdom         15.30
# 1       3.39       17850  United Kingdom         20.34
# ...

# %% [markdown]
# #### Explore your dataset by looking at the data types and summary statistics. Comment your results.

# %%
# your code here
orders.dtypes
# Out:
# Unnamed: 0        int64
# InvoiceNo         int64
# StockCode        object
# year              int64
# month             int64
# day               int64
# hour              int64
# Description      object
# Quantity          int64
# InvoiceDate      object
# UnitPrice       float64
# CustomerID        int64
# Country          object
# amount_spent    float64
# dtype: object

# %%
orders.isnull().values.any()
# Out:
# False

# %%
orders.describe().transpose()
# Out:
#                  count           mean            std       min        25%  \
# Unnamed: 0    397924.0  278465.221859  152771.368303       0.0  148333.75
# InvoiceNo     397924.0  560617.126645   13106.167695  536365.0  549234.00
# year          397924.0    2010.934259       0.247829    2010.0    2011.00
# month         397924.0       7.612537       3.416527       1.0       5.00
# day           397924.0       3.614555       1.928274       1.0       2.00
# hour          397924.0      12.728247       2.273535       6.0      11.00
# Quantity      397924.0      13.021823     180.420210       1.0       2.00
# UnitPrice     397924.0       3.116174      22.096788       0.0       1.25
# CustomerID    397924.0   15294.315171    1713.169877   12346.0   13969.00
# amount_spent  397924.0      22.394749     309.055588       0.0       4.68
#
#                     50%        75%        max
# Unnamed: 0    284907.50  410079.25  541908.00
# InvoiceNo     561893.00  572090.00  581587.00
# ...

# %%
"""
your comments here:

* Data types: mainly numerical datatypes (mostly integers and a few floats).
* Tried to drop column 'Unnamed: 0', but that didn't work. Doesn't add anything to the data.
* No missing values, which I find remarkable in a relatively large set (comparing to what we've worked with.)
* The dataset describes order from customers in the years 2010 and 2011. 
* It contains the information about the order itself: amount spent, what and how much was ordered and from which country.

"""
# Out:
# "\nyour comments here:\n\n* Data types: mainly numerical datatypes (mostly integers and a few floats).\n* Tried to drop column 'Unnamed: 0', but that didn't work. Doesn't add anything to the data.\n* No missing values, which I find remarkable in a relatively large set (comparing to what we've worked with.)\n* The dataset describes order from customers in the years 2010 and 2011. \n* It contains the information about the order itself: amount spent, what and how much was ordered and from which country.\n\n"

# %% [markdown]
# ####  What is the average purchase price?

# %%
# your code here
orders['amount_spent'].mean()
# Out:
# 22.39474850474768

# %% [markdown]
# #### What are the highest and lowest purchase prices?

# %%
# your code here
orders['amount_spent'].min()
# Out:
# 0.0

# %%
orders['amount_spent'].max()
# Out:
# 168469.6

# %% [markdown]
# #### Select all the customers from Spain.
# **Hint**: Remember that you are not asked to find orders from Spain but customers. A customer might have more than one order associated.

# %%
# your code here
orders_spain = orders.loc[orders['Country'] == 'Spain']
orders_spain['CustomerID'].unique()
# Out:
# array([12557, 17097, 12540, 12551, 12484, 12539, 12510, 12421, 12502,
#        12462, 12507, 12541, 12547, 12597, 12545, 12596, 12354, 12417,
#        12455, 12450, 12548, 12556, 12550, 12546, 12454, 12448, 12544,
#        12538, 12445, 12442], dtype=int64)

# %% [markdown]
# #### How many customers do we have in Spain?

# %%
# your code here
len(orders_spain['CustomerID'].unique())
# Out:
# 30

# %% [markdown]
# #### Select all the customers who have bought more than 50 items.
# **Hint**: Remember that you are not asked to find orders with more than 50 items but customers who bought more than 50 items. A customer with two orders of 30 items each should appear in the selection.

# %%
# your code here
quantity = orders.pivot_table(values='Quantity', index=['CustomerID', 'Country'], aggfunc='sum').reset_index()
quan_50 = quantity.loc[quantity['Quantity'] > 50]
quan_50
# Out:
#       CustomerID         Country  Quantity
# 0          12346  United Kingdom     74215
# 1          12347         Iceland      2458
# 2          12348         Finland      2341
# 3          12349           Italy       631
# 4          12350          Norway       197
# ...          ...             ...       ...
# 4341       18278  United Kingdom        66
# 4343       18281  United Kingdom        54
# 4344       18282  United Kingdom       103
# 4345       18283  United Kingdom      1397
# 4346       18287  United Kingdom      1586
#
# [4099 rows x 3 columns]

# %% [markdown]
# #### Select orders from Spain that include more than 50 items.

# %%
# your code here
spain_50 = quan_50.loc[quan_50['Country'] == 'Spain']
spain_50
# Out:
#       CustomerID Country  Quantity
# 7          12354   Spain       530
# 59         12417   Spain       267
# 62         12421   Spain       484
# 84         12442   Spain       182
# 86         12445   Spain        62
# 89         12448   Spain       243
# 91         12450   Spain       128
# 95         12454   Spain      1006
# 97         12455   Spain       566
# 103        12462   Spain       536
# 120        12484   Spain      2191
# 132        12502   Spain       820
# 135        12507   Spain       905
# 138        12510   Spain       353
# 161        12538   Spain       191
# 162        12539   Spain      2067
# 163        12540   Spain      6685
# 164        12541   Spain       680
# 165        12544   Spain       136
# 166        12545   Spain       523
# 167        12546   Spain       633
# 168        12547   Spain       134
# 170        12550   Spain       569
# 171        12551   Spain       100
# 174        12556   Spain       358
# 175        12557   Spain      4384
# ...

# %% [markdown]
# #### Select all free orders.

# %%
# your code here
free_orders = orders.loc[orders['amount_spent'] == 0]
free_orders
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 6914          9302     537197     22841  2010     12    7    14
# 22539        33576     539263     22580  2010     12    4    14
# 25379        40089     539722     22423  2010     12    2    13
# 29080        47068     540372     22090  2011      1    4    16
# 29082        47070     540372     22553  2011      1    4    16
# 34494        56674     541109     22168  2011      1    4    15
# 53788        86789     543599    84535B  2011      2    4    13
# 85671       130188     547417     22062  2011      3    3    10
# 92875       139453     548318     22055  2011      3    3    12
# 97430       145208     548871     22162  2011      4    1    14
# 107192      157042     550188     22636  2011      4    4    18
# 128641      187613     553000     47566  2011      5    4    15
# 137127      198383     554037     22619  2011      5    5    14
# 194648      279324     561284     22167  2011      7    2    12
# ...

# %% [markdown]
# #### Select all orders whose description starts with `lunch bag`.
# **Hint**: use string functions.

# %%
# your code here
starts_lunchbag = orders.loc[orders['Description'].str.startswith('lunch bag') == True]
starts_lunchbag
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 93              93     536378     20725  2010     12    3     9
# 172            174     536385     22662  2010     12    3     9
# 354            363     536401     22662  2010     12    3    11
# 359            368     536401     20725  2010     12    3    11
# 360            369     536401     22382  2010     12    3    11
# ...            ...        ...       ...   ...    ...  ...   ...
# 397465      540436     581486     23207  2011     12    5     9
# 397713      541695     581538     20727  2011     12    5    11
# 397714      541696     581538     20725  2011     12    5    11
# 397877      541862     581581     23681  2011     12    5    12
# 397880      541865     581583     20725  2011     12    5    12
#
#                         Description  Quantity          InvoiceDate  UnitPrice  \
# 93          lunch bag red retrospot        10  2010-12-01 09:37:00       1.65
# ...

# %% [markdown]
# #### Select all `lunch bag` orders made in 2011.

# %%
# your code here
starts_lunchbag_2011 = starts_lunchbag.loc[starts_lunchbag['year'] == 2011]
starts_lunchbag_2011
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 26340        42678     540015     20725  2011      1    2    11
# 26341        42679     540015     20726  2011      1    2    11
# 26512        42851     540023     22382  2011      1    2    12
# 26513        42852     540023     20726  2011      1    2    12
# 26860        43616     540098     22384  2011      1    2    15
# ...            ...        ...       ...   ...    ...  ...   ...
# 397465      540436     581486     23207  2011     12    5     9
# 397713      541695     581538     20727  2011     12    5    11
# 397714      541696     581538     20725  2011     12    5    11
# 397877      541862     581581     23681  2011     12    5    12
# 397880      541865     581583     20725  2011     12    5    12
#
#                         Description  Quantity          InvoiceDate  UnitPrice  \
# 26340       lunch bag red retrospot        10  2011-01-04 11:40:00       1.65
# ...

# %% [markdown]
# #### Show the frequency distribution of the amount spent in Spain.

# %%
# your code here
plt.figure(figsize=(15,7.5))
sns.set(color_codes=True)
sns.distplot(orders_spain['amount_spent'])

# %% [markdown]
# #### Select all orders made in the month of August.

# %%
# your code here
orders_aug = orders.loc[orders['month'] == 8]
orders_aug
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 199475      285421     561904     22075  2011      8    1     8
# 199476      285422     561904    85049E  2011      8    1     8
# 199477      285423     561905     21385  2011      8    1     9
# 199478      285424     561905    84970L  2011      8    1     9
# 199479      285425     561905    84970S  2011      8    1     9
# ...            ...        ...       ...   ...    ...  ...   ...
# 226483      320688     565067     22644  2011      8    3    17
# 226484      320689     565067     22645  2011      8    3    17
# 226485      320690     565067     22637  2011      8    3    17
# 226486      320691     565067     22646  2011      8    3    17
# 226487      320692     565067     22741  2011      8    3    17
#
#                                 Description  Quantity          InvoiceDate  \
# 199475         6 ribbons elegant christmas         96  2011-08-01 08:30:00
# ...

# %% [markdown]
# #### Find the number of orders made by each country in the month of August.
# **Hint**: Use value_counts().

# %%
# your code here
orders_aug['Country'].value_counts()
# Out:
# United Kingdom     23105
# Germany              795
# EIRE                 593
# France               569
# Netherlands          280
# Switzerland          267
# Spain                252
# Belgium              194
# Israel               171
# Channel Islands      140
# Australia            107
# Italy                 95
# Austria               88
# Norway                77
# Finland               61
# Malta                 55
# Portugal              41
# Sweden                40
# Unspecified           23
# Iceland               22
# Poland                17
# Denmark               16
# Canada                 5
# Name: Country, dtype: int64

# %% [markdown]
# #### What's the  average amount of money spent by country?

# %%
# your code here
orders.pivot_table(values='amount_spent', index=['Country'], aggfunc='mean')
# Out:
#                       amount_spent
# Country
# Australia               116.895620
# Austria                  25.624824
# Bahrain                  32.258824
# Belgium                  20.283772
# Brazil                   35.737500
# Canada                   24.280662
# Channel Islands          27.340160
# Cyprus                   22.134169
# Czech Republic           33.069600
# Denmark                  49.882474
# EIRE                     36.687745
# European Community       21.670833
# Finland                  32.913985
# France                   25.056827
# Germany                  25.311562
# Greece                   32.831172
# Iceland                  23.681319
# Israel                   29.119718
# Italy                    23.064960
# Japan                   116.561900
# Lebanon                  37.641778
# Lithuania                47.458857
# Malta                    24.335625
# Netherlands             120.798282
# Norway                   33.736418
# ...

# %% [markdown]
# #### What's the most expensive item?

# %%
# your code here
orders.loc[orders['UnitPrice'] == orders['UnitPrice'].max()]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour Description  \
# 118352      173382     551697      POST  2011      5    2    13     postage
#
#         Quantity          InvoiceDate  UnitPrice  CustomerID         Country  \
# 118352         1  2011-05-03 13:46:00    8142.75       16029  United Kingdom
#
#         amount_spent
# 118352       8142.75

# %% [markdown]
# #### What is the average amount spent per year?

# %%
# your code here
orders.pivot_table(values='amount_spent', index=['year'], aggfunc='mean')
# Out:
#       amount_spent
# year
# 2010     21.892733
# 2011     22.430074
