# %%
import numpy as np
import pandas as pd
from functools import reduce
from sqlalchemy import create_engine

# %%
#Twitter complaints on tourists in Amsterdam, geo-located Amsterdam city
Twitter= pd.read_csv('/Users/mac/Desktop/Newlabs/data_analytics062020/projects/Project 2 - Project Amsterdam/Test/Twitter.csv')
Twitter.head(2)
# Out:
#       DATE  Twitter mentions
# 0  2018-07                 0
# 1  2018-08              4563

# %%
#Originating & Destinating passengers. Those whose journey by air, starts or ends at Amsterdam Airport Schiphol.
Schipol=pd.read_csv('/Users/mac/Desktop/Newlabs/data_analytics062020/projects/Project 2 - Project Amsterdam/Test/Schipol.csv')
Schipol.head(2)
# Out:
#       DATE Schipol O&D
# 0  2018-01   2,897,577
# 1  2018-02   2,865,512

# %% [markdown]
# Other tried codes
# #bike.merge(weather[['DATE', 'AWND', 'SNOW', 'TAVG']], on='DATE')
# #data = pd.merge(Twitter, Schipol, on = 'DATE')
# #Twitter.merge(Schipol[['DATE', 'Schipol O&D']], on='DATE')
# #data=pd.merge(Twitter,Schipol[['DATE','Schipol O&D']],left_on='DATE',right_on='DATE',how='inner')
# #pd.merge(restaurant_ids_dataframe, restaurant_review_frame, on='business_id', how='outer')

# %%
insight=pd.merge(Twitter,Schipol,on='DATE',how='inner')
insight
# Out:
#        DATE  Twitter mentions Schipol O&D
# 0   2018-07                 0   4,386,076
# 1   2018-08              4563   4,497,488
# 2   2018-09              5996   4,073,062
# 3   2018-10              6874   4,132,718
# 4   2018-11              4487   3,316,203
# 5   2018-12              6520   3,163,052
# 6   2019-01              5102   2,981,899
# 7   2019-02              4153   2,981,844
# 8   2019-03              4330   3,571,422
# 9   2019-04              7261   4,025,536
# 10  2019-05              6234   4,237,293
# 11  2019-06              5639   4,159,562
# 12  2019-07              8347   4,427,091
# 13  2019-08              6194   4,495,169
# 14  2019-09              5834   4,153,928
# 15  2019-10              5759   4,161,063
# 16  2019-11              4338   3,353,744
# 17  2019-12              4255   3,259,261
# 18  2020-01              5653   3,011,207
# 19  2020-02              4919   3,011,143
# 20  2020-03              8269   1,498,230
# ...

# %%
pip install matplotlib
# Out:
# ...
#      |████████████████████████████████| 8.5 MB 5.8 MB/s eta 0:00:01
# ...
#   Using cached cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# ...
#   Using cached pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
# ...
#   Using cached kiwisolver-1.2.0-cp38-cp38-macosx_10_9_x86_64.whl (60 kB)
# ...
#      |████████████████████████████████| 156 kB 3.0 MB/s eta 0:00:01
# ...
#   Using cached Pillow-7.2.0-cp38-cp38-macosx_10_10_x86_64.whl (2.2 MB)
# ...
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2020.4.5.1
#     Uninstalling certifi-2020.4.5.1:
#       Successfully uninstalled certifi-2020.4.5.1
# ...
# WARNING: You are using pip version 20.1; however, version 20.2.2 is available.
# You should consider upgrading via the '/usr/local/Cellar/jupyterlab/2.1.2/libexec/bin/python3.8 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(Twitter, Schipol)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-327e6220e532> in <module>
# ----> 1 plt.plot(Twitter, Schipol)
#       2 plt.show()
#
# /usr/local/Cellar/jupyterlab/2.1.2/libexec/lib/python3.8/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2822 @_copy_docstring_and_deprecators(Axes.plot)
#    2823 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2824     return gca().plot(
#    2825         *args, scalex=scalex, scaley=scaley,
#    2826         **({"data": data} if data is not None else {}), **kwargs)
#
# /usr/local/Cellar/jupyterlab/2.1.2/libexec/lib/python3.8/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1741         """
#    1742         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# ...

# %%
insight.to_csv('insight.csv')
