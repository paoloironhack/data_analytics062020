# %%
import pandas as pd
import numpy as np
import  matplotlib as plt
import seaborn as sns

# %%
data = pd.read_csv('../data/thecure_discography.csv')
data.sample(5)
# Out:
#      Unnamed: 0               album_uri   album_name  \
# 119         137  3x1CmNdXWU0DzpTZXFFRZu         Wish
# 23           24  6SCYoeXeQjxbrioUozsvo1      The Top
# 147         165  0oi8Xnmhy3lMsSlpeoXvmP         Show
# 136         154  0oi8Xnmhy3lMsSlpeoXvmP         Show
# 5             6  33TDfmEXufojT6jxgb3BTK  Pornography
#
#                                              album_img album_release_date  \
# 119  https://i.scdn.co/image/5dff051e4d3c118f50e96a...         1992-04-21
# 23   https://i.scdn.co/image/40bb47fe5c869ed7f7f83b...         1984-04-30
# 147  https://i.scdn.co/image/7d4819d557b6f4ef5455a8...         1993-10-26
# 136  https://i.scdn.co/image/7d4819d557b6f4ef5455a8...         1993-10-26
# 5    https://i.scdn.co/image/fbec42025b461d54853ba6...         1982-05-03
#
#     album_release_year  album_popularity  \
# 119         1992-04-21                52
# 23          1984-04-30                28
# 147         1993-10-26                34
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'album_uri', 'album_name', 'album_img',
#        'album_release_date', 'album_release_year', 'album_popularity',
#        'track_name', 'track_uri', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'duration_ms', 'time_signature', 'key_mode',
#        'track_popularity'],
#       dtype='object')

# %%
df1 = data.drop(columns = ['Unnamed: 0', 'album_uri','album_img','track_uri'])
df1.sample(3)
# Out:
#                   album_name album_release_date album_release_year  \
# 191               4:13 Dream         2008-10-27         2008-10-27
# 207       Bestival Live 2011         2011-12-13         2011-12-13
# 63   Kiss Me Kiss Me Kiss Me         1987-05-25         1987-05-25
#
#      album_popularity                                  track_name  \
# 191                38                                The Only One
# 207                16   The End Of The World - Bestival Live 2011
# 63                 40  A Thousand Hours - 2006 Remastered Version
#
#      danceability  energy key  loudness   mode  speechiness  acousticness  \
# 191         0.564   0.900   D    -2.414  major       0.0401        0.0558
# 207         0.596   0.898   B    -5.413  minor       0.0831        0.0403
# 63          0.395   0.454   D    -8.657  major       0.0277        0.2130
#
#      instrumentalness  liveness  valence    tempo  duration_ms  \
# 191          0.001190     0.381    0.693  117.430       235360
# ...

# %% [markdown]
# Questions:
# Later albums are more popular albums
# Higher tempo songs are dancier
# Live albums are less popular than non live albums

# %%
df2 = df1.groupby(['album_name'])
df2[['album_name','album_release_year', 'album_popularity']].head(3)
# Out:
#                                        album_name album_release_year  \
# 0                                     Pornography         1982-05-03
# 1                                     Pornography         1982-05-03
# 2                                     Pornography         1982-05-03
# 8                                         The Top         1984-04-30
# 9                                         The Top         1984-04-30
# 10                                        The Top         1984-04-30
# 28                        Concert - The Cure Live         1984-10-22
# 29                        Concert - The Cure Live         1984-10-22
# 30                        Concert - The Cure Live         1984-10-22
# 38                           The Head On The Door         1985-08-26
# 39                           The Head On The Door         1985-08-26
# 40                           The Head On The Door         1985-08-26
# 48                        Kiss Me Kiss Me Kiss Me         1987-05-25
# ...

# %%
from datetime import datetime
df2['year'] = pd.to_datetime(df4['album_release_year'],format='%Y')
#df3 = df1.pivot_table(index = ['album_name', 'album_release_year'])
#df3[['album_popularity', 'album_release_year']].head(10)
#df4 = df3[['album_popularity']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'album_release_year'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-61-364b64600e23> in <module>()
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'album_release_year'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-60-772f491fc511> in <module>()
# ...

# %%
sns.scatterplot(x = 'album_popularity', y = 'album_release_year',data = df3)
