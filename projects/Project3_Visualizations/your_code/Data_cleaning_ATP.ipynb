# %%
import pandas as pd

# %%
# ATP file contains data from ATP matches from 1968-beginning 2019

tennis_df = pd.read_csv("ATP_cleaned.csv")

# %%
tennis_df.head()
# Out:
#    best_of  draw_size  l_1stIn  l_1stWon  l_2ndWon  l_SvGms  l_ace  l_bpFaced  \
# 0        5       64.0      NaN       NaN       NaN      NaN    NaN        NaN
# 1        5       64.0      NaN       NaN       NaN      NaN    NaN        NaN
# 2        5       64.0      NaN       NaN       NaN      NaN    NaN        NaN
# 3        5       64.0      NaN       NaN       NaN      NaN    NaN        NaN
# 4        5       64.0      NaN       NaN       NaN      NaN    NaN        NaN
#
#    l_bpSaved  l_df  ...  winner_age  winner_entry winner_hand winner_ht  \
# 0        NaN   NaN  ...         NaN           NaN           R       NaN
# 1        NaN   NaN  ...   27.520876           NaN           R       NaN
# 2        NaN   NaN  ...   16.216290           NaN           R       NaN
# 3        NaN   NaN  ...   22.264203           NaN           R       NaN
# 4        NaN   NaN  ...   29.861739           NaN           R       NaN
#
# ...

# %%
tennis_df.shape
# Out:
# (169690, 49)

# %%
# understand how many datapoints are available for columns/attributes

print(tennis_df.info())
tennis_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169690 entries, 0 to 169689
# Data columns (total 49 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   best_of             169690 non-null  int64
#  1   draw_size           1232 non-null    float64
#  2   l_1stIn             83415 non-null   float64
#  3   l_1stWon            83415 non-null   float64
#  4   l_2ndWon            83415 non-null   float64
#  5   l_SvGms             83415 non-null   float64
#  6   l_ace               83415 non-null   float64
#  7   l_bpFaced           83415 non-null   float64
#  8   l_bpSaved           83415 non-null   float64
#  9   l_df                83415 non-null   float64
#  10  l_svpt              83415 non-null   float64
#  11  loser_age           164700 non-null  float64
#  12  loser_entry         25339 non-null   object
#  13  loser_hand          169605 non-null  object
#  14  loser_ht            139052 non-null  float64
# ...

# %%
tennis_df.columns
# Out:
# Index(['best_of', 'draw_size', 'l_1stIn', 'l_1stWon', 'l_2ndWon', 'l_SvGms',
#        'l_ace', 'l_bpFaced', 'l_bpSaved', 'l_df', 'l_svpt', 'loser_age',
#        'loser_entry', 'loser_hand', 'loser_ht', 'loser_id', 'loser_ioc',
#        'loser_name', 'loser_rank', 'loser_rank_points', 'loser_seed',
#        'match_num', 'minutes', 'round', 'score', 'surface', 'tourney_date',
#        'tourney_id', 'tourney_level', 'tourney_name', 'w_1stIn', 'w_1stWon',
#        'w_2ndWon', 'w_SvGms', 'w_ace', 'w_bpFaced', 'w_bpSaved', 'w_df',
#        'w_svpt', 'winner_age', 'winner_entry', 'winner_hand', 'winner_ht',
#        'winner_id', 'winner_ioc', 'winner_name', 'winner_rank',
#        'winner_rank_points', 'winner_seed'],
#       dtype='object')

# %%
#last tournament in ATP csv is of 25 Feb 2019, check how many matches

tennis2019 = tennis_df[tennis_df.tourney_date == 20190225]

# %%
tennis2019.shape

#89 matches
# Out:
# (89, 49)

# %%
# load ATP matches of 2019

ATP2019 = pd.read_csv("atp_matches_2019.csv")

# %%
ATP2019.describe()
# Out:
#          draw_size  tourney_date    match_num      winner_id  winner_seed  \
# count  2781.000000  2.781000e+03  2781.000000    2781.000000  1110.000000
# mean     60.194175  2.019030e+07   288.857605  114459.656958     7.865766
# std      41.966238  1.635869e+03   218.471215   22544.410658     7.162484
# min       4.000000  2.018123e+07     1.000000  100644.000000     1.000000
# 25%      32.000000  2.019030e+07   247.000000  104926.000000     3.000000
# 50%      32.000000  2.019061e+07   279.000000  105732.000000     6.000000
# 75%     128.000000  2.019082e+07   291.000000  111442.000000    10.000000
# max     128.000000  2.019112e+07  1701.000000  209188.000000    33.000000
#
#          winner_ht   winner_age       loser_id  loser_seed     loser_ht  ...  \
# count  1588.000000  2780.000000    2781.000000  695.000000  1447.000000  ...
# mean    186.102015    27.691881  115186.033082    8.746763   185.810643  ...
# ...

# %%
ATP2019.columns
# Out:
# Index(['tourney_id', 'tourney_name', 'surface', 'draw_size', 'tourney_level',
#        'tourney_date', 'match_num', 'winner_id', 'winner_seed', 'winner_entry',
#        'winner_name', 'winner_hand', 'winner_ht', 'winner_ioc', 'winner_age',
#        'loser_id', 'loser_seed', 'loser_entry', 'loser_name', 'loser_hand',
#        'loser_ht', 'loser_ioc', 'loser_age', 'score', 'best_of', 'round',
#        'minutes', 'w_ace', 'w_df', 'w_svpt', 'w_1stIn', 'w_1stWon', 'w_2ndWon',
#        'w_SvGms', 'w_bpSaved', 'w_bpFaced', 'l_ace', 'l_df', 'l_svpt',
#        'l_1stIn', 'l_1stWon', 'l_2ndWon', 'l_SvGms', 'l_bpSaved', 'l_bpFaced',
#        'winner_rank', 'winner_rank_points', 'loser_rank', 'loser_rank_points'],
#       dtype='object')

# %%
#check of matches of last tournament are the same
tennis2019 = ATP2019[ATP2019.tourney_date == 20190225]

# %%
tennis2019.shape

# so yes also 89 matches
# Out:
# (89, 49)

# %%
ATP2019_cleaned = ATP2019.iloc[610:]

# %%
ATP2019_cleaned.head()
# Out:
#      best_of  draw_size  l_1stIn  l_1stWon  l_2ndWon  l_SvGms  l_ace  \
# 610        3        128     59.0      42.0      12.0     15.0    3.0
# 611        3        128     71.0      57.0      22.0     17.0   17.0
# 612        3        128      NaN       NaN       NaN      NaN    NaN
# 613        3        128      NaN       NaN       NaN      NaN    NaN
# 614        3        128     31.0      23.0       8.0      9.0    2.0
#
#      l_bpFaced  l_bpSaved  l_df  ...  winner_age  winner_entry winner_hand  \
# 610        4.0        1.0   2.0  ...   25.497604           NaN           R
# 611        3.0        2.0   5.0  ...   25.497604           NaN           R
# 612        NaN        NaN   NaN  ...   37.568789           NaN           R
# 613        NaN        NaN   NaN  ...   25.497604           NaN           R
# 614        3.0        1.0   1.0  ...   28.183436           NaN           R
#
#     winner_ht  winner_id  winner_ioc    winner_name winner_rank  \
# ...

# %%
#change order of columns to ATP csv
ATP2019_cleaned = ATP2019_cleaned[['best_of', 'draw_size', 'l_1stIn', 'l_1stWon', 'l_2ndWon', 'l_SvGms',
       'l_ace', 'l_bpFaced', 'l_bpSaved', 'l_df', 'l_svpt', 'loser_age',
       'loser_entry', 'loser_hand', 'loser_ht', 'loser_id', 'loser_ioc',
       'loser_name', 'loser_rank', 'loser_rank_points', 'loser_seed',
       'match_num', 'minutes', 'round', 'score', 'surface', 'tourney_date',
       'tourney_id', 'tourney_level', 'tourney_name', 'w_1stIn', 'w_1stWon',
       'w_2ndWon', 'w_SvGms', 'w_ace', 'w_bpFaced', 'w_bpSaved', 'w_df',
       'w_svpt', 'winner_age', 'winner_entry', 'winner_hand', 'winner_ht',
       'winner_id', 'winner_ioc', 'winner_name', 'winner_rank',
       'winner_rank_points', 'winner_seed']]

# %%
ATP2019_cleaned.head()
# Out:
#      best_of  draw_size  l_1stIn  l_1stWon  l_2ndWon  l_SvGms  l_ace  \
# 610        3        128     59.0      42.0      12.0     15.0    3.0
# 611        3        128     71.0      57.0      22.0     17.0   17.0
# 612        3        128      NaN       NaN       NaN      NaN    NaN
# 613        3        128      NaN       NaN       NaN      NaN    NaN
# 614        3        128     31.0      23.0       8.0      9.0    2.0
#
#      l_bpFaced  l_bpSaved  l_df  ...  winner_age  winner_entry winner_hand  \
# 610        4.0        1.0   2.0  ...   25.497604           NaN           R
# 611        3.0        2.0   5.0  ...   25.497604           NaN           R
# 612        NaN        NaN   NaN  ...   37.568789           NaN           R
# 613        NaN        NaN   NaN  ...   25.497604           NaN           R
# 614        3.0        1.0   1.0  ...   28.183436           NaN           R
#
#     winner_ht  winner_id  winner_ioc    winner_name winner_rank  \
# ...

# %%
ATP2019_cleaned.shape
# Out:
# (2171, 49)

# %%
ATP2020 = pd.read_csv("atp_matches_2020.csv")

# %%
ATP2020.head()
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 0  2020-8888      Atp Cup    Hard         24             A      20200106
# 1  2020-8888      Atp Cup    Hard         24             A      20200106
# 2  2020-8888      Atp Cup    Hard         24             A      20200106
# 3  2020-8888      Atp Cup    Hard         24             A      20200106
# 4  2020-8888      Atp Cup    Hard         24             A      20200106
#
#    match_num  winner_id  winner_seed winner_entry  ... l_1stIn l_1stWon  \
# 0        300     104925          NaN          NaN  ...    51.0     39.0
# 1        299     105138          NaN          NaN  ...    35.0     21.0
# 2        298     104925          NaN          NaN  ...    57.0     35.0
# 3        297     105583          NaN          NaN  ...    54.0     39.0
# 4        296     104745          NaN          NaN  ...    55.0     37.0
#
#    l_2ndWon l_SvGms  l_bpSaved  l_bpFaced  winner_rank winner_rank_points  \
# ...

# %%
ATP2020_cleaned.shape
# Out:
# (638, 49)

# %%
#tournaments until march 2020
ATP2020_cleaned = ATP2020.iloc[:638]

# %%
ATP2020_cleaned.tail()
# Out:
#     tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 633  2020-8996     Santiago    Clay         32             A      20200224
# 634  2020-8996     Santiago    Clay         32             A      20200224
# 635  2020-8996     Santiago    Clay         32             A      20200224
# 636  2020-8996     Santiago    Clay         32             A      20200224
# 637  2020-8996     Santiago    Clay         32             A      20200224
#
#      match_num  winner_id  winner_seed winner_entry  ... l_1stIn l_1stWon  \
# 633        276     106148          NaN          NaN  ...    69.0     45.0
# 634        275     122669          NaN           LL  ...    24.0     15.0
# 635        273     105643          7.0          NaN  ...    35.0     22.0
# 636        272     106099          NaN          NaN  ...    26.0     17.0
# 637        271     126214          NaN           WC  ...    36.0     24.0
#
# ...

# %%
#change order of columns to ATP csv
ATP2020_cleaned = ATP2020_cleaned[['best_of', 'draw_size', 'l_1stIn', 'l_1stWon', 'l_2ndWon', 'l_SvGms',
       'l_ace', 'l_bpFaced', 'l_bpSaved', 'l_df', 'l_svpt', 'loser_age',
       'loser_entry', 'loser_hand', 'loser_ht', 'loser_id', 'loser_ioc',
       'loser_name', 'loser_rank', 'loser_rank_points', 'loser_seed',
       'match_num', 'minutes', 'round', 'score', 'surface', 'tourney_date',
       'tourney_id', 'tourney_level', 'tourney_name', 'w_1stIn', 'w_1stWon',
       'w_2ndWon', 'w_SvGms', 'w_ace', 'w_bpFaced', 'w_bpSaved', 'w_df',
       'w_svpt', 'winner_age', 'winner_entry', 'winner_hand', 'winner_ht',
       'winner_id', 'winner_ioc', 'winner_name', 'winner_rank',
       'winner_rank_points', 'winner_seed']]

# %%
#combine dataframes of ATP with 2019 and 2020
ATP_with2019 = pd.concat([tennis_df, ATP2019_cleaned], ignore_index=True)

#example code: df_row = pd.concat([df1, df2], ignore_index=True)

# %%
ATP_with2019.shape
# Out:
# (171861, 49)

# %%
ATP_with20192020 = pd.concat([ATP_with2019, ATP2020_cleaned], ignore_index=True)

# %%
ATP_with20192020.shape
# Out:
# (172499, 49)

# %%
ATP_with20192020.to_csv('ATP_complete.csv', sep = ',', index = False)
