# %%
pip install dbfread
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from dbfread import DBF

# %%
for record in DBF('WONINGWAARDE_2002_region.dbf'):
    print(record)
# Out:
# OrderedDict([('Lower', 2500.0), ('Upper', 3000.0), ('LABEL', '2500 - 3000'), ('SELECTIE', '2500'), ('FILTER', '2002')])
# OrderedDict([('Lower', 2500.0), ('Upper', 3000.0), ('LABEL', '2500 - 3000'), ('SELECTIE', '2500'), ('FILTER', '2002')])
# OrderedDict([('Lower', 2500.0), ('Upper', 3000.0), ('LABEL', '2500 - 3000'), ('SELECTIE', '2500'), ('FILTER', '2002')])
# OrderedDict([('Lower', 2500.0), ('Upper', 3000.0), ('LABEL', '2500 - 3000'), ('SELECTIE', '2500'), ('FILTER', '2002')])
# OrderedDict([('Lower', 2500.0), ('Upper', 3000.0), ('LABEL', '2500 - 3000'), ('SELECTIE', '2500'), ('FILTER', '2002')])
# OrderedDict([('Lower', 2500.0), ('Upper', 3000.0), ('LABEL', '2500 - 3000'), ('SELECTIE', '2500'), ('FILTER', '2002')])
# OrderedDict([('Lower', 2500.0), ('Upper', 3000.0), ('LABEL', '2500 - 3000'), ('SELECTIE', '2500'), ('FILTER', '2002')])
# OrderedDict([('Lower', 2500.0), ('Upper', 3000.0), ('LABEL', '2500 - 3000'), ('SELECTIE', '2500'), ('FILTER', '2002')])
# ...
