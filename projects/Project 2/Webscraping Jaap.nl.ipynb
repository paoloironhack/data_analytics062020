# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.jaap.nl/koophuizen/utrecht/utrecht/utrecht'
page = requests.get(url)
page.status_code
# Out:
# 200

# %%
page.content
# Out:
# b'\r\n<!DOCTYPE html>\r\n<!--[if lt IE 7]> <html lang="nl" class="no-js ie6 oldie"> <![endif]-->\r\n<!--[if IE 7]>    <html lang="nl" class="no-js ie7 oldie"> <![endif]-->\r\n<!--[if IE 8]>    <html lang="nl" class="no-js ie8 oldie"> <![endif]-->\r\n<!--[if IE 9]>    <html lang="nl" class="no-js ie9"> <![endif]-->\r\n<!--[if gt IE 9]><!-->\r\n<html class=\'no-js\' lang=\'nl\'>\r\n<!--<![endif]-->\r\n<head>\r\n    <meta name="viewport" content="width=device-width, initial-scale=1.0" />\r\n    <!-- Deze site is gemaakt door JAAP.NL BV -->\r\n    <!-- info[at]jaap.nl -->\r\n    <!-- Server: HURRICANE -->\r\n    <title>Huizen te koop in Utrecht - Koopwoningen Utrecht [JAAP.NL]</title>\r\n        <link rel="canonical" href="https://www.jaap.nl/koophuizen/utrecht" />\r\n            <link rel="alternate" media="only screen and (max-width: 640px)" href="https://m.jaap.nl/koophuizen/utrecht">\r\n            <link rel="next" href="/koophuizen/utrecht/p2" />\r\n        <link href=\'https://font
# ...

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(page.content)
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]> <html lang="nl" class="no-js ie6 oldie"> <![endif]--><!--[if IE 7]>    <html lang="nl" class="no-js ie7 oldie"> <![endif]--><!--[if IE 8]>    <html lang="nl" class="no-js ie8 oldie"> <![endif]--><!--[if IE 9]>    <html lang="nl" class="no-js ie9"> <![endif]--><!--[if gt IE 9]><!--><html class="no-js" lang="nl">
# <!--<![endif]-->
# <head>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <!-- Deze site is gemaakt door JAAP.NL BV -->
# <!-- info[at]jaap.nl -->
# <!-- Server: HURRICANE -->
# <title>Huizen te koop in Utrecht - Koopwoningen Utrecht [JAAP.NL]</title>
# <link href="https://www.jaap.nl/koophuizen/utrecht" rel="canonical"/>
# <link href="https://m.jaap.nl/koophuizen/utrecht" media="only screen and (max-width: 640px)" rel="alternate"/>
# <link href="/koophuizen/utrecht/p2" rel="next"/>
# <link href="https://fonts.googleapis.com/css?family=Open+Sans:300,400,600,700,800" rel="stylesheet" type="text/css"/>
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]> <html lang="nl" class="no-js ie6 oldie"> <![endif]-->
# <!--[if IE 7]>    <html lang="nl" class="no-js ie7 oldie"> <![endif]-->
# <!--[if IE 8]>    <html lang="nl" class="no-js ie8 oldie"> <![endif]-->
# <!--[if IE 9]>    <html lang="nl" class="no-js ie9"> <![endif]-->
# <!--[if gt IE 9]><!-->
# <html class="no-js" lang="nl">
#  <!--<![endif]-->
#  <head>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <!-- Deze site is gemaakt door JAAP.NL BV -->
#   <!-- info[at]jaap.nl -->
#   <!-- Server: HURRICANE -->
#   <title>
#    Huizen te koop in Utrecht - Koopwoningen Utrecht [JAAP.NL]
#   </title>
#   <link href="https://www.jaap.nl/koophuizen/utrecht" rel="canonical"/>
#   <link href="https://m.jaap.nl/koophuizen/utrecht" media="only screen and (max-width: 640px)" rel="alternate"/>
#   <link href="/koophuizen/utrecht/p2" rel="next"/>
# ...
