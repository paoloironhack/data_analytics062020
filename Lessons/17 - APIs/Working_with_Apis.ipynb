# %% [markdown]
# # Working with APIs

# %% [markdown]
# ## Introduction

# %% [markdown]
# So far we have learnt how to obtain data from files and from relational databases.

# %% [markdown]
# However, sometimes the data we need is not readily available via one of these two data sources. In some cases, the data we need may be contained within an *application*.

# %% [markdown]
# Application owners will often create APIs **(or Application Programming Interface)** so that their applications can talk to other applications.

# %% [markdown]
# An **API is a set of programmatic instructions for accessing software applications, and the data that comes from APIs typically contains some sort of structure (such as JSON).**

# %% [markdown]
# This structure makes working with API data preferable to crawling websites and scraping content off of web pages.

# %% [markdown]
# In this lesson, we are going to learn:
#
# - How to make API calls to an application;
# - Retrieve data in JSON format;
# - Learn about API authentication;
# - and use Python libraries to obtain data from APIs.

# %% [markdown]
# ## APIs in General

# %%
from IPython.display import YouTubeVideo

YouTubeVideo('OVvTv9Hy91Q', width=800, height=400)

# %% [markdown]
# ## Simple API Example Requests

# %% [markdown]
# There are a few libraries that can be used for working with APIs in Python, but the Requests library is one of the most intuitive. It has a get() method that allows you to send an HTTP request to an application and receive a response.

# %%
import json
import requests

response = requests.get('https://jsonplaceholder.typicode.com/todos')
results = response.json() 
#response

# %% [markdown]
# In this example, we used the get method to send a request to the JSONPlaceholder API, and we received a response in the form of JSON structured data.

# %% [markdown]
# We can now convert these results into a data frame.

# %%
import pandas as pd

data = pd.DataFrame(results)
data.head(10)
# Out:
#    userId  id                                              title  completed
# 0       1   1                                 delectus aut autem      False
# 1       1   2                 quis ut nam facilis et officia qui      False
# 2       1   3                                fugiat veniam minus      False
# 3       1   4                                   et porro tempora       True
# 4       1   5  laboriosam mollitia et enim quasi adipisci qui...      False
# 5       1   6  qui ullam ratione quibusdam voluptatem quia omnis      False
# 6       1   7                  illo expedita consequatur quia in      False
# 7       1   8                       quo adipisci enim quam ut ab       True
# 8       1   9                        molestiae perspiciatis ipsa      False
# 9       1  10       illo est ratione doloremque quia maiores aut       True

# %% [markdown]
# ### StackAPI

# %% [markdown]
# Let's now look at a more realistic example of an API.

# %%
# Import StackAPI
from stackapi import StackAPI

# %%
# from stackapi import StackAPI
stack_api = StackAPI('stackoverflow')
questions = stack_api.fetch('questions')

# %%
questions = pd.DataFrame(questions)
questions.head(10)
# Out:
#    backoff  has_more  page  quota_max  quota_remaining  total  \
# 0        0      True     5        300              300      0
# 1        0      True     5        300              300      0
# 2        0      True     5        300              300      0
# 3        0      True     5        300              300      0
# 4        0      True     5        300              300      0
# 5        0      True     5        300              300      0
# 6        0      True     5        300              300      0
# 7        0      True     5        300              300      0
# 8        0      True     5        300              300      0
# 9        0      True     5        300              300      0
#
#                                                items
# 0  {'tags': ['python', 'testing', 'subprocess'], ...
# 1  {'tags': ['javascript', 'vue.js', 'validation'...
# 2  {'tags': ['python', 'regex', 'pandas'], 'owner...
# 3  {'tags': ['docker', '.net-core', 'raspberry-pi...
# 4  {'tags': ['linux', 'awk', 'command'], 'owner':...
# 5  {'tags': ['user-interface', 'user-experience',...
# 6  {'tags': ['graphql', 'svelte', 'sapper'], 'own...
# 7  {'tags': ['javascript', 'html'], 'owner': {'re...
# 8  {'tags': ['neo4j', 'cypher'], 'owner': {'reput...
# 9  {'tags': ['ruby', 'rspec', 'selenium-chromedri...

# %%
questions['items'][0]
# Out:
# {'tags': ['python', 'testing', 'subprocess'],
#  'owner': {'reputation': 1076,
#   'user_id': 8866053,
#   'user_type': 'registered',
#   'accept_rate': 100,
#   'profile_image': 'https://i.stack.imgur.com/Q1QZv.jpg?s=128&g=1',
#   'display_name': 'CtrlAltF2',
#   'link': 'https://stackoverflow.com/users/8866053/ctrlaltf2'},
#  'is_answered': False,
#  'view_count': 8,
#  'answer_count': 1,
#  'score': 0,
#  'last_activity_date': 1596733889,
#  'creation_date': 1596732804,
#  'last_edit_date': 1596733233,
#  'question_id': 63288357,
#  'content_license': 'CC BY-SA 4.0',
#  'link': 'https://stackoverflow.com/questions/63288357/subprocess-run-leads-to-space-interpreted-as-arg',
#  'title': 'subprocess.run leads to space interpreted as arg?'}

# %% [markdown]
# ## More Complex API Requests

# %% [markdown]
# Sometimes API responses contain data that is nested, and we must find a way to **flatten** the JSON data so that it fits nicely into a data frame. To see this, let us make a call to the GitHub API.

# %% [markdown]
# ### GithubAPI

# %% [markdown]
# Let's now make an API call to the Github public API, create a Pandas data frame from the results, and examine the structure of the data.

# %%
response = requests.get('https://api.github.com/events')

data = pd.DataFrame(response.json()) 
data.head(10)
# Out:
#             id                           type  \
# 0  13131572881                    CreateEvent
# 1  13131572876                      PushEvent
# 2  13131572868                      PushEvent
# 3  13131572860                      PushEvent
# 4  13131572843                      PushEvent
# 5  13131572852               PullRequestEvent
# 6  13131572849                    MemberEvent
# 7  13131572834  PullRequestReviewCommentEvent
# 8  13131572832                      PushEvent
# 9  13131572820                      PushEvent
#
#                                                actor  \
# 0  {'id': 20477746, 'login': 'santhoshramanathan'...
# 1  {'id': 29139614, 'login': 'renovate[bot]', 'di...
# 2  {'id': 7911893, 'login': 'slskopytko', 'displa...
# 3  {'id': 67704827, 'login': 'ctutiya', 'display_...
# 4  {'id': 1748530, 'login': 'antonyantony', 'disp...
# 5  {'id': 27856297, 'login': 'dependabot-preview[...
# 6  {'id': 68732767, 'login': 'iiitnprobe', 'displ...
# 7  {'id': 2251653, 'login': 'adrian-prantl', 'dis...
# 8  {'id': 21154424, 'login': 'q375ml', 'display_l...
# 9  {'id': 11172640, 'login': 'mengjutsai', 'displ...
#
#                                                 repo  \
# 0  {'id': 285277549, 'name': 'santhoshramanathan/...
# 1  {'id': 146916092, 'name': 'commercetools/ui-ki...
# 2  {'id': 285627963, 'name': 'Chrzaszczyzewoszyce...
# 3  {'id': 285628440, 'name': 'ctutiya/joshbersin'...
# 4  {'id': 89720418, 'name': 'antonyantony/libresw...
# 5  {'id': 87125103, 'name': 'nypublicradio/nypr-a...
# 6  {'id': 282615733, 'name': 'iiitnprobe/iiitnpro...
# 7  {'id': 44838949, 'name': 'apple/swift', 'url':...
# 8  {'id': 138178056, 'name': 'q375ml/PEGGY-PORTFO...
# 9  {'id': 285614403, 'name': 'mengjutsai/tutorial...
#
#                                              payload  public  \
# 0  {'ref': '0.0.1-oneclk-frntend-chart.8', 'ref_t...    True
# 1  {'push_id': 5492236582, 'size': 2, 'distinct_s...    True
# 2  {'push_id': 5492236577, 'size': 1, 'distinct_s...    True
# 3  {'push_id': 5492236575, 'size': 1, 'distinct_s...    True
# 4  {'push_id': 5492236564, 'size': 1, 'distinct_s...    True
# 5  {'action': 'opened', 'number': 106, 'pull_requ...    True
# 6  {'member': {'login': 'Hemanshu68', 'id': 61977...    True
# 7  {'action': 'created', 'comment': {'url': 'http...    True
# 8  {'push_id': 5492236560, 'size': 1, 'distinct_s...    True
# 9  {'push_id': 5492236548, 'size': 1, 'distinct_s...    True
#
#              created_at                                                org
# 0  2020-08-06T17:15:53Z                                                NaN
# 1  2020-08-06T17:15:53Z  {'id': 1084585, 'login': 'commercetools', 'gra...
# 2  2020-08-06T17:15:53Z  {'id': 13028066, 'login': 'Chrzaszczyzewoszyce...
# 3  2020-08-06T17:15:53Z                                                NaN
# 4  2020-08-06T17:15:53Z                                                NaN
# 5  2020-08-06T17:15:53Z  {'id': 1070797, 'login': 'nypublicradio', 'gra...
# 6  2020-08-06T17:15:53Z                                                NaN
# 7  2020-08-06T17:15:52Z  {'id': 10639145, 'login': 'apple', 'gravatar_i...
# 8  2020-08-06T17:15:53Z                                                NaN
# 9  2020-08-06T17:15:53Z                                                NaN

# %% [markdown]
# Since many of the columns are nested, we are going to do the following:
#
# - Turn the nested dictionaries into a data frame with a column for each key;
# - Assign column names to each column in this new data frame;
# - Add these new columns to the original data frame;
# - Drop the column with the nested dictionaries.

# %% [markdown]
# ### More Complex API Requests: One Column

# %%
# select the data['actor'] column
data['actor']
# Out:
# 0     {'id': 20477746, 'login': 'santhoshramanathan'...
# 1     {'id': 29139614, 'login': 'renovate[bot]', 'di...
# 2     {'id': 7911893, 'login': 'slskopytko', 'displa...
# 3     {'id': 67704827, 'login': 'ctutiya', 'display_...
# 4     {'id': 1748530, 'login': 'antonyantony', 'disp...
# 5     {'id': 27856297, 'login': 'dependabot-preview[...
# 6     {'id': 68732767, 'login': 'iiitnprobe', 'displ...
# 7     {'id': 2251653, 'login': 'adrian-prantl', 'dis...
# 8     {'id': 21154424, 'login': 'q375ml', 'display_l...
# 9     {'id': 11172640, 'login': 'mengjutsai', 'displ...
# 10    {'id': 50760049, 'login': 'nive927', 'display_...
# 11    {'id': 27856297, 'login': 'dependabot-preview[...
# 12    {'id': 2266860, 'login': 'hellifiknow', 'displ...
# 13    {'id': 1864323, 'login': 'stripe-ci', 'display...
# 14    {'id': 4990456, 'login': 'litespeedtech', 'dis...
# 15    {'id': 7726127, 'login': 'kwsutter', 'display_...
# 16    {'id': 16691757, 'login': 'felipeblazing', 'di...
# 17    {'id': 68343783, 'login': 'yonzmeer', 'display...
# 18    {'id': 7144781, 'login': 'aoterodelaroza', 'di...
# 19    {'id': 32226730, 'login': 'dmitrykosykh', 'dis...
# 20    {'id': 35613825, 'login': 'vercel[bot]', 'disp...
# 21    {'id': 68934996, 'login': 'IvanM117', 'display...
# 22    {'id': 41898282, 'login': 'github-actions[bot]...
# 23    {'id': 3455449, 'login': 'Dids', 'display_logi...
# 24    {'id': 62543621, 'login': 'llvm-premerge-tests...
# 25    {'id': 18289117, 'login': 'kleitonkltn', 'disp...
# 26    {'id': 58181, 'login': 'lkramer', 'display_log...
# 27    {'id': 63174725, 'login': 'gethiskg', 'display...
# 28    {'id': 43582323, 'login': 'Shijokingo', 'displ...
# 29    {'id': 55092420, 'login': 'jacobdonais', 'disp...
# Name: actor, dtype: object

# %%
# convert the data['actor'] column to a dictionary
dict(data['actor'])
# Out:
# {0: {'id': 20477746,
#   'login': 'santhoshramanathan',
#   'display_login': 'santhoshramanathan',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/santhoshramanathan',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/20477746?'},
#  1: {'id': 29139614,
#   'login': 'renovate[bot]',
#   'display_login': 'renovate',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/renovate[bot]',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/29139614?'},
#  2: {'id': 7911893,
#   'login': 'slskopytko',
#   'display_login': 'slskopytko',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/slskopytko',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/7911893?'},
#  3: {'id': 67704827,
#   'login': 'ctutiya',
#   'display_login': 'ctutiya',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/ctutiya',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/67704827?'},
#  4: {'id': 1748530,
#   'login': 'antonyantony',
#   'display_login': 'antonyantony',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/antonyantony',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/1748530?'},
#  5: {'id': 27856297,
#   'login': 'dependabot-preview[bot]',
#   'display_login': 'dependabot-preview',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/dependabot-preview[bot]',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/27856297?'},
#  6: {'id': 68732767,
#   'login': 'iiitnprobe',
#   'display_login': 'iiitnprobe',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/iiitnprobe',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/68732767?'},
#  7: {'id': 2251653,
#   'login': 'adrian-prantl',
#   'display_login': 'adrian-prantl',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/adrian-prantl',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/2251653?'},
#  8: {'id': 21154424,
#   'login': 'q375ml',
#   'display_login': 'q375ml',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/q375ml',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/21154424?'},
#  9: {'id': 11172640,
#   'login': 'mengjutsai',
#   'display_login': 'mengjutsai',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/mengjutsai',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/11172640?'},
#  10: {'id': 50760049,
#   'login': 'nive927',
#   'display_login': 'nive927',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/nive927',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/50760049?'},
#  11: {'id': 27856297,
#   'login': 'dependabot-preview[bot]',
#   'display_login': 'dependabot-preview',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/dependabot-preview[bot]',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/27856297?'},
#  12: {'id': 2266860,
#   'login': 'hellifiknow',
#   'display_login': 'hellifiknow',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/hellifiknow',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/2266860?'},
#  13: {'id': 1864323,
#   'login': 'stripe-ci',
#   'display_login': 'stripe-ci',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/stripe-ci',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/1864323?'},
#  14: {'id': 4990456,
#   'login': 'litespeedtech',
#   'display_login': 'litespeedtech',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/litespeedtech',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/4990456?'},
#  15: {'id': 7726127,
#   'login': 'kwsutter',
#   'display_login': 'kwsutter',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/kwsutter',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/7726127?'},
#  16: {'id': 16691757,
#   'login': 'felipeblazing',
#   'display_login': 'felipeblazing',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/felipeblazing',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/16691757?'},
#  17: {'id': 68343783,
#   'login': 'yonzmeer',
#   'display_login': 'yonzmeer',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/yonzmeer',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/68343783?'},
#  18: {'id': 7144781,
#   'login': 'aoterodelaroza',
#   'display_login': 'aoterodelaroza',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/aoterodelaroza',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/7144781?'},
#  19: {'id': 32226730,
#   'login': 'dmitrykosykh',
#   'display_login': 'dmitrykosykh',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/dmitrykosykh',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/32226730?'},
#  20: {'id': 35613825,
#   'login': 'vercel[bot]',
#   'display_login': 'vercel',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/vercel[bot]',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/35613825?'},
#  21: {'id': 68934996,
#   'login': 'IvanM117',
#   'display_login': 'IvanM117',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/IvanM117',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/68934996?'},
#  22: {'id': 41898282,
#   'login': 'github-actions[bot]',
#   'display_login': 'github-actions',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/github-actions[bot]',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#  23: {'id': 3455449,
#   'login': 'Dids',
#   'display_login': 'Dids',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/Dids',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/3455449?'},
#  24: {'id': 62543621,
#   'login': 'llvm-premerge-tests-bot',
#   'display_login': 'llvm-premerge-tests-bot',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/llvm-premerge-tests-bot',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/62543621?'},
#  25: {'id': 18289117,
#   'login': 'kleitonkltn',
#   'display_login': 'kleitonkltn',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/kleitonkltn',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/18289117?'},
#  26: {'id': 58181,
#   'login': 'lkramer',
#   'display_login': 'lkramer',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/lkramer',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/58181?'},
#  27: {'id': 63174725,
#   'login': 'gethiskg',
#   'display_login': 'gethiskg',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/gethiskg',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/63174725?'},
#  28: {'id': 43582323,
#   'login': 'Shijokingo',
#   'display_login': 'Shijokingo',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/Shijokingo',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/43582323?'},
#  29: {'id': 55092420,
#   'login': 'jacobdonais',
#   'display_login': 'jacobdonais',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/jacobdonais',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/55092420?'}}

# %%
# create a new data frame 
flatten = pd.DataFrame(dict(data['actor']))
flatten.head()
# Out:
#                                                             0   \
# id                                                    20477746
# login                                       santhoshramanathan
# display_login                               santhoshramanathan
# gravatar_id
# url            https://api.github.com/users/santhoshramanathan
#
#                                                        1   \
# id                                               29139614
# login                                       renovate[bot]
# display_login                                    renovate
# gravatar_id
# url            https://api.github.com/users/renovate[bot]
#
#                                                     2   \
# id                                             7911893
# login                                       slskopytko
# display_login                               slskopytko
# gravatar_id
# url            https://api.github.com/users/slskopytko
#
#                                                  3   \
# id                                         67704827
# login                                       ctutiya
# display_login                               ctutiya
# gravatar_id
# url            https://api.github.com/users/ctutiya
#
#                                                       4   \
# id                                               1748530
# login                                       antonyantony
# display_login                               antonyantony
# gravatar_id
# url            https://api.github.com/users/antonyantony
#
#                                                               5   \
# id                                                      27856297
# login                                    dependabot-preview[bot]
# display_login                                 dependabot-preview
# gravatar_id
# url            https://api.github.com/users/dependabot-previe...
#
#                                                     6   \
# id                                            68732767
# login                                       iiitnprobe
# display_login                               iiitnprobe
# gravatar_id
# url            https://api.github.com/users/iiitnprobe
#
#                                                        7   \
# id                                                2251653
# login                                       adrian-prantl
# display_login                               adrian-prantl
# gravatar_id
# url            https://api.github.com/users/adrian-prantl
#
#                                                 8   \
# id                                        21154424
# login                                       q375ml
# display_login                               q375ml
# gravatar_id
# url            https://api.github.com/users/q375ml
#
#                                                     9   ...  \
# id                                            11172640  ...
# login                                       mengjutsai  ...
# display_login                               mengjutsai  ...
# gravatar_id                                             ...
# url            https://api.github.com/users/mengjutsai  ...
#
#                                                      20  \
# id                                             35613825
# login                                       vercel[bot]
# display_login                                    vercel
# gravatar_id
# url            https://api.github.com/users/vercel[bot]
#
#                                                   21  \
# id                                          68934996
# login                                       IvanM117
# display_login                               IvanM117
# gravatar_id
# url            https://api.github.com/users/IvanM117
#
#                                                              22  \
# id                                                     41898282
# login                                       github-actions[bot]
# display_login                                    github-actions
# gravatar_id
# url            https://api.github.com/users/github-actions[bot]
#
#                                               23  \
# id                                       3455449
# login                                       Dids
# display_login                               Dids
# gravatar_id
# url            https://api.github.com/users/Dids
#
#                                                               24  \
# id                                                      62543621
# login                                    llvm-premerge-tests-bot
# display_login                            llvm-premerge-tests-bot
# gravatar_id
# url            https://api.github.com/users/llvm-premerge-tes...
#
#                                                      25  \
# id                                             18289117
# login                                       kleitonkltn
# display_login                               kleitonkltn
# gravatar_id
# url            https://api.github.com/users/kleitonkltn
#
#                                                  26  \
# id                                            58181
# login                                       lkramer
# display_login                               lkramer
# gravatar_id
# url            https://api.github.com/users/lkramer
#
#                                                   27  \
# id                                          63174725
# login                                       gethiskg
# display_login                               gethiskg
# gravatar_id
# url            https://api.github.com/users/gethiskg
#
#                                                     28  \
# id                                            43582323
# login                                       Shijokingo
# display_login                               Shijokingo
# gravatar_id
# url            https://api.github.com/users/Shijokingo
#
#                                                      29
# id                                             55092420
# login                                       jacobdonais
# display_login                               jacobdonais
# gravatar_id
# url            https://api.github.com/users/jacobdonais
#
# [5 rows x 30 columns]

# %%
# transpose flatten

flatten = pd.DataFrame(dict(data['actor'])).transpose()
flatten.head()
# Out:
#          id               login       display_login gravatar_id  \
# 0  20477746  santhoshramanathan  santhoshramanathan
# 1  29139614       renovate[bot]            renovate
# 2   7911893          slskopytko          slskopytko
# 3  67704827             ctutiya             ctutiya
# 4   1748530        antonyantony        antonyantony
#
#                                                url  \
# 0  https://api.github.com/users/santhoshramanathan
# 1       https://api.github.com/users/renovate[bot]
# 2          https://api.github.com/users/slskopytko
# 3             https://api.github.com/users/ctutiya
# 4        https://api.github.com/users/antonyantony
#
#                                           avatar_url
# 0  https://avatars.githubusercontent.com/u/20477746?
# 1  https://avatars.githubusercontent.com/u/29139614?
# 2   https://avatars.githubusercontent.com/u/7911893?
# 3  https://avatars.githubusercontent.com/u/67704827?
# 4   https://avatars.githubusercontent.com/u/1748530?

# %%
# save the columns as strings

columns = [str(i) for i in flatten.columns]
columns
# Out:
# ['id', 'login', 'display_login', 'gravatar_id', 'url', 'avatar_url']

# %%
# rename the columns for actor
# ['id', 'login', 'display_login', 'gravatar_id', 'url', 'avatar_url']

flatten.columns = ['actor' + '_' + colname for colname in columns]
flatten.columns
# Out:
# Index(['actor_id', 'actor_login', 'actor_display_login', 'actor_gravatar_id',
#        'actor_url', 'actor_avatar_url'],
#       dtype='object')

# %%
# add flatten to data using pd.concat

data = pd.concat([data, flatten], axis=1)
data.head()
# Out:
#             id         type  \
# 0  13131572881  CreateEvent
# 1  13131572876    PushEvent
# 2  13131572868    PushEvent
# 3  13131572860    PushEvent
# 4  13131572843    PushEvent
#
#                                                actor  \
# 0  {'id': 20477746, 'login': 'santhoshramanathan'...
# 1  {'id': 29139614, 'login': 'renovate[bot]', 'di...
# 2  {'id': 7911893, 'login': 'slskopytko', 'displa...
# 3  {'id': 67704827, 'login': 'ctutiya', 'display_...
# 4  {'id': 1748530, 'login': 'antonyantony', 'disp...
#
#                                                 repo  \
# 0  {'id': 285277549, 'name': 'santhoshramanathan/...
# 1  {'id': 146916092, 'name': 'commercetools/ui-ki...
# 2  {'id': 285627963, 'name': 'Chrzaszczyzewoszyce...
# 3  {'id': 285628440, 'name': 'ctutiya/joshbersin'...
# 4  {'id': 89720418, 'name': 'antonyantony/libresw...
#
#                                              payload  public  \
# 0  {'ref': '0.0.1-oneclk-frntend-chart.8', 'ref_t...    True
# 1  {'push_id': 5492236582, 'size': 2, 'distinct_s...    True
# 2  {'push_id': 5492236577, 'size': 1, 'distinct_s...    True
# 3  {'push_id': 5492236575, 'size': 1, 'distinct_s...    True
# 4  {'push_id': 5492236564, 'size': 1, 'distinct_s...    True
#
#              created_at                                                org  \
# 0  2020-08-06T17:15:53Z                                                NaN
# 1  2020-08-06T17:15:53Z  {'id': 1084585, 'login': 'commercetools', 'gra...
# 2  2020-08-06T17:15:53Z  {'id': 13028066, 'login': 'Chrzaszczyzewoszyce...
# 3  2020-08-06T17:15:53Z                                                NaN
# 4  2020-08-06T17:15:53Z                                                NaN
#
#    actor_id         actor_login actor_display_login actor_gravatar_id  \
# 0  20477746  santhoshramanathan  santhoshramanathan
# 1  29139614       renovate[bot]            renovate
# 2   7911893          slskopytko          slskopytko
# 3  67704827             ctutiya             ctutiya
# 4   1748530        antonyantony        antonyantony
#
#                                          actor_url  \
# 0  https://api.github.com/users/santhoshramanathan
# 1       https://api.github.com/users/renovate[bot]
# 2          https://api.github.com/users/slskopytko
# 3             https://api.github.com/users/ctutiya
# 4        https://api.github.com/users/antonyantony
#
#                                     actor_avatar_url
# 0  https://avatars.githubusercontent.com/u/20477746?
# 1  https://avatars.githubusercontent.com/u/29139614?
# 2   https://avatars.githubusercontent.com/u/7911893?
# 3  https://avatars.githubusercontent.com/u/67704827?
# 4   https://avatars.githubusercontent.com/u/1748530?

# %%
# drop the 'messy' column

data = data.drop('actor', axis=1)

# %%
data.head(10)
# Out:
#             id                           type  \
# 0  13131572881                    CreateEvent
# 1  13131572876                      PushEvent
# 2  13131572868                      PushEvent
# 3  13131572860                      PushEvent
# 4  13131572843                      PushEvent
# 5  13131572852               PullRequestEvent
# 6  13131572849                    MemberEvent
# 7  13131572834  PullRequestReviewCommentEvent
# 8  13131572832                      PushEvent
# 9  13131572820                      PushEvent
#
#                                                 repo  \
# 0  {'id': 285277549, 'name': 'santhoshramanathan/...
# 1  {'id': 146916092, 'name': 'commercetools/ui-ki...
# 2  {'id': 285627963, 'name': 'Chrzaszczyzewoszyce...
# 3  {'id': 285628440, 'name': 'ctutiya/joshbersin'...
# 4  {'id': 89720418, 'name': 'antonyantony/libresw...
# 5  {'id': 87125103, 'name': 'nypublicradio/nypr-a...
# 6  {'id': 282615733, 'name': 'iiitnprobe/iiitnpro...
# 7  {'id': 44838949, 'name': 'apple/swift', 'url':...
# 8  {'id': 138178056, 'name': 'q375ml/PEGGY-PORTFO...
# 9  {'id': 285614403, 'name': 'mengjutsai/tutorial...
#
#                                              payload  public  \
# 0  {'ref': '0.0.1-oneclk-frntend-chart.8', 'ref_t...    True
# 1  {'push_id': 5492236582, 'size': 2, 'distinct_s...    True
# 2  {'push_id': 5492236577, 'size': 1, 'distinct_s...    True
# 3  {'push_id': 5492236575, 'size': 1, 'distinct_s...    True
# 4  {'push_id': 5492236564, 'size': 1, 'distinct_s...    True
# 5  {'action': 'opened', 'number': 106, 'pull_requ...    True
# 6  {'member': {'login': 'Hemanshu68', 'id': 61977...    True
# 7  {'action': 'created', 'comment': {'url': 'http...    True
# 8  {'push_id': 5492236560, 'size': 1, 'distinct_s...    True
# 9  {'push_id': 5492236548, 'size': 1, 'distinct_s...    True
#
#              created_at                                                org  \
# 0  2020-08-06T17:15:53Z                                                NaN
# 1  2020-08-06T17:15:53Z  {'id': 1084585, 'login': 'commercetools', 'gra...
# 2  2020-08-06T17:15:53Z  {'id': 13028066, 'login': 'Chrzaszczyzewoszyce...
# 3  2020-08-06T17:15:53Z                                                NaN
# 4  2020-08-06T17:15:53Z                                                NaN
# 5  2020-08-06T17:15:53Z  {'id': 1070797, 'login': 'nypublicradio', 'gra...
# 6  2020-08-06T17:15:53Z                                                NaN
# 7  2020-08-06T17:15:52Z  {'id': 10639145, 'login': 'apple', 'gravatar_i...
# 8  2020-08-06T17:15:53Z                                                NaN
# 9  2020-08-06T17:15:53Z                                                NaN
#
#    actor_id              actor_login actor_display_login actor_gravatar_id  \
# 0  20477746       santhoshramanathan  santhoshramanathan
# 1  29139614            renovate[bot]            renovate
# 2   7911893               slskopytko          slskopytko
# 3  67704827                  ctutiya             ctutiya
# 4   1748530             antonyantony        antonyantony
# 5  27856297  dependabot-preview[bot]  dependabot-preview
# 6  68732767               iiitnprobe          iiitnprobe
# 7   2251653            adrian-prantl       adrian-prantl
# 8  21154424                   q375ml              q375ml
# 9  11172640               mengjutsai          mengjutsai
#
#                                            actor_url  \
# 0    https://api.github.com/users/santhoshramanathan
# 1         https://api.github.com/users/renovate[bot]
# 2            https://api.github.com/users/slskopytko
# 3               https://api.github.com/users/ctutiya
# 4          https://api.github.com/users/antonyantony
# 5  https://api.github.com/users/dependabot-previe...
# 6            https://api.github.com/users/iiitnprobe
# 7         https://api.github.com/users/adrian-prantl
# 8                https://api.github.com/users/q375ml
# 9            https://api.github.com/users/mengjutsai
#
#                                     actor_avatar_url
# 0  https://avatars.githubusercontent.com/u/20477746?
# 1  https://avatars.githubusercontent.com/u/29139614?
# 2   https://avatars.githubusercontent.com/u/7911893?
# 3  https://avatars.githubusercontent.com/u/67704827?
# 4   https://avatars.githubusercontent.com/u/1748530?
# 5  https://avatars.githubusercontent.com/u/27856297?
# 6  https://avatars.githubusercontent.com/u/68732767?
# 7   https://avatars.githubusercontent.com/u/2251653?
# 8  https://avatars.githubusercontent.com/u/21154424?
# 9  https://avatars.githubusercontent.com/u/11172640?

# %% [markdown]
# ### More Complex API Requests: For Loop

# %% [markdown]
# Most data types of these kinds have more than one condensed column. In that case, it is useful to simply loop over those columns for which this holds.

# %%
# Reinitialise the data
response = requests.get('https://api.github.com/events')
data = pd.DataFrame(response.json())

# %%
data.head(10)
# Out:
#             id              type  \
# 0  13131803442         PushEvent
# 1  13131803436       DeleteEvent
# 2  13131803426         PushEvent
# 3  13131803427        WatchEvent
# 4  13131803418         PushEvent
# 5  13131803423  PullRequestEvent
# 6  13131803425       CreateEvent
# 7  13131803421       DeleteEvent
# 8  13131803414         PushEvent
# 9  13131803406         PushEvent
#
#                                                actor  \
# 0  {'id': 45753873, 'login': 'GuldLuca', 'display...
# 1  {'id': 2874965, 'login': 'qooplmao', 'display_...
# 2  {'id': 25770527, 'login': 'pranavfriend1', 'di...
# 3  {'id': 44944407, 'login': 'xuanyu123', 'displa...
# 4  {'id': 6268905, 'login': 'me-jser', 'display_l...
# 5  {'id': 51982242, 'login': 'idazanggara', 'disp...
# 6  {'id': 16035941, 'login': 'JavierLaguna', 'dis...
# 7  {'id': 49699333, 'login': 'dependabot[bot]', '...
# 8  {'id': 38430641, 'login': 'Reactiver', 'displa...
# 9  {'id': 53914655, 'login': 'ebapidb', 'display_...
#
#                                                 repo  \
# 0  {'id': 278071331, 'name': 'GuldLuca/nodejs_exa...
# 1  {'id': 231526885, 'name': 'qooplmao/michaelfit...
# 2  {'id': 198056400, 'name': 'Ashutoshtripathi14/...
# 3  {'id': 281119466, 'name': 'wgpsec/Perception',...
# 4  {'id': 157518180, 'name': 'jdcloudcom/MKTConte...
# 5  {'id': 285508721, 'name': 'kelompok1-cryptocur...
# 6  {'id': 285633679, 'name': 'JavierLaguna/Eh-Ho-...
# 7  {'id': 254961488, 'name': 'khkwan0/tourneydb',...
# 8  {'id': 266059778, 'name': 'Reactiver/ide-setti...
# 9  {'id': 174544468, 'name': 'VEuPathDB/StaticCon...
#
#                                              payload  public  \
# 0  {'push_id': 5492355825, 'size': 1, 'distinct_s...    True
# 1  {'ref': 'renovate/gatsby-monorepo', 'ref_type'...    True
# 2  {'push_id': 5492355808, 'size': 1, 'distinct_s...    True
# 3                              {'action': 'started'}    True
# 4  {'push_id': 5492355798, 'size': 1, 'distinct_s...    True
# 5  {'action': 'closed', 'number': 10, 'pull_reque...    True
# 6  {'ref': None, 'ref_type': 'repository', 'maste...    True
# 7  {'ref': 'dependabot/npm_and_yarn/api/fastify-2...    True
# 8  {'push_id': 5492355804, 'size': 1, 'distinct_s...    True
# 9  {'push_id': 5492355803, 'size': 1, 'distinct_s...    True
#
#              created_at                                                org
# 0  2020-08-06T17:41:49Z                                                NaN
# 1  2020-08-06T17:41:49Z                                                NaN
# 2  2020-08-06T17:41:49Z                                                NaN
# 3  2020-08-06T17:41:49Z  {'id': 20661677, 'login': 'wgpsec', 'gravatar_...
# 4  2020-08-06T17:41:49Z  {'id': 40586795, 'login': 'jdcloudcom', 'grava...
# 5  2020-08-06T17:41:49Z  {'id': 69297751, 'login': 'kelompok1-cryptocur...
# 6  2020-08-06T17:41:49Z                                                NaN
# 7  2020-08-06T17:41:49Z                                                NaN
# 8  2020-08-06T17:41:49Z                                                NaN
# 9  2020-08-06T17:41:49Z  {'id': 903733, 'login': 'VEuPathDB', 'gravatar...

# %%
# select the columns that contain a dictionary
col_list = ['actor', 'org', 'payload', 'repo']

# %%
# Create a for-loop to loop over the columns
# col_list = ['actor', 'org', 'payload', 'repo']

for column in col_list:
    flattened = pd.DataFrame(dict(data[column])).transpose()
    columns = [str(col) for col in flattened.columns]
    flattened.columns = [column + '_' + colname for colname in columns]
    data = pd.concat([data, flattened], axis=1)
    data = data.drop(column, axis=1)

# %%
data.head()
# Out:
#             id         type  public            created_at  actor_id  \
# 0  13131803442    PushEvent    True  2020-08-06T17:41:49Z  45753873
# 1  13131803436  DeleteEvent    True  2020-08-06T17:41:49Z   2874965
# 2  13131803426    PushEvent    True  2020-08-06T17:41:49Z  25770527
# 3  13131803427   WatchEvent    True  2020-08-06T17:41:49Z  44944407
# 4  13131803418    PushEvent    True  2020-08-06T17:41:49Z   6268905
#
#      actor_login actor_display_login actor_gravatar_id  \
# 0       GuldLuca            GuldLuca
# 1       qooplmao            qooplmao
# 2  pranavfriend1       pranavfriend1
# 3      xuanyu123           xuanyu123
# 4        me-jser             me-jser
#
#                                     actor_url  \
# 0       https://api.github.com/users/GuldLuca
# 1       https://api.github.com/users/qooplmao
# 2  https://api.github.com/users/pranavfriend1
# 3      https://api.github.com/users/xuanyu123
# 4        https://api.github.com/users/me-jser
#
#                                     actor_avatar_url  ... payload_number  \
# 0  https://avatars.githubusercontent.com/u/45753873?  ...            NaN
# 1   https://avatars.githubusercontent.com/u/2874965?  ...            NaN
# 2  https://avatars.githubusercontent.com/u/25770527?  ...            NaN
# 3  https://avatars.githubusercontent.com/u/44944407?  ...            NaN
# 4   https://avatars.githubusercontent.com/u/6268905?  ...            NaN
#
#   payload_pull_request payload_master_branch payload_description  \
# 0                  NaN                   NaN                 NaN
# 1                  NaN                   NaN                 NaN
# 2                  NaN                   NaN                 NaN
# 3                  NaN                   NaN                 NaN
# 4                  NaN                   NaN                 NaN
#
#   payload_issue payload_comment payload_member    repo_id  \
# 0           NaN             NaN            NaN  278071331
# 1           NaN             NaN            NaN  231526885
# 2           NaN             NaN            NaN  198056400
# 3           NaN             NaN            NaN  281119466
# 4           NaN             NaN            NaN  157518180
#
#                            repo_name  \
# 0               GuldLuca/nodejs_exam
# 1  qooplmao/michaelfitzpatrick.co.uk
# 2          Ashutoshtripathi14/vector
# 3                  wgpsec/Perception
# 4              jdcloudcom/MKTContent
#
#                                             repo_url
# 0  https://api.github.com/repos/GuldLuca/nodejs_exam
# 1  https://api.github.com/repos/qooplmao/michaelf...
# 2  https://api.github.com/repos/Ashutoshtripathi1...
# 3     https://api.github.com/repos/wgpsec/Perception
# 4  https://api.github.com/repos/jdcloudcom/MKTCon...
#
# [5 rows x 35 columns]

# %% [markdown]
# ### More Complex API Requests: Function

# %% [markdown]
# We can also write a function that does this for us. Using a function allows us to return a new data frame without actually interfering upon the original one.

# %%
# Reinitialise the data
response = requests.get('https://api.github.com/events')
data = pd.DataFrame(response.json())

# %%
def flatten(data, col_list):
    for column in col_list:
        flattened = pd.DataFrame(dict(data[column])).transpose()
        columns = [str(col) for col in flattened.columns]
        flattened.columns = [column + '_' + colname for colname in columns]
        data = pd.concat([data, flattened], axis=1)
        data = data.drop(column, axis=1)
    return data

# %%
# Call the function flatten
nested_columns = ['actor', 'org', 'payload', 'repo']

flat = flatten(data, nested_columns)

# %%
# display here
flat.head(10)
# Out:
#             id                           type  public            created_at  \
# 0  13131873853  PullRequestReviewCommentEvent    True  2020-08-06T17:21:50Z
# 1  13131873863                    CreateEvent    True  2020-08-06T17:49:44Z
# 2  13131873855                      PushEvent    True  2020-08-06T17:49:44Z
# 3  13131873862                    DeleteEvent    True  2020-08-06T17:49:44Z
# 4  13131873859  PullRequestReviewCommentEvent    True  2020-08-06T17:31:10Z
# 5  13131873852                    CreateEvent    True  2020-08-06T17:49:44Z
# 6  13131873856                    DeleteEvent    True  2020-08-06T17:49:44Z
# 7  13131873842  PullRequestReviewCommentEvent    True  2020-08-06T17:20:56Z
# 8  13131873841  PullRequestReviewCommentEvent    True  2020-08-06T17:49:44Z
# 9  13131873838               PullRequestEvent    True  2020-08-06T17:49:44Z
#
#    actor_id      actor_login actor_display_login actor_gravatar_id  \
# 0   1738558         codyhoag            codyhoag
# 1  45901471      AadiRana911         AadiRana911
# 2  21114956      ValeFranchi         ValeFranchi
# 3  49699333  dependabot[bot]          dependabot
# 4   1738558         codyhoag            codyhoag
# 5  47634520          jcrattz             jcrattz
# 6  21114956      ValeFranchi         ValeFranchi
# 7   1738558         codyhoag            codyhoag
# 8  15035320         cdaly333            cdaly333
# 9  59701002   rebecatalkdesk      rebecatalkdesk
#
#                                       actor_url  \
# 0         https://api.github.com/users/codyhoag
# 1      https://api.github.com/users/AadiRana911
# 2      https://api.github.com/users/ValeFranchi
# 3  https://api.github.com/users/dependabot[bot]
# 4         https://api.github.com/users/codyhoag
# 5          https://api.github.com/users/jcrattz
# 6      https://api.github.com/users/ValeFranchi
# 7         https://api.github.com/users/codyhoag
# 8         https://api.github.com/users/cdaly333
# 9   https://api.github.com/users/rebecatalkdesk
#
#                                     actor_avatar_url  ... payload_size  \
# 0   https://avatars.githubusercontent.com/u/1738558?  ...          NaN
# 1  https://avatars.githubusercontent.com/u/45901471?  ...          NaN
# 2  https://avatars.githubusercontent.com/u/21114956?  ...            1
# 3  https://avatars.githubusercontent.com/u/49699333?  ...          NaN
# 4   https://avatars.githubusercontent.com/u/1738558?  ...          NaN
# 5  https://avatars.githubusercontent.com/u/47634520?  ...          NaN
# 6  https://avatars.githubusercontent.com/u/21114956?  ...          NaN
# 7   https://avatars.githubusercontent.com/u/1738558?  ...          NaN
# 8  https://avatars.githubusercontent.com/u/15035320?  ...          NaN
# 9  https://avatars.githubusercontent.com/u/59701002?  ...          NaN
#
#   payload_distinct_size                              payload_head  \
# 0                   NaN                                       NaN
# 1                   NaN                                       NaN
# 2                     1  e620bf4d51311b2d8e7ec60edbb72ba000361328
# 3                   NaN                                       NaN
# 4                   NaN                                       NaN
# 5                   NaN                                       NaN
# 6                   NaN                                       NaN
# 7                   NaN                                       NaN
# 8                   NaN                                       NaN
# 9                   NaN                                       NaN
#
#                              payload_before  \
# 0                                       NaN
# 1                                       NaN
# 2  2580d7ad5570447ce242ed3b65efc9355393ca2a
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
# 6                                       NaN
# 7                                       NaN
# 8                                       NaN
# 9                                       NaN
#
#                                      payload_commits payload_number  \
# 0                                                NaN            NaN
# 1                                                NaN            NaN
# 2  [{'sha': 'e620bf4d51311b2d8e7ec60edbb72ba00036...            NaN
# 3                                                NaN            NaN
# 4                                                NaN            NaN
# 5                                                NaN            NaN
# 6                                                NaN            NaN
# 7                                                NaN            NaN
# 8                                                NaN            NaN
# 9                                                NaN            187
#
#   payload_issue    repo_id                                      repo_name  \
# 0           NaN   21740844                       openshift/openshift-docs
# 1           NaN  285635228                AadiRana911/aadi-rana.github.io
# 2           NaN  202741795               loopstudio/react-app-boilerplate
# 3           NaN  264158548                              haiphandesign/hai
# 4           NaN   21740844                       openshift/openshift-docs
# 5           NaN  268943195  digitalearthafrica/deafrica-training-workshop
# 6           NaN  202741795               loopstudio/react-app-boilerplate
# 7           NaN   21740844                       openshift/openshift-docs
# 8           NaN  267624045                 googleinterns/smart-home-local
# 9           NaN  261232338                                 Talkdesk/CREAC
#
#                                             repo_url
# 0  https://api.github.com/repos/openshift/openshi...
# 1  https://api.github.com/repos/AadiRana911/aadi-...
# 2  https://api.github.com/repos/loopstudio/react-...
# 3     https://api.github.com/repos/haiphandesign/hai
# 4  https://api.github.com/repos/openshift/openshi...
# 5  https://api.github.com/repos/digitalearthafric...
# 6  https://api.github.com/repos/loopstudio/react-...
# 7  https://api.github.com/repos/openshift/openshi...
# 8  https://api.github.com/repos/googleinterns/sma...
# 9        https://api.github.com/repos/Talkdesk/CREAC
#
# [10 rows x 34 columns]

# %% [markdown]
# ### More Complex API Requests: JSON_Normalise Function

# %% [markdown]
# Alternatively, we can flatten nested data using the function json_normalize. This function is part of the Pandas library.

# %% [markdown]
# Here is an example of how to use this function.

# %%
from pandas.io.json import json_normalize

results = response.json()
#results

# %%
flattened_data = json_normalize(results)
flattened_data
# Out:
#              id                           type  public            created_at  \
# 0   13131873853  PullRequestReviewCommentEvent    True  2020-08-06T17:21:50Z
# 1   13131873863                    CreateEvent    True  2020-08-06T17:49:44Z
# 2   13131873855                      PushEvent    True  2020-08-06T17:49:44Z
# 3   13131873862                    DeleteEvent    True  2020-08-06T17:49:44Z
# 4   13131873859  PullRequestReviewCommentEvent    True  2020-08-06T17:31:10Z
# 5   13131873852                    CreateEvent    True  2020-08-06T17:49:44Z
# 6   13131873856                    DeleteEvent    True  2020-08-06T17:49:44Z
# 7   13131873842  PullRequestReviewCommentEvent    True  2020-08-06T17:20:56Z
# 8   13131873841  PullRequestReviewCommentEvent    True  2020-08-06T17:49:44Z
# 9   13131873838               PullRequestEvent    True  2020-08-06T17:49:44Z
# 10  13131873826                      PushEvent    True  2020-08-06T17:49:44Z
# 11  13131873837              IssueCommentEvent    True  2020-08-06T17:49:44Z
# 12  13131873830  PullRequestReviewCommentEvent    True  2020-08-06T17:18:33Z
# 13  13131873833                    CreateEvent    True  2020-08-06T17:49:44Z
# 14  13131873831                    CreateEvent    True  2020-08-06T17:49:44Z
# 15  13131873825               PullRequestEvent    True  2020-08-06T17:49:44Z
# 16  13131873823  PullRequestReviewCommentEvent    True  2020-08-06T17:15:45Z
# 17  13131873820  PullRequestReviewCommentEvent    True  2020-08-06T17:17:03Z
# 18  13131873805                     WatchEvent    True  2020-08-06T17:49:44Z
# 19  13131873794                      PushEvent    True  2020-08-06T17:49:44Z
# 20  13131873788                      PushEvent    True  2020-08-06T17:49:44Z
# 21  13131873781                    CreateEvent    True  2020-08-06T17:49:44Z
# 22  13131873765                      PushEvent    True  2020-08-06T17:49:44Z
# 23  13131873764                      PushEvent    True  2020-08-06T17:49:44Z
# 24  13131873763                      PushEvent    True  2020-08-06T17:49:44Z
# 25  13131873761                    CreateEvent    True  2020-08-06T17:49:44Z
# 26  13131873740                      PushEvent    True  2020-08-06T17:49:44Z
# 27  13131873749              IssueCommentEvent    True  2020-08-06T17:49:44Z
# 28  13131873742               PullRequestEvent    True  2020-08-06T17:49:44Z
# 29  13131873733                      PushEvent    True  2020-08-06T17:49:44Z
#
#     actor.id              actor.login   actor.display_login actor.gravatar_id  \
# 0    1738558                 codyhoag              codyhoag
# 1   45901471              AadiRana911           AadiRana911
# 2   21114956              ValeFranchi           ValeFranchi
# 3   49699333          dependabot[bot]            dependabot
# 4    1738558                 codyhoag              codyhoag
# 5   47634520                  jcrattz               jcrattz
# 6   21114956              ValeFranchi           ValeFranchi
# 7    1738558                 codyhoag              codyhoag
# 8   15035320                 cdaly333              cdaly333
# 9   59701002           rebecatalkdesk        rebecatalkdesk
# 10  68417258          breakingheatmap       breakingheatmap
# 11   6331106                  codyoss               codyoss
# 12   1738558                 codyhoag              codyhoag
# 13  47148648     svc-software-factory  svc-software-factory
# 14    946903                    leezu                 leezu
# 15  65618041               GudiedRyan            GudiedRyan
# 16   1738558                 codyhoag              codyhoag
# 17   1738558                 codyhoag              codyhoag
# 18  40715044                   SukkaW                SukkaW
# 19  16075726                   olprod                olprod
# 20  69004726                 dicoking              dicoking
# 21  27856297  dependabot-preview[bot]    dependabot-preview
# 22  19311485                delcantao             delcantao
# 23  61518346             dipankarshaw          dipankarshaw
# 24  63329638         rogeliosamuel621      rogeliosamuel621
# 25   3496076                sixpac009             sixpac009
# 26  48250443                ssolomon9             ssolomon9
# 27   6123962                tinmarino             tinmarino
# 28  27856297  dependabot-preview[bot]    dependabot-preview
# 29  58665342                 mnglaura              mnglaura
#
#                                             actor.url  \
# 0               https://api.github.com/users/codyhoag
# 1            https://api.github.com/users/AadiRana911
# 2            https://api.github.com/users/ValeFranchi
# 3        https://api.github.com/users/dependabot[bot]
# 4               https://api.github.com/users/codyhoag
# 5                https://api.github.com/users/jcrattz
# 6            https://api.github.com/users/ValeFranchi
# 7               https://api.github.com/users/codyhoag
# 8               https://api.github.com/users/cdaly333
# 9         https://api.github.com/users/rebecatalkdesk
# 10       https://api.github.com/users/breakingheatmap
# 11               https://api.github.com/users/codyoss
# 12              https://api.github.com/users/codyhoag
# 13  https://api.github.com/users/svc-software-factory
# 14                 https://api.github.com/users/leezu
# 15            https://api.github.com/users/GudiedRyan
# 16              https://api.github.com/users/codyhoag
# 17              https://api.github.com/users/codyhoag
# 18                https://api.github.com/users/SukkaW
# 19                https://api.github.com/users/olprod
# 20              https://api.github.com/users/dicoking
# 21  https://api.github.com/users/dependabot-previe...
# 22             https://api.github.com/users/delcantao
# 23          https://api.github.com/users/dipankarshaw
# 24      https://api.github.com/users/rogeliosamuel621
# 25             https://api.github.com/users/sixpac009
# 26             https://api.github.com/users/ssolomon9
# 27             https://api.github.com/users/tinmarino
# 28  https://api.github.com/users/dependabot-previe...
# 29              https://api.github.com/users/mnglaura
#
#                                      actor.avatar_url  ...  \
# 0    https://avatars.githubusercontent.com/u/1738558?  ...
# 1   https://avatars.githubusercontent.com/u/45901471?  ...
# 2   https://avatars.githubusercontent.com/u/21114956?  ...
# 3   https://avatars.githubusercontent.com/u/49699333?  ...
# 4    https://avatars.githubusercontent.com/u/1738558?  ...
# 5   https://avatars.githubusercontent.com/u/47634520?  ...
# 6   https://avatars.githubusercontent.com/u/21114956?  ...
# 7    https://avatars.githubusercontent.com/u/1738558?  ...
# 8   https://avatars.githubusercontent.com/u/15035320?  ...
# 9   https://avatars.githubusercontent.com/u/59701002?  ...
# 10  https://avatars.githubusercontent.com/u/68417258?  ...
# 11   https://avatars.githubusercontent.com/u/6331106?  ...
# 12   https://avatars.githubusercontent.com/u/1738558?  ...
# 13  https://avatars.githubusercontent.com/u/47148648?  ...
# 14    https://avatars.githubusercontent.com/u/946903?  ...
# 15  https://avatars.githubusercontent.com/u/65618041?  ...
# 16   https://avatars.githubusercontent.com/u/1738558?  ...
# 17   https://avatars.githubusercontent.com/u/1738558?  ...
# 18  https://avatars.githubusercontent.com/u/40715044?  ...
# 19  https://avatars.githubusercontent.com/u/16075726?  ...
# 20  https://avatars.githubusercontent.com/u/69004726?  ...
# 21  https://avatars.githubusercontent.com/u/27856297?  ...
# 22  https://avatars.githubusercontent.com/u/19311485?  ...
# 23  https://avatars.githubusercontent.com/u/61518346?  ...
# 24  https://avatars.githubusercontent.com/u/63329638?  ...
# 25   https://avatars.githubusercontent.com/u/3496076?  ...
# 26  https://avatars.githubusercontent.com/u/48250443?  ...
# 27   https://avatars.githubusercontent.com/u/6123962?  ...
# 28  https://avatars.githubusercontent.com/u/27856297?  ...
# 29  https://avatars.githubusercontent.com/u/58665342?  ...
#
#     payload.issue.created_at payload.issue.updated_at payload.issue.closed_at  \
# 0                        NaN                      NaN                     NaN
# 1                        NaN                      NaN                     NaN
# 2                        NaN                      NaN                     NaN
# 3                        NaN                      NaN                     NaN
# 4                        NaN                      NaN                     NaN
# 5                        NaN                      NaN                     NaN
# 6                        NaN                      NaN                     NaN
# 7                        NaN                      NaN                     NaN
# 8                        NaN                      NaN                     NaN
# 9                        NaN                      NaN                     NaN
# 10                       NaN                      NaN                     NaN
# 11      2020-08-06T17:45:54Z     2020-08-06T17:49:44Z    2020-08-06T17:49:44Z
# 12                       NaN                      NaN                     NaN
# 13                       NaN                      NaN                     NaN
# 14                       NaN                      NaN                     NaN
# 15                       NaN                      NaN                     NaN
# 16                       NaN                      NaN                     NaN
# 17                       NaN                      NaN                     NaN
# 18                       NaN                      NaN                     NaN
# 19                       NaN                      NaN                     NaN
# 20                       NaN                      NaN                     NaN
# 21                       NaN                      NaN                     NaN
# 22                       NaN                      NaN                     NaN
# 23                       NaN                      NaN                     NaN
# 24                       NaN                      NaN                     NaN
# 25                       NaN                      NaN                     NaN
# 26                       NaN                      NaN                     NaN
# 27      2020-06-14T19:50:13Z     2020-08-06T17:49:44Z                    None
# 28                       NaN                      NaN                     NaN
# 29                       NaN                      NaN                     NaN
#
#    payload.issue.author_association payload.issue.active_lock_reason  \
# 0                               NaN                              NaN
# 1                               NaN                              NaN
# 2                               NaN                              NaN
# 3                               NaN                              NaN
# 4                               NaN                              NaN
# 5                               NaN                              NaN
# 6                               NaN                              NaN
# 7                               NaN                              NaN
# 8                               NaN                              NaN
# 9                               NaN                              NaN
# 10                              NaN                              NaN
# 11                             NONE                              NaN
# 12                              NaN                              NaN
# 13                              NaN                              NaN
# 14                              NaN                              NaN
# 15                              NaN                              NaN
# 16                              NaN                              NaN
# 17                              NaN                              NaN
# 18                              NaN                              NaN
# 19                              NaN                              NaN
# 20                              NaN                              NaN
# 21                              NaN                              NaN
# 22                              NaN                              NaN
# 23                              NaN                              NaN
# 24                              NaN                              NaN
# 25                              NaN                              NaN
# 26                              NaN                              NaN
# 27                             NONE                              NaN
# 28                              NaN                              NaN
# 29                              NaN                              NaN
#
#                                    payload.issue.body  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11  **Client**\r\n\r\nStorage on `cloud.google.com...
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27  This is feature request.\r\n\r\nI would like t...
# 28                                                NaN
# 29                                                NaN
#
#     payload.issue.performed_via_github_app  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# 5                                      NaN
# 6                                      NaN
# 7                                      NaN
# 8                                      NaN
# 9                                      NaN
# 10                                     NaN
# 11                                     NaN
# 12                                     NaN
# 13                                     NaN
# 14                                     NaN
# 15                                     NaN
# 16                                     NaN
# 17                                     NaN
# 18                                     NaN
# 19                                     NaN
# 20                                     NaN
# 21                                     NaN
# 22                                     NaN
# 23                                     NaN
# 24                                     NaN
# 25                                     NaN
# 26                                     NaN
# 27                                     NaN
# 28                                     NaN
# 29                                     NaN
#
#                             payload.comment.issue_url  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11  https://api.github.com/repos/googleapis/google...
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27  https://api.github.com/repos/vimwiki/vimwiki/i...
# 28                                                NaN
# 29                                                NaN
#
#    payload.comment.performed_via_github_app payload.pull_request.merged_by
# 0                                       NaN                            NaN
# 1                                       NaN                            NaN
# 2                                       NaN                            NaN
# 3                                       NaN                            NaN
# 4                                       NaN                            NaN
# 5                                       NaN                            NaN
# 6                                       NaN                            NaN
# 7                                       NaN                            NaN
# 8                                       NaN                            NaN
# 9                                       NaN                            NaN
# 10                                      NaN                            NaN
# 11                                      NaN                            NaN
# 12                                      NaN                            NaN
# 13                                      NaN                            NaN
# 14                                      NaN                            NaN
# 15                                      NaN                            NaN
# 16                                      NaN                            NaN
# 17                                      NaN                            NaN
# 18                                      NaN                            NaN
# 19                                      NaN                            NaN
# 20                                      NaN                            NaN
# 21                                      NaN                            NaN
# 22                                      NaN                            NaN
# 23                                      NaN                            NaN
# 24                                      NaN                            NaN
# 25                                      NaN                            NaN
# 26                                      NaN                            NaN
# 27                                      NaN                            NaN
# 28                                      NaN                            NaN
# 29                                      NaN                            NaN
#
# [30 rows x 488 columns]

# %% [markdown]
# **Important**: Sometimes multiple rounds of flattening will be required if the JSON data returned from the API you are working with has hierarchically nested data.

# %% [markdown]
# ## Summary
#
# In this lesson, we covered:

# %% [markdown]
# - The basics of working with APIs and API libraries;

# %% [markdown]
# - How to work with more complex API calls;

# %% [markdown]
# - How to flatten JSON-structured data.
